# %%
# Importing Libraries 

import pandas as pd
import numpy as np
import math
from pyomo.environ import *

# %%
from __future__ import division
from pyomo.opt import SolverFactory

# %%
# Reading the data from Excel workbook
InputData = 'C:\\Users\\dell\\Desktop\\Optimisation Case Study - Staff Planning\\Staffing+Data.xlsx'

# Reading data from Cost sheet
cost = pd.read_excel(InputData,sheet_name='Cost')

# Reading data from StaffAvailability sheet
availability = pd.read_excel(InputData,sheet_name='StaffAvailability')

# Reading data from DemandData sheet
demand = pd.read_excel(InputData,sheet_name='DemandData')

# Reading data from ServiceRate sheet
servicerate = pd.read_excel(InputData, sheet_name = 'ServiceRate')

# %%
# Reading Cost sheet

cost.head()
# Out:
#   State Month  AnnualSalary  MonthlySalary  UnitOutSourceCost  UnitOutCost_v2
# 0     A   Jan         60000         5000.0                180             155
# 1     A   Feb         60000         5000.0                180             155
# 2     A   Mar         60000         5000.0                180             155
# 3     A   Apr         60000         5000.0                180             155
# 4     A   May         60000         5000.0                180             155

# %%
# Reading StaffAvailability sheet

availability.head()
# Out:
#   State Month    LB    UB  StaffAvPer
# 0     A   Jan  0.70  0.90        0.81
# 1     A   Feb  0.65  0.85        0.76
# 2     A   Mar  0.70  0.80        0.75
# 3     A   Apr  0.75  0.85        0.80
# 4     A   May  0.70  0.85        0.78

# %%
# Reading DemandData sheet

demand.head()
# Out:
#   State Month  Demand
# 0     A   Jan    5240
# 1     A   Feb    4878
# 2     A   Mar    5942
# 3     A   Apr    2297
# 4     A   May    1992

# %%
# Reading ServiceRate

servicerate.head()
# Out:
#    MgAppServedPerMonth
# 0                   40

# %% [markdown]
# ## Data pre-processing

# %%
# Create the required Python data structures for indexes and parameters

# DEMAND-Per month, per state
Demand = demand.set_index(['State', 'Month'])['Demand'].to_dict()
print('Demand : ', Demand)

# Average availability of staff
StaffAvPer = availability.set_index(['State', 'Month'])['StaffAvPer'].to_dict()
print('\n Availability Rate : ', StaffAvPer)

#Availability of employees - best case with high availability - upper bound
StaffAv_UB = availability.set_index(['State', 'Month'])['UB'].to_dict()
print('\n Availability Rate : ', StaffAv_UB)

# Availability of employees - worst case with low availability - lower bound
StaffAv_LB = availability.set_index(['State', 'Month'])['LB'].to_dict()
print('\n Availability Rate : ', StaffAv_LB)

# FTE Salary data
FTE_Salary = cost.set_index(['State', 'Month'])['MonthlySalary'].to_dict()
print('\n Employee Cost : ', FTE_Salary)

# Unit Outsourcing Cost
outsourcecost = cost.set_index(['State', 'Month'])['UnitOutSourceCost'].to_dict()
print('\n Outsource Cost : ', outsourcecost)

# Outosurcing cost per application - Vendor2
outsourcecost_vendor2=cost.set_index(['State', 'Month'])['UnitOutCost_v2'].to_dict()
print('\n Outsource Cost V2 : ', outsourcecost_vendor2)

# Regulatory requirement on maximum outsourcing 
regulation_base ={'A':0.3, 'B':0.4, 'C':1.0}
print('\n Regulatory percent of Outsource allowed : ', regulation_base)

# No. of application handled by FTE on 100% working
FTE_MgAppServed = servicerate.iloc[0,0]
print('\n Service rate) : ', FTE_MgAppServed)
# Out:
# Demand :  {('A', 'Jan'): 5240, ('A', 'Feb'): 4878, ('A', 'Mar'): 5942, ('A', 'Apr'): 2297, ('A', 'May'): 1992, ('A', 'Jun'): 2275, ('A', 'Jul'): 5334, ('A', 'Aug'): 3371, ('A', 'Sep'): 3759, ('A', 'Oct'): 3529, ('A', 'Nov'): 4284, ('A', 'Dec'): 5183, ('B', 'Jan'): 4927, ('B', 'Feb'): 2628, ('B', 'Mar'): 2974, ('B', 'Apr'): 2338, ('B', 'May'): 4020, ('B', 'Jun'): 3147, ('B', 'Jul'): 4271, ('B', 'Aug'): 2620, ('B', 'Sep'): 4517, ('B', 'Oct'): 4155, ('B', 'Nov'): 3137, ('B', 'Dec'): 4227, ('C', 'Jan'): 1162, ('C', 'Feb'): 1967, ('C', 'Mar'): 1898, ('C', 'Apr'): 2261, ('C', 'May'): 2030, ('C', 'Jun'): 1642, ('C', 'Jul'): 2489, ('C', 'Aug'): 2496, ('C', 'Sep'): 922, ('C', 'Oct'): 2421, ('C', 'Nov'): 963, ('C', 'Dec'): 1998}
#
#  Availability Rate :  {('A', 'Jan'): 0.81, ('A', 'Feb'): 0.76, ('A', 'Mar'): 0.75, ('A', 'Apr'): 0.8, ('A', 'May'): 0.78, ('A', 'Jun'): 0.73, ('A', 'Jul'): 0.68, ('A', 'Aug'): 0.76, ('A', 'Sep'): 0.81, ('A', 'Oct'): 0.73, ('A', 'Nov'): 0.68, ('A', 'Dec'): 0.65, ('B', 'Jan'): 0.81, ('B', 'Feb'): 0.76, ('B', 'Mar'): 0.75, ('B', 'Apr'): 0.8, ('B', 'May'): 0.78, ('B', 'Jun'): 0.73, ('B', 'Jul'): 0.68, ('B', 'Aug'): 0.76, ('B', 'Sep'): 0.81, ('B', 'Oct'): 0.73, ('B', 'Nov'): 0.68, ('B', 'Dec'): 0.65, ('C', 'Jan'): 0.81, ('C', 'Feb'): 0.76, ('C', 'Mar'): 0.75, ('C', 'Apr'): 0.8, ('C', 'May'): 0.78, ('C', 'Jun'): 0.73, ('C', 'Jul'): 0.68, ('C', 'Aug'): 0.76, ('C', 'Sep'): 0.81, ('C', 'Oct'): 0.73, ('C', 'Nov'): 0.68, ('C', 'Dec'): 0.65}
#
#  Availability Rate :  {('A', 'Jan'): 0.9, ('A', 'Feb'): 0.85, ('A', 'Mar'): 0.8, ('A', 'Apr'): 0.85, ('A', 'May'): 0.85, ('A', 'Jun'): 0.8, ('A', 'Jul'): 0.75, ('A', 'Aug'): 0.85, ('A', 'Sep'): 0.9, ('A', 'Oct'): 0.8, ('A', 'Nov'): 0.75, ('A', 'Dec'): 0.7, ('B', 'Jan'): 0.9, ('B', 'Feb'): 0.85, ('B', 'Mar'): 0.8, ('B', 'Apr'): 0.85, ('B', 'May'): 0.85, ('B', 'Jun'): 0.8, ('B', 'Jul'): 0.75, ('B', 'Aug'): 0.85, ('B', 'Sep'): 0.9, ('B', 'Oct'): 0.8, ('B', 'Nov'): 0.75, ('B', 'Dec'): 0.7, ('C', 'Jan'): 0.9, ('C', 'Feb'): 0.85, ('C', 'Mar'): 0.8, ('C', 'Apr'): 0.85, ('C', 'May'): 0.85, ('C', 'Jun'): 0.8, ('C', 'Jul'): 0.75, ('C', 'Aug'): 0.85, ('C', 'Sep'): 0.9, ('C', 'Oct'): 0.8, ('C', 'Nov'): 0.75, ('C', 'Dec'): 0.7}
#
#  Availability Rate :  {('A', 'Jan'): 0.7, ('A', 'Feb'): 0.65, ('A', 'Mar'): 0.7, ('A', 'Apr'): 0.75, ('A', 'May'): 0.7, ('A', 'Jun'): 0.65, ('A', 'Jul'): 0.6, ('A', 'Aug'): 0.65, ('A', 'Sep'): 0.7, ('A', 'Oct'): 0.65, ('A', 'Nov'): 0.6, ('A', 'Dec'): 0.6, ('B', 'Jan'): 0.7, ('B', 'Feb'): 0.65, ('B', 'Mar'): 0.7, ('B', 'Apr'): 0.75, ('B', 'May'): 0.7, ('B', 'Jun'): 0.65, ('B', 'Jul'): 0.6, ('B', 'Aug'): 0.65, ('B', 'Sep'): 0.7, ('B', 'Oct'): 0.65, ('B', 'Nov'): 0.6, ('B', 'Dec'): 0.6, ('C', 'Jan'): 0.7, ('C', 'Feb'): 0.65, ('C', 'Mar'): 0.7, ('C', 'Apr'): 0.75, ('C', 'May'): 0.7, ('C', 'Jun'): 0.65, ('C', 'Jul'): 0.6, ('C', 'Aug'): 0.65, ('C', 'Sep'): 0.7, ('C', 'Oct'): 0.65, ('C', 'Nov'): 0.6, ('C', 'Dec'): 0.6}
#
#  Employee Cost :  {('A', 'Jan'): 5000.0, ('A', 'Feb'): 5000.0, ('A', 'Mar'): 5000.0, ('A', 'Apr'): 5000.0, ('A', 'May'): 5000.0, ('A', 'Jun'): 5000.0, ('A', 'Jul'): 5000.0, ('A', 'Aug'): 5000.0, ('A', 'Sep'): 5000.0, ('A', 'Oct'): 5000.0, ('A', 'Nov'): 5000.0, ('A', 'Dec'): 5000.0, ('B', 'Jan'): 4583.333333333333, ('B', 'Feb'): 4583.333333333333, ('B', 'Mar'): 4583.333333333333, ('B', 'Apr'): 4583.333333333333, ('B', 'May'): 4583.333333333333, ('B', 'Jun'): 4583.333333333333, ('B', 'Jul'): 4583.333333333333, ('B', 'Aug'): 4583.333333333333, ('B', 'Sep'): 4583.333333333333, ('B', 'Oct'): 4583.333333333333, ('B', 'Nov'): 4583.333333333333, ('B', 'Dec'): 4583.333333333333, ('C', 'Jan'): 4416.666666666667, ('C', 'Feb'): 4416.666666666667, ('C', 'Mar'): 4416.666666666667, ('C', 'Apr'): 4416.666666666667, ('C', 'May'): 4416.666666666667, ('C', 'Jun'): 4416.666666666667, ('C', 'Jul'): 4416.666666666667, ('C', 'Aug'): 4416.666666666667, ('C', 'Sep'): 4416.666666666667, ('C', 'Oct'): 4416.666666666667, ('C', 'Nov'): 4416.666666666667, ('C', 'Dec'): 4416.666666666667}
#
#  Outsource Cost :  {('A', 'Jan'): 180, ('A', 'Feb'): 180, ('A', 'Mar'): 180, ('A', 'Apr'): 180, ('A', 'May'): 180, ('A', 'Jun'): 180, ('A', 'Jul'): 180, ('A', 'Aug'): 180, ('A', 'Sep'): 180, ('A', 'Oct'): 180, ('A', 'Nov'): 180, ('A', 'Dec'): 180, ('B', 'Jan'): 150, ('B', 'Feb'): 150, ('B', 'Mar'): 150, ('B', 'Apr'): 150, ('B', 'May'): 150, ('B', 'Jun'): 150, ('B', 'Jul'): 150, ('B', 'Aug'): 150, ('B', 'Sep'): 150, ('B', 'Oct'): 150, ('B', 'Nov'): 150, ('B', 'Dec'): 150, ('C', 'Jan'): 160, ('C', 'Feb'): 160, ('C', 'Mar'): 160, ('C', 'Apr'): 160, ('C', 'May'): 160, ('C', 'Jun'): 160, ('C', 'Jul'): 160, ('C', 'Aug'): 160, ('C', 'Sep'): 160, ('C', 'Oct'): 160, ('C', 'Nov'): 160, ('C', 'Dec'): 160}
#
#  Outsource Cost V2 :  {('A', 'Jan'): 155, ('A', 'Feb'): 155, ('A', 'Mar'): 155, ('A', 'Apr'): 155, ('A', 'May'): 155, ('A', 'Jun'): 155, ('A', 'Jul'): 155, ('A', 'Aug'): 155, ('A', 'Sep'): 155, ('A', 'Oct'): 155, ('A', 'Nov'): 155, ('A', 'Dec'): 155, ('B', 'Jan'): 150, ('B', 'Feb'): 150, ('B', 'Mar'): 150, ('B', 'Apr'): 150, ('B', 'May'): 150, ('B', 'Jun'): 150, ('B', 'Jul'): 150, ('B', 'Aug'): 150, ('B', 'Sep'): 150, ('B', 'Oct'): 150, ('B', 'Nov'): 150, ('B', 'Dec'): 150, ('C', 'Jan'): 158, ('C', 'Feb'): 158, ('C', 'Mar'): 158, ('C', 'Apr'): 158, ('C', 'May'): 158, ('C', 'Jun'): 158, ('C', 'Jul'): 158, ('C', 'Aug'): 158, ('C', 'Sep'): 158, ('C', 'Oct'): 158, ('C', 'Nov'): 158, ('C', 'Dec'): 158}
#
#  Regulatory percent of Outsource allowed :  {'A': 0.3, 'B': 0.4, 'C': 1.0}
#
#  Service rate) :  40

# %%
# Index

# unique value of State index over each sate
state = cost['State'].unique()
print('state : ', state)

# unique value of time index over each month
month = cost['Month'].unique()
print('month : ', month)
# Out:
# state :  ['A' 'B' 'C']
# month :  ['Jan' 'Feb' 'Mar' 'Apr' 'May' 'Jun' 'Jul' 'Aug' 'Sep' 'Oct' 'Nov' 'Dec']

# %% [markdown]
# # Question 1
#
# The company wants to know the optimised staffing recommendations for the business case described.
# Write the mathematical model for the deterministic optimisation problem. Define and explain your decision variables, objective function and the constraint. (Hint: Use months of the year as the model timeline).

# %% [markdown]
# **Note:** You can write the mathematical formulation directly in your report.

# %% [markdown]
# # Question 2
#
# Code the problem is Python and use any optimization package to solve it. Add comments to your code to explain each step.

# %% [markdown]
# #### Expected output:
#
# Create a data frame containing the number of outsourced applications  and the number of FTEs for each state-month combination. You can choose to have extra columns like staff availability, demand etc. in your dataframe apart from the ones mentioned earlier.

# %%
# Creating a model instance
model = ConcreteModel()

# %%
# Define Pyomo sets and Parameters

# Index :  month and  state

#Parameters : in code terms it is already defined above
# for in-house processing
#  Employee Cost - Monthly Salary across each state  : employeecost
#  Service Rate - Maximum applications that can be processed per FTE  : FTE_MgAppServed
# Availability Rate - Percentage of avaialability for FTE for each state for each month : StaffAvPer
# for Outsourced processing
# Outsourcing Cost - Outsourced processing cost per application :  outsourcecost
# for contraint definitions
# regulatory limit on percentage of application that can be outsourced : regulation_base
# demand for each state each month that needs to be completely serviced : Demand

# %%
# Decision variables

#Number of applications managed by Staff or own employee
model.x = Var(state, month, within=Integers, bounds=(0,None))

#Number of applications managed by Outsourced vendor
model.y = Var(state, month, within=Integers, bounds=(0,None))

# %%
# Objective function

#Total processing cost = Salary cost for inhouse processed applications + processing cost for outsourced applications
#outsourcing cost is equal to outsourced applications count (Y) mutplied by outsourcing cost per application
#salary cost is decision variable (X)  * employee salary adjusted for servicerate and availability rate

def obj_rule(model):
    
    return sum(((model.x[s,m]*FTE_Salary[s,m]/FTE_MgAppServed/StaffAvPer[s,m])
               +(model.y[s,m])*outsourcecost[s,m])
                for s in state for m in month)

model.value = Objective(rule=obj_rule, sense= minimize) # Minimize the total cost for the application approval process

# %%
# Constraints
# OUTSOURCE CONSTRAINT - Regulatory requirement of maximum percentage of applications that can be outsourced

def max_outsourced_perstate_permonth(model,s,m):
    return (model.y[s,m]/Demand[s,m]) <= regulation_base[s]
                   
model.max_outsourced = Constraint(state, month, rule=max_outsourced_perstate_permonth)

# %%
# Constraints
# DEMAND CONSTRAINT - entire demand should be serviced

def demand_serviced(model,s,m):
    return (model.x[s,m]+ model.y[s,m]) == Demand[s,m]
                   
model.demandserviced = Constraint(state, month, rule=demand_serviced)

# %%
# Invoking the solver
result = SolverFactory('glpk').solve(model)
result.write()
# Out:
# # ==========================================================
# # = Solver Results                                         =
# # ==========================================================
# # ----------------------------------------------------------
# #   Problem Information
# # ----------------------------------------------------------
# Problem:
# - Name: unknown
#   Lower bound: 17962336.4487699
#   Upper bound: 17962336.4487699
#   Number of objectives: 1
#   Number of constraints: 73
#   Number of variables: 73
#   Number of nonzeros: 109
#   Sense: minimize
# # ----------------------------------------------------------
# #   Solver Information
# # ----------------------------------------------------------
# Solver:
# - Status: ok
#   Termination condition: optimal
#   Statistics:
#     Branch and bound:
#       Number of bounded subproblems: 1
#       Number of created subproblems: 1
#   Error rc: 0
#   Time: 0.14058923721313477
# # ----------------------------------------------------------
# #   Solution Information
# # ----------------------------------------------------------
# Solution:
# - number of solutions: 0
#   number of solutions displayed: 0

# %%
#dispalying optimal result parameters
model.pprint()
# Out:
# 12 Set Declarations
#     demandserviced_index : Size=1, Index=None, Ordered=False
#         Key  : Dimen : Domain                                        : Size : Members
#         None :     2 : demandserviced_index_0*demandserviced_index_1 :   36 : {('A', 'Apr'), ('A', 'Aug'), ('A', 'Dec'), ('A', 'Feb'), ('A', 'Jan'), ('A', 'Jul'), ('A', 'Jun'), ('A', 'Mar'), ('A', 'May'), ('A', 'Nov'), ('A', 'Oct'), ('A', 'Sep'), ('B', 'Apr'), ('B', 'Aug'), ('B', 'Dec'), ('B', 'Feb'), ('B', 'Jan'), ('B', 'Jul'), ('B', 'Jun'), ('B', 'Mar'), ('B', 'May'), ('B', 'Nov'), ('B', 'Oct'), ('B', 'Sep'), ('C', 'Apr'), ('C', 'Aug'), ('C', 'Dec'), ('C', 'Feb'), ('C', 'Jan'), ('C', 'Jul'), ('C', 'Jun'), ('C', 'Mar'), ('C', 'May'), ('C', 'Nov'), ('C', 'Oct'), ('C', 'Sep')}
#     demandserviced_index_0 : Size=1, Index=None, Ordered=False
#         Key  : Dimen : Domain : Size : Members
#         None :     1 :    Any :    3 : {'A', 'B', 'C'}
#     demandserviced_index_1 : Size=1, Index=None, Ordered=False
#         Key  : Dimen : Domain : Size : Members
#         None :     1 :    Any :   12 : {'Apr', 'Aug', 'Dec', 'Feb', 'Jan', 'Jul', 'Jun', 'Mar', 'May', 'Nov', 'Oct', 'Sep'}
#     max_outsourced_index : Size=1, Index=None, Ordered=False
#         Key  : Dimen : Domain                                        : Size : Members
#         None :     2 : max_outsourced_index_0*max_outsourced_index_1 :   36 : {('A', 'Apr'), ('A', 'Aug'), ('A', 'Dec'), ('A', 'Feb'), ('A', 'Jan'), ('A', 'Jul'), ('A', 'Jun'), ('A', 'Mar'), ('A', 'May'), ('A', 'Nov'), ('A', 'Oct'), ('A', 'Sep'), ('B', 'Apr'), ('B', 'Aug'), ('B', 'Dec'), ('B', 'Feb'), ('B', 'Jan'), ('B', 'Jul'), ('B', 'Jun'), ('B', 'Mar'), ('B', 'May'), ('B', 'Nov'), ('B', 'Oct'), ('B', 'Sep'), ('C', 'Apr'), ('C', 'Aug'), ('C', 'Dec'), ('C', 'Feb'), ('C', 'Jan'), ('C', 'Jul'), ('C', 'Jun'), ('C', 'Mar'), ('C', 'May'), ('C', 'Nov'), ('C', 'Oct'), ('C', 'Sep')}
#     max_outsourced_index_0 : Size=1, Index=None, Ordered=False
#         Key  : Dimen : Domain : Size : Members
#         None :     1 :    Any :    3 : {'A', 'B', 'C'}
#     max_outsourced_index_1 : Size=1, Index=None, Ordered=False
#         Key  : Dimen : Domain : Size : Members
#         None :     1 :    Any :   12 : {'Apr', 'Aug', 'Dec', 'Feb', 'Jan', 'Jul', 'Jun', 'Mar', 'May', 'Nov', 'Oct', 'Sep'}
#     x_index : Size=1, Index=None, Ordered=False
#         Key  : Dimen : Domain              : Size : Members
#         None :     2 : x_index_0*x_index_1 :   36 : {('A', 'Apr'), ('A', 'Aug'), ('A', 'Dec'), ('A', 'Feb'), ('A', 'Jan'), ('A', 'Jul'), ('A', 'Jun'), ('A', 'Mar'), ('A', 'May'), ('A', 'Nov'), ('A', 'Oct'), ('A', 'Sep'), ('B', 'Apr'), ('B', 'Aug'), ('B', 'Dec'), ('B', 'Feb'), ('B', 'Jan'), ('B', 'Jul'), ('B', 'Jun'), ('B', 'Mar'), ('B', 'May'), ('B', 'Nov'), ('B', 'Oct'), ('B', 'Sep'), ('C', 'Apr'), ('C', 'Aug'), ('C', 'Dec'), ('C', 'Feb'), ('C', 'Jan'), ('C', 'Jul'), ('C', 'Jun'), ('C', 'Mar'), ('C', 'May'), ('C', 'Nov'), ('C', 'Oct'), ('C', 'Sep')}
#     x_index_0 : Size=1, Index=None, Ordered=False
#         Key  : Dimen : Domain : Size : Members
#         None :     1 :    Any :    3 : {'A', 'B', 'C'}
#     x_index_1 : Size=1, Index=None, Ordered=False
#         Key  : Dimen : Domain : Size : Members
#         None :     1 :    Any :   12 : {'Apr', 'Aug', 'Dec', 'Feb', 'Jan', 'Jul', 'Jun', 'Mar', 'May', 'Nov', 'Oct', 'Sep'}
#     y_index : Size=1, Index=None, Ordered=False
#         Key  : Dimen : Domain              : Size : Members
#         None :     2 : y_index_0*y_index_1 :   36 : {('A', 'Apr'), ('A', 'Aug'), ('A', 'Dec'), ('A', 'Feb'), ('A', 'Jan'), ('A', 'Jul'), ('A', 'Jun'), ('A', 'Mar'), ('A', 'May'), ('A', 'Nov'), ('A', 'Oct'), ('A', 'Sep'), ('B', 'Apr'), ('B', 'Aug'), ('B', 'Dec'), ('B', 'Feb'), ('B', 'Jan'), ('B', 'Jul'), ('B', 'Jun'), ('B', 'Mar'), ('B', 'May'), ('B', 'Nov'), ('B', 'Oct'), ('B', 'Sep'), ('C', 'Apr'), ('C', 'Aug'), ('C', 'Dec'), ('C', 'Feb'), ('C', 'Jan'), ('C', 'Jul'), ('C', 'Jun'), ('C', 'Mar'), ('C', 'May'), ('C', 'Nov'), ('C', 'Oct'), ('C', 'Sep')}
#     y_index_0 : Size=1, Index=None, Ordered=False
#         Key  : Dimen : Domain : Size : Members
#         None :     1 :    Any :    3 : {'A', 'B', 'C'}
#     y_index_1 : Size=1, Index=None, Ordered=False
#         Key  : Dimen : Domain : Size : Members
#         None :     1 :    Any :   12 : {'Apr', 'Aug', 'Dec', 'Feb', 'Jan', 'Jul', 'Jun', 'Mar', 'May', 'Nov', 'Oct', 'Sep'}
#
# 2 Var Declarations
#     x : Size=36, Index=x_index
#         Key          : Lower : Value  : Upper : Fixed : Stale : Domain
#         ('A', 'Apr') :     0 : 2297.0 :  None : False : False : Integers
#         ('A', 'Aug') :     0 : 3371.0 :  None : False : False : Integers
#         ('A', 'Dec') :     0 : 3629.0 :  None : False : False : Integers
#         ('A', 'Feb') :     0 : 4878.0 :  None : False : False : Integers
#         ('A', 'Jan') :     0 : 5240.0 :  None : False : False : Integers
#         ('A', 'Jul') :     0 : 3734.0 :  None : False : False : Integers
#         ('A', 'Jun') :     0 : 2275.0 :  None : False : False : Integers
#         ('A', 'Mar') :     0 : 5942.0 :  None : False : False : Integers
#         ('A', 'May') :     0 : 1992.0 :  None : False : False : Integers
#         ('A', 'Nov') :     0 : 2999.0 :  None : False : False : Integers
#         ('A', 'Oct') :     0 : 3529.0 :  None : False : False : Integers
#         ('A', 'Sep') :     0 : 3759.0 :  None : False : False : Integers
#         ('B', 'Apr') :     0 : 2338.0 :  None : False : False : Integers
#         ('B', 'Aug') :     0 : 1572.0 :  None : False : False : Integers
#         ('B', 'Dec') :     0 : 2537.0 :  None : False : False : Integers
#         ('B', 'Feb') :     0 : 1577.0 :  None : False : False : Integers
#         ('B', 'Jan') :     0 : 4927.0 :  None : False : False : Integers
#         ('B', 'Jul') :     0 : 2563.0 :  None : False : False : Integers
#         ('B', 'Jun') :     0 : 1889.0 :  None : False : False : Integers
#         ('B', 'Mar') :     0 : 1785.0 :  None : False : False : Integers
#         ('B', 'May') :     0 : 4020.0 :  None : False : False : Integers
#         ('B', 'Nov') :     0 : 1883.0 :  None : False : False : Integers
#         ('B', 'Oct') :     0 : 2493.0 :  None : False : False : Integers
#         ('B', 'Sep') :     0 : 4517.0 :  None : False : False : Integers
#         ('C', 'Apr') :     0 : 2261.0 :  None : False : False : Integers
#         ('C', 'Aug') :     0 : 2496.0 :  None : False : False : Integers
#         ('C', 'Dec') :     0 :    0.0 :  None : False : False : Integers
#         ('C', 'Feb') :     0 : 1967.0 :  None : False : False : Integers
#         ('C', 'Jan') :     0 : 1162.0 :  None : False : False : Integers
#         ('C', 'Jul') :     0 :    0.0 :  None : False : False : Integers
#         ('C', 'Jun') :     0 : 1642.0 :  None : False : False : Integers
#         ('C', 'Mar') :     0 : 1898.0 :  None : False : False : Integers
#         ('C', 'May') :     0 : 2030.0 :  None : False : False : Integers
#         ('C', 'Nov') :     0 :    0.0 :  None : False : False : Integers
#         ('C', 'Oct') :     0 : 2421.0 :  None : False : False : Integers
#         ('C', 'Sep') :     0 :  922.0 :  None : False : False : Integers
#     y : Size=36, Index=y_index
#         Key          : Lower : Value  : Upper : Fixed : Stale : Domain
#         ('A', 'Apr') :     0 :    0.0 :  None : False : False : Integers
#         ('A', 'Aug') :     0 :    0.0 :  None : False : False : Integers
#         ('A', 'Dec') :     0 : 1554.0 :  None : False : False : Integers
#         ('A', 'Feb') :     0 :    0.0 :  None : False : False : Integers
#         ('A', 'Jan') :     0 :    0.0 :  None : False : False : Integers
#         ('A', 'Jul') :     0 : 1600.0 :  None : False : False : Integers
#         ('A', 'Jun') :     0 :    0.0 :  None : False : False : Integers
#         ('A', 'Mar') :     0 :    0.0 :  None : False : False : Integers
#         ('A', 'May') :     0 :    0.0 :  None : False : False : Integers
#         ('A', 'Nov') :     0 : 1285.0 :  None : False : False : Integers
#         ('A', 'Oct') :     0 :    0.0 :  None : False : False : Integers
#         ('A', 'Sep') :     0 :    0.0 :  None : False : False : Integers
#         ('B', 'Apr') :     0 :    0.0 :  None : False : False : Integers
#         ('B', 'Aug') :     0 : 1048.0 :  None : False : False : Integers
#         ('B', 'Dec') :     0 : 1690.0 :  None : False : False : Integers
#         ('B', 'Feb') :     0 : 1051.0 :  None : False : False : Integers
#         ('B', 'Jan') :     0 :    0.0 :  None : False : False : Integers
#         ('B', 'Jul') :     0 : 1708.0 :  None : False : False : Integers
#         ('B', 'Jun') :     0 : 1258.0 :  None : False : False : Integers
#         ('B', 'Mar') :     0 : 1189.0 :  None : False : False : Integers
#         ('B', 'May') :     0 :    0.0 :  None : False : False : Integers
#         ('B', 'Nov') :     0 : 1254.0 :  None : False : False : Integers
#         ('B', 'Oct') :     0 : 1662.0 :  None : False : False : Integers
#         ('B', 'Sep') :     0 :    0.0 :  None : False : False : Integers
#         ('C', 'Apr') :     0 :    0.0 :  None : False : False : Integers
#         ('C', 'Aug') :     0 :    0.0 :  None : False : False : Integers
#         ('C', 'Dec') :     0 : 1998.0 :  None : False : False : Integers
#         ('C', 'Feb') :     0 :    0.0 :  None : False : False : Integers
#         ('C', 'Jan') :     0 :    0.0 :  None : False : False : Integers
#         ('C', 'Jul') :     0 : 2489.0 :  None : False : False : Integers
#         ('C', 'Jun') :     0 :    0.0 :  None : False : False : Integers
#         ('C', 'Mar') :     0 :    0.0 :  None : False : False : Integers
#         ('C', 'May') :     0 :    0.0 :  None : False : False : Integers
#         ('C', 'Nov') :     0 :  963.0 :  None : False : False : Integers
#         ('C', 'Oct') :     0 :    0.0 :  None : False : False : Integers
#         ('C', 'Sep') :     0 :    0.0 :  None : False : False : Integers
#
# 1 Objective Declarations
#     value : Size=1, Index=None, Active=True
#         Key  : Active : Sense    : Expression
#         None :   True : minimize : 154.320987654321*x[A,Jan] + 180*y[A,Jan] + 164.4736842105263*x[A,Feb] + 180*y[A,Feb] + 166.66666666666666*x[A,Mar] + 180*y[A,Mar] + 156.25*x[A,Apr] + 180*y[A,Apr] + 160.25641025641025*x[A,May] + 180*y[A,May] + 171.23287671232876*x[A,Jun] + 180*y[A,Jun] + 183.8235294117647*x[A,Jul] + 180*y[A,Jul] + 164.4736842105263*x[A,Aug] + 180*y[A,Aug] + 154.320987654321*x[A,Sep] + 180*y[A,Sep] + 171.23287671232876*x[A,Oct] + 180*y[A,Oct] + 183.8235294117647*x[A,Nov] + 180*y[A,Nov] + 192.3076923076923*x[A,Dec] + 180*y[A,Dec] + 141.46090534979422*x[B,Jan] + 150*y[B,Jan] + 150.76754385964912*x[B,Feb] + 150*y[B,Feb] + 152.77777777777777*x[B,Mar] + 150*y[B,Mar] + 143.22916666666666*x[B,Apr] + 150*y[B,Apr] + 146.90170940170938*x[B,May] + 150*y[B,May] + 156.9634703196347*x[B,Jun] + 150*y[B,Jun] + 168.50490196078428*x[B,Jul] + 150*y[B,Jul] + 150.76754385964912*x[B,Aug] + 150*y[B,Aug] + 141.46090534979422*x[B,Sep] + 150*y[B,Sep] + 156.9634703196347*x[B,Oct] + 150*y[B,Oct] + 168.50490196078428*x[B,Nov] + 150*y[B,Nov] + 176.28205128205127*x[B,Dec] + 150*y[B,Dec] + 136.31687242798353*x[C,Jan] + 160*y[C,Jan] + 145.28508771929825*x[C,Feb] + 160*y[C,Feb] + 147.22222222222223*x[C,Mar] + 160*y[C,Mar] + 138.02083333333334*x[C,Apr] + 160*y[C,Apr] + 141.55982905982907*x[C,May] + 160*y[C,May] + 151.25570776255708*x[C,Jun] + 160*y[C,Jun] + 162.37745098039215*x[C,Jul] + 160*y[C,Jul] + 145.28508771929825*x[C,Aug] + 160*y[C,Aug] + 136.31687242798353*x[C,Sep] + 160*y[C,Sep] + 151.25570776255708*x[C,Oct] + 160*y[C,Oct] + 162.37745098039215*x[C,Nov] + 160*y[C,Nov] + 169.87179487179486*x[C,Dec] + 160*y[C,Dec]
#
# 2 Constraint Declarations
#     demandserviced : Size=36, Index=demandserviced_index, Active=True
#         Key          : Lower  : Body                : Upper  : Active
#         ('A', 'Apr') : 2297.0 : x[A,Apr] + y[A,Apr] : 2297.0 :   True
#         ('A', 'Aug') : 3371.0 : x[A,Aug] + y[A,Aug] : 3371.0 :   True
#         ('A', 'Dec') : 5183.0 : x[A,Dec] + y[A,Dec] : 5183.0 :   True
#         ('A', 'Feb') : 4878.0 : x[A,Feb] + y[A,Feb] : 4878.0 :   True
#         ('A', 'Jan') : 5240.0 : x[A,Jan] + y[A,Jan] : 5240.0 :   True
#         ('A', 'Jul') : 5334.0 : x[A,Jul] + y[A,Jul] : 5334.0 :   True
#         ('A', 'Jun') : 2275.0 : x[A,Jun] + y[A,Jun] : 2275.0 :   True
#         ('A', 'Mar') : 5942.0 : x[A,Mar] + y[A,Mar] : 5942.0 :   True
#         ('A', 'May') : 1992.0 : x[A,May] + y[A,May] : 1992.0 :   True
#         ('A', 'Nov') : 4284.0 : x[A,Nov] + y[A,Nov] : 4284.0 :   True
#         ('A', 'Oct') : 3529.0 : x[A,Oct] + y[A,Oct] : 3529.0 :   True
#         ('A', 'Sep') : 3759.0 : x[A,Sep] + y[A,Sep] : 3759.0 :   True
#         ('B', 'Apr') : 2338.0 : x[B,Apr] + y[B,Apr] : 2338.0 :   True
#         ('B', 'Aug') : 2620.0 : x[B,Aug] + y[B,Aug] : 2620.0 :   True
#         ('B', 'Dec') : 4227.0 : x[B,Dec] + y[B,Dec] : 4227.0 :   True
#         ('B', 'Feb') : 2628.0 : x[B,Feb] + y[B,Feb] : 2628.0 :   True
#         ('B', 'Jan') : 4927.0 : x[B,Jan] + y[B,Jan] : 4927.0 :   True
#         ('B', 'Jul') : 4271.0 : x[B,Jul] + y[B,Jul] : 4271.0 :   True
#         ('B', 'Jun') : 3147.0 : x[B,Jun] + y[B,Jun] : 3147.0 :   True
#         ('B', 'Mar') : 2974.0 : x[B,Mar] + y[B,Mar] : 2974.0 :   True
#         ('B', 'May') : 4020.0 : x[B,May] + y[B,May] : 4020.0 :   True
#         ('B', 'Nov') : 3137.0 : x[B,Nov] + y[B,Nov] : 3137.0 :   True
#         ('B', 'Oct') : 4155.0 : x[B,Oct] + y[B,Oct] : 4155.0 :   True
#         ('B', 'Sep') : 4517.0 : x[B,Sep] + y[B,Sep] : 4517.0 :   True
#         ('C', 'Apr') : 2261.0 : x[C,Apr] + y[C,Apr] : 2261.0 :   True
#         ('C', 'Aug') : 2496.0 : x[C,Aug] + y[C,Aug] : 2496.0 :   True
#         ('C', 'Dec') : 1998.0 : x[C,Dec] + y[C,Dec] : 1998.0 :   True
#         ('C', 'Feb') : 1967.0 : x[C,Feb] + y[C,Feb] : 1967.0 :   True
#         ('C', 'Jan') : 1162.0 : x[C,Jan] + y[C,Jan] : 1162.0 :   True
#         ('C', 'Jul') : 2489.0 : x[C,Jul] + y[C,Jul] : 2489.0 :   True
#         ('C', 'Jun') : 1642.0 : x[C,Jun] + y[C,Jun] : 1642.0 :   True
#         ('C', 'Mar') : 1898.0 : x[C,Mar] + y[C,Mar] : 1898.0 :   True
#         ('C', 'May') : 2030.0 : x[C,May] + y[C,May] : 2030.0 :   True
#         ('C', 'Nov') :  963.0 : x[C,Nov] + y[C,Nov] :  963.0 :   True
#         ('C', 'Oct') : 2421.0 : x[C,Oct] + y[C,Oct] : 2421.0 :   True
#         ('C', 'Sep') :  922.0 : x[C,Sep] + y[C,Sep] :  922.0 :   True
#     max_outsourced : Size=36, Index=max_outsourced_index, Active=True
#         Key          : Lower : Body                            : Upper : Active
#         ('A', 'Apr') :  -Inf : 0.00043535045711797995*y[A,Apr] :   0.3 :   True
#         ('A', 'Aug') :  -Inf :  0.0002966478789676654*y[A,Aug] :   0.3 :   True
#         ('A', 'Dec') :  -Inf : 0.00019293845263360988*y[A,Dec] :   0.3 :   True
#         ('A', 'Feb') :  -Inf :  0.0002050020500205002*y[A,Feb] :   0.3 :   True
#         ('A', 'Jan') :  -Inf : 0.00019083969465648855*y[A,Jan] :   0.3 :   True
#         ('A', 'Jul') :  -Inf : 0.00018747656542932134*y[A,Jul] :   0.3 :   True
#         ('A', 'Jun') :  -Inf : 0.00043956043956043956*y[A,Jun] :   0.3 :   True
#         ('A', 'Mar') :  -Inf :  0.0001682935038707506*y[A,Mar] :   0.3 :   True
#         ('A', 'May') :  -Inf :   0.000502008032128514*y[A,May] :   0.3 :   True
#         ('A', 'Nov') :  -Inf : 0.00023342670401493932*y[A,Nov] :   0.3 :   True
#         ('A', 'Oct') :  -Inf : 0.00028336639274582036*y[A,Oct] :   0.3 :   True
#         ('A', 'Sep') :  -Inf : 0.00026602819898909286*y[A,Sep] :   0.3 :   True
#         ('B', 'Apr') :  -Inf :   0.000427715996578272*y[B,Apr] :   0.4 :   True
#         ('B', 'Aug') :  -Inf :  0.0003816793893129771*y[B,Aug] :   0.4 :   True
#         ('B', 'Dec') :  -Inf :  0.0002365744026496333*y[B,Dec] :   0.4 :   True
#         ('B', 'Feb') :  -Inf :   0.000380517503805175*y[B,Feb] :   0.4 :   True
#         ('B', 'Jan') :  -Inf : 0.00020296326364927948*y[B,Jan] :   0.4 :   True
#         ('B', 'Jul') :  -Inf : 0.00023413720440177945*y[B,Jul] :   0.4 :   True
#         ('B', 'Jun') :  -Inf : 0.00031776294884016526*y[B,Jun] :   0.4 :   True
#         ('B', 'Mar') :  -Inf :  0.0003362474781439139*y[B,Mar] :   0.4 :   True
#         ('B', 'May') :  -Inf :  0.0002487562189054726*y[B,May] :   0.4 :   True
#         ('B', 'Nov') :  -Inf :   0.000318775900541919*y[B,Nov] :   0.4 :   True
#         ('B', 'Oct') :  -Inf : 0.00024067388688327315*y[B,Oct] :   0.4 :   True
#         ('B', 'Sep') :  -Inf : 0.00022138587558113792*y[B,Sep] :   0.4 :   True
#         ('C', 'Apr') :  -Inf :  0.0004422821760283061*y[C,Apr] :   1.0 :   True
#         ('C', 'Aug') :  -Inf : 0.00040064102564102563*y[C,Aug] :   1.0 :   True
#         ('C', 'Dec') :  -Inf :  0.0005005005005005005*y[C,Dec] :   1.0 :   True
#         ('C', 'Feb') :  -Inf :  0.0005083884087442806*y[C,Feb] :   1.0 :   True
#         ('C', 'Jan') :  -Inf :  0.0008605851979345956*y[C,Jan] :   1.0 :   True
#         ('C', 'Jul') :  -Inf :  0.0004017677782241864*y[C,Jul] :   1.0 :   True
#         ('C', 'Jun') :  -Inf :  0.0006090133982947625*y[C,Jun] :   1.0 :   True
#         ('C', 'Mar') :  -Inf :  0.0005268703898840885*y[C,Mar] :   1.0 :   True
#         ('C', 'May') :  -Inf :  0.0004926108374384236*y[C,May] :   1.0 :   True
#         ('C', 'Nov') :  -Inf :  0.0010384215991692627*y[C,Nov] :   1.0 :   True
#         ('C', 'Oct') :  -Inf :  0.0004130524576621231*y[C,Oct] :   1.0 :   True
#         ('C', 'Sep') :  -Inf :  0.0010845986984815619*y[C,Sep] :   1.0 :   True
#
# 17 Declarations: x_index_0 x_index_1 x_index x y_index_0 y_index_1 y_index y value max_outsourced_index_0 max_outsourced_index_1 max_outsourced_index max_outsourced demandserviced_index_0 demandserviced_index_1 demandserviced_index demandserviced

# %%
# Print the value of the objective function
model.value()
# Out:
# 17962336.44876988

# %% [markdown]
# **`Checkpoint 1:`** Seems like the company has to spend around 17.9 m$ in total for the application approval process.

# %%
# Creating dataframe for the results

#Creating an empty list
output2 = []

# For every iteration, the code below will create a list containing 6 values - 
# 1. count of applications managed by own staff (OwnStaff)
# 2. count of application managed by outsourced vendor (Outsourced)
# 3. demand (Demand) for each state for each month
# 4. number of FTE (own staff required)
# 5. percentage of application outosurced (PercentOutsourced)
# 6. cost of application processing (Processing Cost)

for s in state:
    for m in month:
        
        #Demand for each state for each month
        Dem=Demand[s,m]
       
        #count of applications managed by own staff (OwnStaff)
        OwnStaff=model.x[s,m].value
        
        #count of applications managed by outsourced vendor (Outsourced)
        Outsourced=model.y[s,m].value
        
        #Number of FTE
        FTE=round(model.x[s,m].value /FTE_MgAppServed/StaffAvPer[s,m],2)
        
        #percentage of application own staff 
        PercentOwnStaff=round(model.x[s,m].value / Demand[s,m]*100,2)
        
        #percentage of application outosurced (PercentOutsourced)
        PercentOutsourced=round(model.y[s,m].value / Demand[s,m]*100,2)
        
        
        #cost of application processing (Total Cost)
        ProcessingCost=round((model.x[s,m].value*FTE_Salary[s,m]/FTE_MgAppServed/StaffAvPer[s,m])\
                        +(model.y[s,m].value*outsourcecost[s,m]),2)
                
        output2.append([s,m,Dem,OwnStaff,Outsourced,FTE, PercentOwnStaff, PercentOutsourced,round(ProcessingCost,2)])
        
output2 = pd.DataFrame(output2,columns=['State','Month','Demand','OwnStaff','Outsourced','FTE',\
                                        'PercentOwnStaff','PercentOutsourced','BaseProcesingCost'])
output2
# Out:
#    State Month  Demand  OwnStaff  Outsourced     FTE  PercentOwnStaff  \
# 0      A   Jan    5240    5240.0         0.0  161.73           100.00
# 1      A   Feb    4878    4878.0         0.0  160.46           100.00
# 2      A   Mar    5942    5942.0         0.0  198.07           100.00
# 3      A   Apr    2297    2297.0         0.0   71.78           100.00
# 4      A   May    1992    1992.0         0.0   63.85           100.00
# 5      A   Jun    2275    2275.0         0.0   77.91           100.00
# 6      A   Jul    5334    3734.0      1600.0  137.28            70.00
# 7      A   Aug    3371    3371.0         0.0  110.89           100.00
# 8      A   Sep    3759    3759.0         0.0  116.02           100.00
# 9      A   Oct    3529    3529.0         0.0  120.86           100.00
# 10     A   Nov    4284    2999.0      1285.0  110.26            70.00
# 11     A   Dec    5183    3629.0      1554.0  139.58            70.02
# 12     B   Jan    4927    4927.0         0.0  152.07           100.00
# 13     B   Feb    2628    1577.0      1051.0   51.87            60.01
# 14     B   Mar    2974    1785.0      1189.0   59.50            60.02
# 15     B   Apr    2338    2338.0         0.0   73.06           100.00
# 16     B   May    4020    4020.0         0.0  128.85           100.00
# 17     B   Jun    3147    1889.0      1258.0   64.69            60.03
# 18     B   Jul    4271    2563.0      1708.0   94.23            60.01
# 19     B   Aug    2620    1572.0      1048.0   51.71            60.00
# 20     B   Sep    4517    4517.0         0.0  139.41           100.00
# 21     B   Oct    4155    2493.0      1662.0   85.38            60.00
# 22     B   Nov    3137    1883.0      1254.0   69.23            60.03
# 23     B   Dec    4227    2537.0      1690.0   97.58            60.02
# 24     C   Jan    1162    1162.0         0.0   35.86           100.00
# 25     C   Feb    1967    1967.0         0.0   64.70           100.00
# 26     C   Mar    1898    1898.0         0.0   63.27           100.00
# 27     C   Apr    2261    2261.0         0.0   70.66           100.00
# 28     C   May    2030    2030.0         0.0   65.06           100.00
# 29     C   Jun    1642    1642.0         0.0   56.23           100.00
# 30     C   Jul    2489       0.0      2489.0    0.00             0.00
# 31     C   Aug    2496    2496.0         0.0   82.11           100.00
# 32     C   Sep     922     922.0         0.0   28.46           100.00
# 33     C   Oct    2421    2421.0         0.0   82.91           100.00
# 34     C   Nov     963       0.0       963.0    0.00             0.00
# 35     C   Dec    1998       0.0      1998.0    0.00             0.00
#
#     PercentOutsourced  BaseProcesingCost
# 0                0.00          808641.98
# 1                0.00          802302.63
# 2                0.00          990333.33
# 3                0.00          358906.25
# 4                0.00          319230.77
# 5                0.00          389554.79
# 6               30.00          974397.06
# 7                0.00          554440.79
# 8                0.00          580092.59
# 9                0.00          604280.82
# 10              30.00          782586.76
# 11              29.98          977604.62
# 12               0.00          696977.88
# 13              39.99          395410.42
# 14              39.98          451058.33
# 15               0.00          334869.79
# 16               0.00          590544.87
# 17              39.97          485204.00
# 18              39.99          688078.06
# 19              40.00          394206.58
# 20               0.00          638978.91
# 21              40.00          640609.93
# 22              39.97          505394.73
# 23              39.98          700727.56
# 24               0.00          158400.21
# 25               0.00          285775.77
# 26               0.00          279427.78
# 27               0.00          312065.10
# 28               0.00          287366.45
# 29               0.00          248361.87
# 30             100.00          398240.00
# 31               0.00          362631.58
# 32               0.00          125684.16
# 33               0.00          366190.07
# 34             100.00          154080.00
# 35             100.00          319680.00

# %%
#calcualting Total Processing cost
print(round(sum(output2['BaseProcesingCost'])/1000000,2), "millions")
# Out:
# 17.96 millions

# %%
# Its $ 17.96 million

# %%
print(round((sum(output2['BaseProcesingCost']))/sum(output2['Demand']),2), \
      " processing cost per application")
# Out:
# 158.55  processing cost per application

# %%
# Writing the results in to an Excel sheet

# Importing the required library
from openpyxl import load_workbook

book = load_workbook("C:\\Users\\dell\\Desktop\\Optimisation Case Study - Staff Planning\\Staffing+Data.xlsx")

# create excel writer object
writer = pd.ExcelWriter("C:\\Users\\dell\\Desktop\\Optimisation Case Study - Staff Planning\\Staffing+Data.xlsx", engine = 'openpyxl')

#Assigning the workbook to the writer object
writer.book = book

# write dataframe to excel sheet named 'Staffing+Data'
output2.to_excel(writer, sheet_name='Question 2')

# save the excel file
writer.save()
print('DataFrame is loaded successfully to Excel Sheet.')
# Out:
# DataFrame is loaded successfully to Excel Sheet.

# %% [markdown]
# # Question 3
#
# #### Expected Scenarios
#
# The company wants to get a solution for the scenario, where no more than 10% of the total applications for every month in each state is handled by the external resources, for quality assurance reasons
#
# - **`Q 3.1-`** What is the additional average cost per application of keeping the 10% limit on outsourcing?
# Note: Compare with the cost in question 2
#
# - **`Q 3.2-`** If the company increases the outsourcing costs by 20% to reflect the cost of quality assurance, what would you recommend the optimal percent of outsourcing should be?

# %% [markdown]
# #### Expected output:
# `Subtask 3.1-` Create a data frame containing the number of outsourced applications and the number of FTEs for each state-month combination. You can choose to have extra columns like staff availability, demand etc. in your dataframe apart from the ones mentioned earlier. Also, print the additional average cost per application.
#
# `Subtask 3.2-` Create a data frame containing the number of outsourced applications and the number of FTEs for each state-month combination. You can choose to have extra columns like staff availability, demand etc. in your dataframe apart from the ones mentioned earlier. Also, print the additional average cost per application. Also, print the overall average optimal per cent of outsourcing.

# %% [markdown]
# ### 3.1 Additional cost per application of keeping the 10% limit on outsourcing

# %%
# Creating a model instance
model = ConcreteModel()

# %%
# Define Pyomo sets and Parameters

#only change will be to quality related contraints rather than regulation

#Quality requirement on maximum outsourcing 
quality_scenario1 ={'A':0.1, 'B':0.1, 'C':0.1}
print('\n Quality reasons percent of Outsource allowed : ', quality_scenario1)
# Out:
#  Quality reasons percent of Outsource allowed :  {'A': 0.1, 'B': 0.1, 'C': 0.1}

# %%
# Decision variables

#Number of applications managed by Staff or own employee
model.x = Var(state, month, within=Integers, bounds=(0,None))

#Number of applications managed by Outsourced Vendor
model.y = Var(state, month, within=Integers, bounds=(0,None))

# %%
# Constraints

#Quality requirement of maximum percentage of applications that can be outsourced - Scenario 1
def max_outsourced_perstate_permonth(model,s,m):
    return (model.y[s,m]/Demand[s,m]) <= quality_scenario1[s]
                   
model.max_outsourced = Constraint(state, month, rule=max_outsourced_perstate_permonth)

# %%
# Constraints
#entire demand should be serviced

def demand_serviced(model,s,m):
    return (model.x[s,m]+ model.y[s,m]) == Demand[s,m]
                   
model.demandserviced = Constraint(state, month, rule=demand_serviced)

# %%
# Objective function

# Defining the objective rule

#Total processing cost = Salary cost for inhouse processed applications + processing cost for outsourced applications
#outsourcing cost is equal to outsourced applications count (Y) mutplied by outsourcing cost per application
#salary cost is decision variable (X)  * employee salary adjusted for servicerate and availability rate

def obj_rule(model):
    
    return sum(((model.x[s,m]*FTE_Salary[s,m]/FTE_MgAppServed/StaffAvPer[s,m])
               +(model.y[s,m])*outsourcecost[s,m])
                for s in state for m in month)

# Minimize the total cost for the application approval process
model.value = Objective(rule=obj_rule, sense= minimize)

# %%
# Invoking the solver

result = SolverFactory('glpk').solve(model)
result.write()
# Out:
# # ==========================================================
# # = Solver Results                                         =
# # ==========================================================
# # ----------------------------------------------------------
# #   Problem Information
# # ----------------------------------------------------------
# Problem:
# - Name: unknown
#   Lower bound: 18100979.3212198
#   Upper bound: 18100979.3212198
#   Number of objectives: 1
#   Number of constraints: 73
#   Number of variables: 73
#   Number of nonzeros: 109
#   Sense: minimize
# # ----------------------------------------------------------
# #   Solver Information
# # ----------------------------------------------------------
# Solver:
# - Status: ok
#   Termination condition: optimal
#   Statistics:
#     Branch and bound:
#       Number of bounded subproblems: 1
#       Number of created subproblems: 1
#   Error rc: 0
#   Time: 0.14062213897705078
# # ----------------------------------------------------------
# #   Solution Information
# # ----------------------------------------------------------
# Solution:
# - number of solutions: 0
#   number of solutions displayed: 0

# %%
# Model parameters after optimization
model.pprint()
# Out:
# 12 Set Declarations
#     demandserviced_index : Size=1, Index=None, Ordered=False
#         Key  : Dimen : Domain                                        : Size : Members
#         None :     2 : demandserviced_index_0*demandserviced_index_1 :   36 : {('A', 'Apr'), ('A', 'Aug'), ('A', 'Dec'), ('A', 'Feb'), ('A', 'Jan'), ('A', 'Jul'), ('A', 'Jun'), ('A', 'Mar'), ('A', 'May'), ('A', 'Nov'), ('A', 'Oct'), ('A', 'Sep'), ('B', 'Apr'), ('B', 'Aug'), ('B', 'Dec'), ('B', 'Feb'), ('B', 'Jan'), ('B', 'Jul'), ('B', 'Jun'), ('B', 'Mar'), ('B', 'May'), ('B', 'Nov'), ('B', 'Oct'), ('B', 'Sep'), ('C', 'Apr'), ('C', 'Aug'), ('C', 'Dec'), ('C', 'Feb'), ('C', 'Jan'), ('C', 'Jul'), ('C', 'Jun'), ('C', 'Mar'), ('C', 'May'), ('C', 'Nov'), ('C', 'Oct'), ('C', 'Sep')}
#     demandserviced_index_0 : Size=1, Index=None, Ordered=False
#         Key  : Dimen : Domain : Size : Members
#         None :     1 :    Any :    3 : {'A', 'B', 'C'}
#     demandserviced_index_1 : Size=1, Index=None, Ordered=False
#         Key  : Dimen : Domain : Size : Members
#         None :     1 :    Any :   12 : {'Apr', 'Aug', 'Dec', 'Feb', 'Jan', 'Jul', 'Jun', 'Mar', 'May', 'Nov', 'Oct', 'Sep'}
#     max_outsourced_index : Size=1, Index=None, Ordered=False
#         Key  : Dimen : Domain                                        : Size : Members
#         None :     2 : max_outsourced_index_0*max_outsourced_index_1 :   36 : {('A', 'Apr'), ('A', 'Aug'), ('A', 'Dec'), ('A', 'Feb'), ('A', 'Jan'), ('A', 'Jul'), ('A', 'Jun'), ('A', 'Mar'), ('A', 'May'), ('A', 'Nov'), ('A', 'Oct'), ('A', 'Sep'), ('B', 'Apr'), ('B', 'Aug'), ('B', 'Dec'), ('B', 'Feb'), ('B', 'Jan'), ('B', 'Jul'), ('B', 'Jun'), ('B', 'Mar'), ('B', 'May'), ('B', 'Nov'), ('B', 'Oct'), ('B', 'Sep'), ('C', 'Apr'), ('C', 'Aug'), ('C', 'Dec'), ('C', 'Feb'), ('C', 'Jan'), ('C', 'Jul'), ('C', 'Jun'), ('C', 'Mar'), ('C', 'May'), ('C', 'Nov'), ('C', 'Oct'), ('C', 'Sep')}
#     max_outsourced_index_0 : Size=1, Index=None, Ordered=False
#         Key  : Dimen : Domain : Size : Members
#         None :     1 :    Any :    3 : {'A', 'B', 'C'}
#     max_outsourced_index_1 : Size=1, Index=None, Ordered=False
#         Key  : Dimen : Domain : Size : Members
#         None :     1 :    Any :   12 : {'Apr', 'Aug', 'Dec', 'Feb', 'Jan', 'Jul', 'Jun', 'Mar', 'May', 'Nov', 'Oct', 'Sep'}
#     x_index : Size=1, Index=None, Ordered=False
#         Key  : Dimen : Domain              : Size : Members
#         None :     2 : x_index_0*x_index_1 :   36 : {('A', 'Apr'), ('A', 'Aug'), ('A', 'Dec'), ('A', 'Feb'), ('A', 'Jan'), ('A', 'Jul'), ('A', 'Jun'), ('A', 'Mar'), ('A', 'May'), ('A', 'Nov'), ('A', 'Oct'), ('A', 'Sep'), ('B', 'Apr'), ('B', 'Aug'), ('B', 'Dec'), ('B', 'Feb'), ('B', 'Jan'), ('B', 'Jul'), ('B', 'Jun'), ('B', 'Mar'), ('B', 'May'), ('B', 'Nov'), ('B', 'Oct'), ('B', 'Sep'), ('C', 'Apr'), ('C', 'Aug'), ('C', 'Dec'), ('C', 'Feb'), ('C', 'Jan'), ('C', 'Jul'), ('C', 'Jun'), ('C', 'Mar'), ('C', 'May'), ('C', 'Nov'), ('C', 'Oct'), ('C', 'Sep')}
#     x_index_0 : Size=1, Index=None, Ordered=False
#         Key  : Dimen : Domain : Size : Members
#         None :     1 :    Any :    3 : {'A', 'B', 'C'}
#     x_index_1 : Size=1, Index=None, Ordered=False
#         Key  : Dimen : Domain : Size : Members
#         None :     1 :    Any :   12 : {'Apr', 'Aug', 'Dec', 'Feb', 'Jan', 'Jul', 'Jun', 'Mar', 'May', 'Nov', 'Oct', 'Sep'}
#     y_index : Size=1, Index=None, Ordered=False
#         Key  : Dimen : Domain              : Size : Members
#         None :     2 : y_index_0*y_index_1 :   36 : {('A', 'Apr'), ('A', 'Aug'), ('A', 'Dec'), ('A', 'Feb'), ('A', 'Jan'), ('A', 'Jul'), ('A', 'Jun'), ('A', 'Mar'), ('A', 'May'), ('A', 'Nov'), ('A', 'Oct'), ('A', 'Sep'), ('B', 'Apr'), ('B', 'Aug'), ('B', 'Dec'), ('B', 'Feb'), ('B', 'Jan'), ('B', 'Jul'), ('B', 'Jun'), ('B', 'Mar'), ('B', 'May'), ('B', 'Nov'), ('B', 'Oct'), ('B', 'Sep'), ('C', 'Apr'), ('C', 'Aug'), ('C', 'Dec'), ('C', 'Feb'), ('C', 'Jan'), ('C', 'Jul'), ('C', 'Jun'), ('C', 'Mar'), ('C', 'May'), ('C', 'Nov'), ('C', 'Oct'), ('C', 'Sep')}
#     y_index_0 : Size=1, Index=None, Ordered=False
#         Key  : Dimen : Domain : Size : Members
#         None :     1 :    Any :    3 : {'A', 'B', 'C'}
#     y_index_1 : Size=1, Index=None, Ordered=False
#         Key  : Dimen : Domain : Size : Members
#         None :     1 :    Any :   12 : {'Apr', 'Aug', 'Dec', 'Feb', 'Jan', 'Jul', 'Jun', 'Mar', 'May', 'Nov', 'Oct', 'Sep'}
#
# 2 Var Declarations
#     x : Size=36, Index=x_index
#         Key          : Lower : Value  : Upper : Fixed : Stale : Domain
#         ('A', 'Apr') :     0 : 2297.0 :  None : False : False : Integers
#         ('A', 'Aug') :     0 : 3371.0 :  None : False : False : Integers
#         ('A', 'Dec') :     0 : 4665.0 :  None : False : False : Integers
#         ('A', 'Feb') :     0 : 4878.0 :  None : False : False : Integers
#         ('A', 'Jan') :     0 : 5240.0 :  None : False : False : Integers
#         ('A', 'Jul') :     0 : 4801.0 :  None : False : False : Integers
#         ('A', 'Jun') :     0 : 2275.0 :  None : False : False : Integers
#         ('A', 'Mar') :     0 : 5942.0 :  None : False : False : Integers
#         ('A', 'May') :     0 : 1992.0 :  None : False : False : Integers
#         ('A', 'Nov') :     0 : 3856.0 :  None : False : False : Integers
#         ('A', 'Oct') :     0 : 3529.0 :  None : False : False : Integers
#         ('A', 'Sep') :     0 : 3759.0 :  None : False : False : Integers
#         ('B', 'Apr') :     0 : 2338.0 :  None : False : False : Integers
#         ('B', 'Aug') :     0 : 2358.0 :  None : False : False : Integers
#         ('B', 'Dec') :     0 : 3805.0 :  None : False : False : Integers
#         ('B', 'Feb') :     0 : 2366.0 :  None : False : False : Integers
#         ('B', 'Jan') :     0 : 4927.0 :  None : False : False : Integers
#         ('B', 'Jul') :     0 : 3844.0 :  None : False : False : Integers
#         ('B', 'Jun') :     0 : 2833.0 :  None : False : False : Integers
#         ('B', 'Mar') :     0 : 2677.0 :  None : False : False : Integers
#         ('B', 'May') :     0 : 4020.0 :  None : False : False : Integers
#         ('B', 'Nov') :     0 : 2824.0 :  None : False : False : Integers
#         ('B', 'Oct') :     0 : 3740.0 :  None : False : False : Integers
#         ('B', 'Sep') :     0 : 4517.0 :  None : False : False : Integers
#         ('C', 'Apr') :     0 : 2261.0 :  None : False : False : Integers
#         ('C', 'Aug') :     0 : 2496.0 :  None : False : False : Integers
#         ('C', 'Dec') :     0 : 1799.0 :  None : False : False : Integers
#         ('C', 'Feb') :     0 : 1967.0 :  None : False : False : Integers
#         ('C', 'Jan') :     0 : 1162.0 :  None : False : False : Integers
#         ('C', 'Jul') :     0 : 2241.0 :  None : False : False : Integers
#         ('C', 'Jun') :     0 : 1642.0 :  None : False : False : Integers
#         ('C', 'Mar') :     0 : 1898.0 :  None : False : False : Integers
#         ('C', 'May') :     0 : 2030.0 :  None : False : False : Integers
#         ('C', 'Nov') :     0 :  867.0 :  None : False : False : Integers
#         ('C', 'Oct') :     0 : 2421.0 :  None : False : False : Integers
#         ('C', 'Sep') :     0 :  922.0 :  None : False : False : Integers
#     y : Size=36, Index=y_index
#         Key          : Lower : Value : Upper : Fixed : Stale : Domain
#         ('A', 'Apr') :     0 :   0.0 :  None : False : False : Integers
#         ('A', 'Aug') :     0 :   0.0 :  None : False : False : Integers
#         ('A', 'Dec') :     0 : 518.0 :  None : False : False : Integers
#         ('A', 'Feb') :     0 :   0.0 :  None : False : False : Integers
#         ('A', 'Jan') :     0 :   0.0 :  None : False : False : Integers
#         ('A', 'Jul') :     0 : 533.0 :  None : False : False : Integers
#         ('A', 'Jun') :     0 :   0.0 :  None : False : False : Integers
#         ('A', 'Mar') :     0 :   0.0 :  None : False : False : Integers
#         ('A', 'May') :     0 :   0.0 :  None : False : False : Integers
#         ('A', 'Nov') :     0 : 428.0 :  None : False : False : Integers
#         ('A', 'Oct') :     0 :   0.0 :  None : False : False : Integers
#         ('A', 'Sep') :     0 :   0.0 :  None : False : False : Integers
#         ('B', 'Apr') :     0 :   0.0 :  None : False : False : Integers
#         ('B', 'Aug') :     0 : 262.0 :  None : False : False : Integers
#         ('B', 'Dec') :     0 : 422.0 :  None : False : False : Integers
#         ('B', 'Feb') :     0 : 262.0 :  None : False : False : Integers
#         ('B', 'Jan') :     0 :   0.0 :  None : False : False : Integers
#         ('B', 'Jul') :     0 : 427.0 :  None : False : False : Integers
#         ('B', 'Jun') :     0 : 314.0 :  None : False : False : Integers
#         ('B', 'Mar') :     0 : 297.0 :  None : False : False : Integers
#         ('B', 'May') :     0 :   0.0 :  None : False : False : Integers
#         ('B', 'Nov') :     0 : 313.0 :  None : False : False : Integers
#         ('B', 'Oct') :     0 : 415.0 :  None : False : False : Integers
#         ('B', 'Sep') :     0 :   0.0 :  None : False : False : Integers
#         ('C', 'Apr') :     0 :   0.0 :  None : False : False : Integers
#         ('C', 'Aug') :     0 :   0.0 :  None : False : False : Integers
#         ('C', 'Dec') :     0 : 199.0 :  None : False : False : Integers
#         ('C', 'Feb') :     0 :   0.0 :  None : False : False : Integers
#         ('C', 'Jan') :     0 :   0.0 :  None : False : False : Integers
#         ('C', 'Jul') :     0 : 248.0 :  None : False : False : Integers
#         ('C', 'Jun') :     0 :   0.0 :  None : False : False : Integers
#         ('C', 'Mar') :     0 :   0.0 :  None : False : False : Integers
#         ('C', 'May') :     0 :   0.0 :  None : False : False : Integers
#         ('C', 'Nov') :     0 :  96.0 :  None : False : False : Integers
#         ('C', 'Oct') :     0 :   0.0 :  None : False : False : Integers
#         ('C', 'Sep') :     0 :   0.0 :  None : False : False : Integers
#
# 1 Objective Declarations
#     value : Size=1, Index=None, Active=True
#         Key  : Active : Sense    : Expression
#         None :   True : minimize : 154.320987654321*x[A,Jan] + 180*y[A,Jan] + 164.4736842105263*x[A,Feb] + 180*y[A,Feb] + 166.66666666666666*x[A,Mar] + 180*y[A,Mar] + 156.25*x[A,Apr] + 180*y[A,Apr] + 160.25641025641025*x[A,May] + 180*y[A,May] + 171.23287671232876*x[A,Jun] + 180*y[A,Jun] + 183.8235294117647*x[A,Jul] + 180*y[A,Jul] + 164.4736842105263*x[A,Aug] + 180*y[A,Aug] + 154.320987654321*x[A,Sep] + 180*y[A,Sep] + 171.23287671232876*x[A,Oct] + 180*y[A,Oct] + 183.8235294117647*x[A,Nov] + 180*y[A,Nov] + 192.3076923076923*x[A,Dec] + 180*y[A,Dec] + 141.46090534979422*x[B,Jan] + 150*y[B,Jan] + 150.76754385964912*x[B,Feb] + 150*y[B,Feb] + 152.77777777777777*x[B,Mar] + 150*y[B,Mar] + 143.22916666666666*x[B,Apr] + 150*y[B,Apr] + 146.90170940170938*x[B,May] + 150*y[B,May] + 156.9634703196347*x[B,Jun] + 150*y[B,Jun] + 168.50490196078428*x[B,Jul] + 150*y[B,Jul] + 150.76754385964912*x[B,Aug] + 150*y[B,Aug] + 141.46090534979422*x[B,Sep] + 150*y[B,Sep] + 156.9634703196347*x[B,Oct] + 150*y[B,Oct] + 168.50490196078428*x[B,Nov] + 150*y[B,Nov] + 176.28205128205127*x[B,Dec] + 150*y[B,Dec] + 136.31687242798353*x[C,Jan] + 160*y[C,Jan] + 145.28508771929825*x[C,Feb] + 160*y[C,Feb] + 147.22222222222223*x[C,Mar] + 160*y[C,Mar] + 138.02083333333334*x[C,Apr] + 160*y[C,Apr] + 141.55982905982907*x[C,May] + 160*y[C,May] + 151.25570776255708*x[C,Jun] + 160*y[C,Jun] + 162.37745098039215*x[C,Jul] + 160*y[C,Jul] + 145.28508771929825*x[C,Aug] + 160*y[C,Aug] + 136.31687242798353*x[C,Sep] + 160*y[C,Sep] + 151.25570776255708*x[C,Oct] + 160*y[C,Oct] + 162.37745098039215*x[C,Nov] + 160*y[C,Nov] + 169.87179487179486*x[C,Dec] + 160*y[C,Dec]
#
# 2 Constraint Declarations
#     demandserviced : Size=36, Index=demandserviced_index, Active=True
#         Key          : Lower  : Body                : Upper  : Active
#         ('A', 'Apr') : 2297.0 : x[A,Apr] + y[A,Apr] : 2297.0 :   True
#         ('A', 'Aug') : 3371.0 : x[A,Aug] + y[A,Aug] : 3371.0 :   True
#         ('A', 'Dec') : 5183.0 : x[A,Dec] + y[A,Dec] : 5183.0 :   True
#         ('A', 'Feb') : 4878.0 : x[A,Feb] + y[A,Feb] : 4878.0 :   True
#         ('A', 'Jan') : 5240.0 : x[A,Jan] + y[A,Jan] : 5240.0 :   True
#         ('A', 'Jul') : 5334.0 : x[A,Jul] + y[A,Jul] : 5334.0 :   True
#         ('A', 'Jun') : 2275.0 : x[A,Jun] + y[A,Jun] : 2275.0 :   True
#         ('A', 'Mar') : 5942.0 : x[A,Mar] + y[A,Mar] : 5942.0 :   True
#         ('A', 'May') : 1992.0 : x[A,May] + y[A,May] : 1992.0 :   True
#         ('A', 'Nov') : 4284.0 : x[A,Nov] + y[A,Nov] : 4284.0 :   True
#         ('A', 'Oct') : 3529.0 : x[A,Oct] + y[A,Oct] : 3529.0 :   True
#         ('A', 'Sep') : 3759.0 : x[A,Sep] + y[A,Sep] : 3759.0 :   True
#         ('B', 'Apr') : 2338.0 : x[B,Apr] + y[B,Apr] : 2338.0 :   True
#         ('B', 'Aug') : 2620.0 : x[B,Aug] + y[B,Aug] : 2620.0 :   True
#         ('B', 'Dec') : 4227.0 : x[B,Dec] + y[B,Dec] : 4227.0 :   True
#         ('B', 'Feb') : 2628.0 : x[B,Feb] + y[B,Feb] : 2628.0 :   True
#         ('B', 'Jan') : 4927.0 : x[B,Jan] + y[B,Jan] : 4927.0 :   True
#         ('B', 'Jul') : 4271.0 : x[B,Jul] + y[B,Jul] : 4271.0 :   True
#         ('B', 'Jun') : 3147.0 : x[B,Jun] + y[B,Jun] : 3147.0 :   True
#         ('B', 'Mar') : 2974.0 : x[B,Mar] + y[B,Mar] : 2974.0 :   True
#         ('B', 'May') : 4020.0 : x[B,May] + y[B,May] : 4020.0 :   True
#         ('B', 'Nov') : 3137.0 : x[B,Nov] + y[B,Nov] : 3137.0 :   True
#         ('B', 'Oct') : 4155.0 : x[B,Oct] + y[B,Oct] : 4155.0 :   True
#         ('B', 'Sep') : 4517.0 : x[B,Sep] + y[B,Sep] : 4517.0 :   True
#         ('C', 'Apr') : 2261.0 : x[C,Apr] + y[C,Apr] : 2261.0 :   True
#         ('C', 'Aug') : 2496.0 : x[C,Aug] + y[C,Aug] : 2496.0 :   True
#         ('C', 'Dec') : 1998.0 : x[C,Dec] + y[C,Dec] : 1998.0 :   True
#         ('C', 'Feb') : 1967.0 : x[C,Feb] + y[C,Feb] : 1967.0 :   True
#         ('C', 'Jan') : 1162.0 : x[C,Jan] + y[C,Jan] : 1162.0 :   True
#         ('C', 'Jul') : 2489.0 : x[C,Jul] + y[C,Jul] : 2489.0 :   True
#         ('C', 'Jun') : 1642.0 : x[C,Jun] + y[C,Jun] : 1642.0 :   True
#         ('C', 'Mar') : 1898.0 : x[C,Mar] + y[C,Mar] : 1898.0 :   True
#         ('C', 'May') : 2030.0 : x[C,May] + y[C,May] : 2030.0 :   True
#         ('C', 'Nov') :  963.0 : x[C,Nov] + y[C,Nov] :  963.0 :   True
#         ('C', 'Oct') : 2421.0 : x[C,Oct] + y[C,Oct] : 2421.0 :   True
#         ('C', 'Sep') :  922.0 : x[C,Sep] + y[C,Sep] :  922.0 :   True
#     max_outsourced : Size=36, Index=max_outsourced_index, Active=True
#         Key          : Lower : Body                            : Upper : Active
#         ('A', 'Apr') :  -Inf : 0.00043535045711797995*y[A,Apr] :   0.1 :   True
#         ('A', 'Aug') :  -Inf :  0.0002966478789676654*y[A,Aug] :   0.1 :   True
#         ('A', 'Dec') :  -Inf : 0.00019293845263360988*y[A,Dec] :   0.1 :   True
#         ('A', 'Feb') :  -Inf :  0.0002050020500205002*y[A,Feb] :   0.1 :   True
#         ('A', 'Jan') :  -Inf : 0.00019083969465648855*y[A,Jan] :   0.1 :   True
#         ('A', 'Jul') :  -Inf : 0.00018747656542932134*y[A,Jul] :   0.1 :   True
#         ('A', 'Jun') :  -Inf : 0.00043956043956043956*y[A,Jun] :   0.1 :   True
#         ('A', 'Mar') :  -Inf :  0.0001682935038707506*y[A,Mar] :   0.1 :   True
#         ('A', 'May') :  -Inf :   0.000502008032128514*y[A,May] :   0.1 :   True
#         ('A', 'Nov') :  -Inf : 0.00023342670401493932*y[A,Nov] :   0.1 :   True
#         ('A', 'Oct') :  -Inf : 0.00028336639274582036*y[A,Oct] :   0.1 :   True
#         ('A', 'Sep') :  -Inf : 0.00026602819898909286*y[A,Sep] :   0.1 :   True
#         ('B', 'Apr') :  -Inf :   0.000427715996578272*y[B,Apr] :   0.1 :   True
#         ('B', 'Aug') :  -Inf :  0.0003816793893129771*y[B,Aug] :   0.1 :   True
#         ('B', 'Dec') :  -Inf :  0.0002365744026496333*y[B,Dec] :   0.1 :   True
#         ('B', 'Feb') :  -Inf :   0.000380517503805175*y[B,Feb] :   0.1 :   True
#         ('B', 'Jan') :  -Inf : 0.00020296326364927948*y[B,Jan] :   0.1 :   True
#         ('B', 'Jul') :  -Inf : 0.00023413720440177945*y[B,Jul] :   0.1 :   True
#         ('B', 'Jun') :  -Inf : 0.00031776294884016526*y[B,Jun] :   0.1 :   True
#         ('B', 'Mar') :  -Inf :  0.0003362474781439139*y[B,Mar] :   0.1 :   True
#         ('B', 'May') :  -Inf :  0.0002487562189054726*y[B,May] :   0.1 :   True
#         ('B', 'Nov') :  -Inf :   0.000318775900541919*y[B,Nov] :   0.1 :   True
#         ('B', 'Oct') :  -Inf : 0.00024067388688327315*y[B,Oct] :   0.1 :   True
#         ('B', 'Sep') :  -Inf : 0.00022138587558113792*y[B,Sep] :   0.1 :   True
#         ('C', 'Apr') :  -Inf :  0.0004422821760283061*y[C,Apr] :   0.1 :   True
#         ('C', 'Aug') :  -Inf : 0.00040064102564102563*y[C,Aug] :   0.1 :   True
#         ('C', 'Dec') :  -Inf :  0.0005005005005005005*y[C,Dec] :   0.1 :   True
#         ('C', 'Feb') :  -Inf :  0.0005083884087442806*y[C,Feb] :   0.1 :   True
#         ('C', 'Jan') :  -Inf :  0.0008605851979345956*y[C,Jan] :   0.1 :   True
#         ('C', 'Jul') :  -Inf :  0.0004017677782241864*y[C,Jul] :   0.1 :   True
#         ('C', 'Jun') :  -Inf :  0.0006090133982947625*y[C,Jun] :   0.1 :   True
#         ('C', 'Mar') :  -Inf :  0.0005268703898840885*y[C,Mar] :   0.1 :   True
#         ('C', 'May') :  -Inf :  0.0004926108374384236*y[C,May] :   0.1 :   True
#         ('C', 'Nov') :  -Inf :  0.0010384215991692627*y[C,Nov] :   0.1 :   True
#         ('C', 'Oct') :  -Inf :  0.0004130524576621231*y[C,Oct] :   0.1 :   True
#         ('C', 'Sep') :  -Inf :  0.0010845986984815619*y[C,Sep] :   0.1 :   True
#
# 17 Declarations: x_index_0 x_index_1 x_index x y_index_0 y_index_1 y_index y max_outsourced_index_0 max_outsourced_index_1 max_outsourced_index max_outsourced demandserviced_index_0 demandserviced_index_1 demandserviced_index demandserviced value

# %%
# Print the value of the objective function
model.value()
# Out:
# 18100979.32121985

# %% [markdown]
# **`Checkpoint 2:`** The company has to spend around 18.1 m$ in total for the application approval process if there is 10% limit on the outsourcing.

# %%
# Creating dataframe for the results
#Creating an empty list
output3_1 = []

# For every iteration, the code below will create a list containing 6 values - 
# 1. count of applications managed by own staff (OwnStaff)
# 2. count of application managed by outsourced vendor (Outsourced)
# 3. demand (Demand) for each state for each month
# 4. number of FTE (own staff required)
# 5. percentage of application outosurced (PercentOutsourced)
# 6. cost of application processing (Total Cost)

for s in state:
    for m in month:
        
        #Demand for each state for each month
        Dem=Demand[s,m]
       
        #count of applications managed by own staff (OwnStaff)
        OwnStaff=model.x[s,m].value
        
        #count of applications managed by outsourced vendor (Outsourced)
        Outsourced=model.y[s,m].value
        
        #Number of FTE
        FTE=round(model.x[s,m].value /FTE_MgAppServed/StaffAvPer[s,m],2)
        
        #percentage of application outosurced (PercentOutsourced)
        PercentOutsourced=round(model.y[s,m].value / Demand[s,m]*100,2)
        
        
        #cost of application processing (Total Cost)
        ProcessingCost=round((model.x[s,m].value*FTE_Salary[s,m]/FTE_MgAppServed/StaffAvPer[s,m])\
                        +(model.y[s,m].value*outsourcecost[s,m]),2)
                
        output3_1.append([s,m,Dem,OwnStaff,Outsourced,FTE, PercentOutsourced,round(ProcessingCost,2)])
        
output3_1 = pd.DataFrame(output3_1,columns=['State','Month','Demand','OwnStaff','Outsourced','FTE',\
                                            'PercentOutsourced','Cost10%Outsourced'])
output3_1
# Out:
#    State Month  Demand  OwnStaff  Outsourced     FTE  PercentOutsourced  \
# 0      A   Jan    5240    5240.0         0.0  161.73               0.00
# 1      A   Feb    4878    4878.0         0.0  160.46               0.00
# 2      A   Mar    5942    5942.0         0.0  198.07               0.00
# 3      A   Apr    2297    2297.0         0.0   71.78               0.00
# 4      A   May    1992    1992.0         0.0   63.85               0.00
# 5      A   Jun    2275    2275.0         0.0   77.91               0.00
# 6      A   Jul    5334    4801.0       533.0  176.51               9.99
# 7      A   Aug    3371    3371.0         0.0  110.89               0.00
# 8      A   Sep    3759    3759.0         0.0  116.02               0.00
# 9      A   Oct    3529    3529.0         0.0  120.86               0.00
# 10     A   Nov    4284    3856.0       428.0  141.76               9.99
# 11     A   Dec    5183    4665.0       518.0  179.42               9.99
# 12     B   Jan    4927    4927.0         0.0  152.07               0.00
# 13     B   Feb    2628    2366.0       262.0   77.83               9.97
# 14     B   Mar    2974    2677.0       297.0   89.23               9.99
# 15     B   Apr    2338    2338.0         0.0   73.06               0.00
# 16     B   May    4020    4020.0         0.0  128.85               0.00
# 17     B   Jun    3147    2833.0       314.0   97.02               9.98
# 18     B   Jul    4271    3844.0       427.0  141.32              10.00
# 19     B   Aug    2620    2358.0       262.0   77.57              10.00
# 20     B   Sep    4517    4517.0         0.0  139.41               0.00
# 21     B   Oct    4155    3740.0       415.0  128.08               9.99
# 22     B   Nov    3137    2824.0       313.0  103.82               9.98
# 23     B   Dec    4227    3805.0       422.0  146.35               9.98
# 24     C   Jan    1162    1162.0         0.0   35.86               0.00
# 25     C   Feb    1967    1967.0         0.0   64.70               0.00
# 26     C   Mar    1898    1898.0         0.0   63.27               0.00
# 27     C   Apr    2261    2261.0         0.0   70.66               0.00
# 28     C   May    2030    2030.0         0.0   65.06               0.00
# 29     C   Jun    1642    1642.0         0.0   56.23               0.00
# 30     C   Jul    2489    2241.0       248.0   82.39               9.96
# 31     C   Aug    2496    2496.0         0.0   82.11               0.00
# 32     C   Sep     922     922.0         0.0   28.46               0.00
# 33     C   Oct    2421    2421.0         0.0   82.91               0.00
# 34     C   Nov     963     867.0        96.0   31.88               9.97
# 35     C   Dec    1998    1799.0       199.0   69.19               9.96
#
#     Cost10%Outsourced
# 0           808641.98
# 1           802302.63
# 2           990333.33
# 3           358906.25
# 4           319230.77
# 5           389554.79
# 6           978476.76
# 7           554440.79
# 8           580092.59
# 9           604280.82
# 10          785863.53
# 11          990355.38
# 12          696977.88
# 13          396016.01
# 14          453536.11
# 15          334869.79
# 16          590544.87
# 17          491777.51
# 18          711782.84
# 19          394809.87
# 20          638978.91
# 21          649293.38
# 22          522807.84
# 23          734053.21
# 24          158400.21
# 25          285775.77
# 26          279427.78
# 27          312065.10
# 28          287366.45
# 29          248361.87
# 30          403567.87
# 31          362631.58
# 32          125684.16
# 33          366190.07
# 34          156141.25
# 35          337439.36

# %%
# Print the value of the objective function
print(round(sum(output3_1['Cost10%Outsourced']/1000000),3), "millions")
# Out:
# 18.101 millions

# %%
# Its $ 18.1 million

# %%
# Additional cost per application

print(round(sum(output3_1['Cost10%Outsourced'])/1000000,2)," millions is total processing cost with 10% Outsourcing limit")
      
print(round((sum(output3_1['Cost10%Outsourced'])-sum(output2['BaseProcesingCost']))/1000000,2), \
      "millions is additional processing cost with 10% Outsourcing limit compared to base case \n")
    
print(round(sum(output2['BaseProcesingCost'])/sum(output2['Demand']),2),\
            " rupees is processing cost per application for Base Case")
      
print(round(sum(output3_1['Cost10%Outsourced'])/sum(output2['Demand']),2), \
      " rupees is processing cost per application with 10% Outsourcing limit \n")

print(round((sum(output3_1['Cost10%Outsourced'])-sum(output2['BaseProcesingCost']))/sum(output2['Demand']),2), \
      " rupees is additional processing cost per application with 10% Outsourcing limit compared to base case")
# Out:
# 18.1  millions is total processing cost with 10% Outsourcing limit
# 0.14 millions is additional processing cost with 10% Outsourcing limit compared to base case
#
# 158.55  rupees is processing cost per application for Base Case
# 159.77  rupees is processing cost per application with 10% Outsourcing limit
#
# 1.22  rupees is additional processing cost per application with 10% Outsourcing limit compared to base case

# %%
# Writing the results in to an Excel sheet

# Importing the required library
from openpyxl import load_workbook

book = load_workbook("Staffing+Data.xlsx")

# create excel writer object
writer = pd.ExcelWriter("Staffing+Data.xlsx", engine = 'openpyxl')

#Assigning the workbook to the writer object
writer.book = book

# write dataframe to excel sheet named 'Staffing+Data.xlsx'
output3_1.to_excel(writer, sheet_name='Question 3 Scenario 1')

# save the excel file
writer.save()
print('DataFrame is written successfully to Excel Sheet.')
# Out:
# DataFrame is written successfully to Excel Sheet.

# %% [markdown]
# ### 3.2  Increase in the outsourcing costs by 20%

# %%
# Creating a model instance
model = ConcreteModel()

# %%
# Define Pyomo sets and Parameters

# Only thing that changes is the Outsourcing Cost, which will increase by 20 %, for quality assurance.

for i in outsourcecost.keys():
    outsourcecost[i]=1.2*outsourcecost[i]
print(outsourcecost)
# Out:
# {('A', 'Jan'): 216.0, ('A', 'Feb'): 216.0, ('A', 'Mar'): 216.0, ('A', 'Apr'): 216.0, ('A', 'May'): 216.0, ('A', 'Jun'): 216.0, ('A', 'Jul'): 216.0, ('A', 'Aug'): 216.0, ('A', 'Sep'): 216.0, ('A', 'Oct'): 216.0, ('A', 'Nov'): 216.0, ('A', 'Dec'): 216.0, ('B', 'Jan'): 180.0, ('B', 'Feb'): 180.0, ('B', 'Mar'): 180.0, ('B', 'Apr'): 180.0, ('B', 'May'): 180.0, ('B', 'Jun'): 180.0, ('B', 'Jul'): 180.0, ('B', 'Aug'): 180.0, ('B', 'Sep'): 180.0, ('B', 'Oct'): 180.0, ('B', 'Nov'): 180.0, ('B', 'Dec'): 180.0, ('C', 'Jan'): 192.0, ('C', 'Feb'): 192.0, ('C', 'Mar'): 192.0, ('C', 'Apr'): 192.0, ('C', 'May'): 192.0, ('C', 'Jun'): 192.0, ('C', 'Jul'): 192.0, ('C', 'Aug'): 192.0, ('C', 'Sep'): 192.0, ('C', 'Oct'): 192.0, ('C', 'Nov'): 192.0, ('C', 'Dec'): 192.0}

# %%
# Decision variables

#Number of applications managed by Staff or own employee
model.x = Var(state, month, within=Integers, bounds=(0,None))

#Number of applications managed by Outsourced Vendor
model.y = Var(state, month, within=Integers, bounds=(0,None))

# %%
# Constraints

#Quality requirement of maximum percentage of applications that can be outsourced - Scenario 1
def max_outsourced_perstate_permonth(model,s,m):
    return (model.y[s,m]/Demand[s,m]) <= quality_scenario1[s]
                   
model.max_outsourced = Constraint(state, month, rule=max_outsourced_perstate_permonth)

# %%
#entire demand should be serviced

def demand_serviced(model,s,m):
    return (model.x[s,m]+ model.y[s,m]) == Demand[s,m]
                   
model.demandserviced = Constraint(state, month, rule=demand_serviced)

# %%
# Objective function
# Defining the objective rule

#Total processing cost = Salary cost for inhouse processed applications + processing cost for outsourced applications
#outsourcing cost is equal to outsourced applications count (Y) mutplied by outsourcing cost per application
#salary cost is decision variable (X)  * employee salary adjusted for servicerate and availability rate

def obj_rule(model):
    
    return sum(((model.x[s,m]*FTE_Salary[s,m]/FTE_MgAppServed/StaffAvPer[s,m])
               +(model.y[s,m])*outsourcecost[s,m])
                for s in state for m in month)

# Minimize the total cost for the application approval process
model.value = Objective(rule=obj_rule, sense= minimize)

# %%
# Invoking the solver
result = SolverFactory('glpk').solve(model)
result.write()
# Out:
# # ==========================================================
# # = Solver Results                                         =
# # ==========================================================
# # ----------------------------------------------------------
# #   Problem Information
# # ----------------------------------------------------------
# Problem:
# - Name: unknown
#   Lower bound: 18144899.6638542
#   Upper bound: 18144899.6638542
#   Number of objectives: 1
#   Number of constraints: 73
#   Number of variables: 73
#   Number of nonzeros: 109
#   Sense: minimize
# # ----------------------------------------------------------
# #   Solver Information
# # ----------------------------------------------------------
# Solver:
# - Status: ok
#   Termination condition: optimal
#   Statistics:
#     Branch and bound:
#       Number of bounded subproblems: 1
#       Number of created subproblems: 1
#   Error rc: 0
#   Time: 0.16003656387329102
# # ----------------------------------------------------------
# #   Solution Information
# # ----------------------------------------------------------
# Solution:
# - number of solutions: 0
#   number of solutions displayed: 0

# %%
# Model parameters after optimization
model.pprint()
# Out:
# 12 Set Declarations
#     demandserviced_index : Size=1, Index=None, Ordered=False
#         Key  : Dimen : Domain                                        : Size : Members
#         None :     2 : demandserviced_index_0*demandserviced_index_1 :   36 : {('A', 'Apr'), ('A', 'Aug'), ('A', 'Dec'), ('A', 'Feb'), ('A', 'Jan'), ('A', 'Jul'), ('A', 'Jun'), ('A', 'Mar'), ('A', 'May'), ('A', 'Nov'), ('A', 'Oct'), ('A', 'Sep'), ('B', 'Apr'), ('B', 'Aug'), ('B', 'Dec'), ('B', 'Feb'), ('B', 'Jan'), ('B', 'Jul'), ('B', 'Jun'), ('B', 'Mar'), ('B', 'May'), ('B', 'Nov'), ('B', 'Oct'), ('B', 'Sep'), ('C', 'Apr'), ('C', 'Aug'), ('C', 'Dec'), ('C', 'Feb'), ('C', 'Jan'), ('C', 'Jul'), ('C', 'Jun'), ('C', 'Mar'), ('C', 'May'), ('C', 'Nov'), ('C', 'Oct'), ('C', 'Sep')}
#     demandserviced_index_0 : Size=1, Index=None, Ordered=False
#         Key  : Dimen : Domain : Size : Members
#         None :     1 :    Any :    3 : {'A', 'B', 'C'}
#     demandserviced_index_1 : Size=1, Index=None, Ordered=False
#         Key  : Dimen : Domain : Size : Members
#         None :     1 :    Any :   12 : {'Apr', 'Aug', 'Dec', 'Feb', 'Jan', 'Jul', 'Jun', 'Mar', 'May', 'Nov', 'Oct', 'Sep'}
#     max_outsourced_index : Size=1, Index=None, Ordered=False
#         Key  : Dimen : Domain                                        : Size : Members
#         None :     2 : max_outsourced_index_0*max_outsourced_index_1 :   36 : {('A', 'Apr'), ('A', 'Aug'), ('A', 'Dec'), ('A', 'Feb'), ('A', 'Jan'), ('A', 'Jul'), ('A', 'Jun'), ('A', 'Mar'), ('A', 'May'), ('A', 'Nov'), ('A', 'Oct'), ('A', 'Sep'), ('B', 'Apr'), ('B', 'Aug'), ('B', 'Dec'), ('B', 'Feb'), ('B', 'Jan'), ('B', 'Jul'), ('B', 'Jun'), ('B', 'Mar'), ('B', 'May'), ('B', 'Nov'), ('B', 'Oct'), ('B', 'Sep'), ('C', 'Apr'), ('C', 'Aug'), ('C', 'Dec'), ('C', 'Feb'), ('C', 'Jan'), ('C', 'Jul'), ('C', 'Jun'), ('C', 'Mar'), ('C', 'May'), ('C', 'Nov'), ('C', 'Oct'), ('C', 'Sep')}
#     max_outsourced_index_0 : Size=1, Index=None, Ordered=False
#         Key  : Dimen : Domain : Size : Members
#         None :     1 :    Any :    3 : {'A', 'B', 'C'}
#     max_outsourced_index_1 : Size=1, Index=None, Ordered=False
#         Key  : Dimen : Domain : Size : Members
#         None :     1 :    Any :   12 : {'Apr', 'Aug', 'Dec', 'Feb', 'Jan', 'Jul', 'Jun', 'Mar', 'May', 'Nov', 'Oct', 'Sep'}
#     x_index : Size=1, Index=None, Ordered=False
#         Key  : Dimen : Domain              : Size : Members
#         None :     2 : x_index_0*x_index_1 :   36 : {('A', 'Apr'), ('A', 'Aug'), ('A', 'Dec'), ('A', 'Feb'), ('A', 'Jan'), ('A', 'Jul'), ('A', 'Jun'), ('A', 'Mar'), ('A', 'May'), ('A', 'Nov'), ('A', 'Oct'), ('A', 'Sep'), ('B', 'Apr'), ('B', 'Aug'), ('B', 'Dec'), ('B', 'Feb'), ('B', 'Jan'), ('B', 'Jul'), ('B', 'Jun'), ('B', 'Mar'), ('B', 'May'), ('B', 'Nov'), ('B', 'Oct'), ('B', 'Sep'), ('C', 'Apr'), ('C', 'Aug'), ('C', 'Dec'), ('C', 'Feb'), ('C', 'Jan'), ('C', 'Jul'), ('C', 'Jun'), ('C', 'Mar'), ('C', 'May'), ('C', 'Nov'), ('C', 'Oct'), ('C', 'Sep')}
#     x_index_0 : Size=1, Index=None, Ordered=False
#         Key  : Dimen : Domain : Size : Members
#         None :     1 :    Any :    3 : {'A', 'B', 'C'}
#     x_index_1 : Size=1, Index=None, Ordered=False
#         Key  : Dimen : Domain : Size : Members
#         None :     1 :    Any :   12 : {'Apr', 'Aug', 'Dec', 'Feb', 'Jan', 'Jul', 'Jun', 'Mar', 'May', 'Nov', 'Oct', 'Sep'}
#     y_index : Size=1, Index=None, Ordered=False
#         Key  : Dimen : Domain              : Size : Members
#         None :     2 : y_index_0*y_index_1 :   36 : {('A', 'Apr'), ('A', 'Aug'), ('A', 'Dec'), ('A', 'Feb'), ('A', 'Jan'), ('A', 'Jul'), ('A', 'Jun'), ('A', 'Mar'), ('A', 'May'), ('A', 'Nov'), ('A', 'Oct'), ('A', 'Sep'), ('B', 'Apr'), ('B', 'Aug'), ('B', 'Dec'), ('B', 'Feb'), ('B', 'Jan'), ('B', 'Jul'), ('B', 'Jun'), ('B', 'Mar'), ('B', 'May'), ('B', 'Nov'), ('B', 'Oct'), ('B', 'Sep'), ('C', 'Apr'), ('C', 'Aug'), ('C', 'Dec'), ('C', 'Feb'), ('C', 'Jan'), ('C', 'Jul'), ('C', 'Jun'), ('C', 'Mar'), ('C', 'May'), ('C', 'Nov'), ('C', 'Oct'), ('C', 'Sep')}
#     y_index_0 : Size=1, Index=None, Ordered=False
#         Key  : Dimen : Domain : Size : Members
#         None :     1 :    Any :    3 : {'A', 'B', 'C'}
#     y_index_1 : Size=1, Index=None, Ordered=False
#         Key  : Dimen : Domain : Size : Members
#         None :     1 :    Any :   12 : {'Apr', 'Aug', 'Dec', 'Feb', 'Jan', 'Jul', 'Jun', 'Mar', 'May', 'Nov', 'Oct', 'Sep'}
#
# 2 Var Declarations
#     x : Size=36, Index=x_index
#         Key          : Lower : Value  : Upper : Fixed : Stale : Domain
#         ('A', 'Apr') :     0 : 2297.0 :  None : False : False : Integers
#         ('A', 'Aug') :     0 : 3371.0 :  None : False : False : Integers
#         ('A', 'Dec') :     0 : 5183.0 :  None : False : False : Integers
#         ('A', 'Feb') :     0 : 4878.0 :  None : False : False : Integers
#         ('A', 'Jan') :     0 : 5240.0 :  None : False : False : Integers
#         ('A', 'Jul') :     0 : 5334.0 :  None : False : False : Integers
#         ('A', 'Jun') :     0 : 2275.0 :  None : False : False : Integers
#         ('A', 'Mar') :     0 : 5942.0 :  None : False : False : Integers
#         ('A', 'May') :     0 : 1992.0 :  None : False : False : Integers
#         ('A', 'Nov') :     0 : 4284.0 :  None : False : False : Integers
#         ('A', 'Oct') :     0 : 3529.0 :  None : False : False : Integers
#         ('A', 'Sep') :     0 : 3759.0 :  None : False : False : Integers
#         ('B', 'Apr') :     0 : 2338.0 :  None : False : False : Integers
#         ('B', 'Aug') :     0 : 2620.0 :  None : False : False : Integers
#         ('B', 'Dec') :     0 : 4227.0 :  None : False : False : Integers
#         ('B', 'Feb') :     0 : 2628.0 :  None : False : False : Integers
#         ('B', 'Jan') :     0 : 4927.0 :  None : False : False : Integers
#         ('B', 'Jul') :     0 : 4271.0 :  None : False : False : Integers
#         ('B', 'Jun') :     0 : 3147.0 :  None : False : False : Integers
#         ('B', 'Mar') :     0 : 2974.0 :  None : False : False : Integers
#         ('B', 'May') :     0 : 4020.0 :  None : False : False : Integers
#         ('B', 'Nov') :     0 : 3137.0 :  None : False : False : Integers
#         ('B', 'Oct') :     0 : 4155.0 :  None : False : False : Integers
#         ('B', 'Sep') :     0 : 4517.0 :  None : False : False : Integers
#         ('C', 'Apr') :     0 : 2261.0 :  None : False : False : Integers
#         ('C', 'Aug') :     0 : 2496.0 :  None : False : False : Integers
#         ('C', 'Dec') :     0 : 1998.0 :  None : False : False : Integers
#         ('C', 'Feb') :     0 : 1967.0 :  None : False : False : Integers
#         ('C', 'Jan') :     0 : 1162.0 :  None : False : False : Integers
#         ('C', 'Jul') :     0 : 2489.0 :  None : False : False : Integers
#         ('C', 'Jun') :     0 : 1642.0 :  None : False : False : Integers
#         ('C', 'Mar') :     0 : 1898.0 :  None : False : False : Integers
#         ('C', 'May') :     0 : 2030.0 :  None : False : False : Integers
#         ('C', 'Nov') :     0 :  963.0 :  None : False : False : Integers
#         ('C', 'Oct') :     0 : 2421.0 :  None : False : False : Integers
#         ('C', 'Sep') :     0 :  922.0 :  None : False : False : Integers
#     y : Size=36, Index=y_index
#         Key          : Lower : Value : Upper : Fixed : Stale : Domain
#         ('A', 'Apr') :     0 :   0.0 :  None : False : False : Integers
#         ('A', 'Aug') :     0 :   0.0 :  None : False : False : Integers
#         ('A', 'Dec') :     0 :   0.0 :  None : False : False : Integers
#         ('A', 'Feb') :     0 :   0.0 :  None : False : False : Integers
#         ('A', 'Jan') :     0 :   0.0 :  None : False : False : Integers
#         ('A', 'Jul') :     0 :   0.0 :  None : False : False : Integers
#         ('A', 'Jun') :     0 :   0.0 :  None : False : False : Integers
#         ('A', 'Mar') :     0 :   0.0 :  None : False : False : Integers
#         ('A', 'May') :     0 :   0.0 :  None : False : False : Integers
#         ('A', 'Nov') :     0 :   0.0 :  None : False : False : Integers
#         ('A', 'Oct') :     0 :   0.0 :  None : False : False : Integers
#         ('A', 'Sep') :     0 :   0.0 :  None : False : False : Integers
#         ('B', 'Apr') :     0 :   0.0 :  None : False : False : Integers
#         ('B', 'Aug') :     0 :   0.0 :  None : False : False : Integers
#         ('B', 'Dec') :     0 :   0.0 :  None : False : False : Integers
#         ('B', 'Feb') :     0 :   0.0 :  None : False : False : Integers
#         ('B', 'Jan') :     0 :   0.0 :  None : False : False : Integers
#         ('B', 'Jul') :     0 :   0.0 :  None : False : False : Integers
#         ('B', 'Jun') :     0 :   0.0 :  None : False : False : Integers
#         ('B', 'Mar') :     0 :   0.0 :  None : False : False : Integers
#         ('B', 'May') :     0 :   0.0 :  None : False : False : Integers
#         ('B', 'Nov') :     0 :   0.0 :  None : False : False : Integers
#         ('B', 'Oct') :     0 :   0.0 :  None : False : False : Integers
#         ('B', 'Sep') :     0 :   0.0 :  None : False : False : Integers
#         ('C', 'Apr') :     0 :   0.0 :  None : False : False : Integers
#         ('C', 'Aug') :     0 :   0.0 :  None : False : False : Integers
#         ('C', 'Dec') :     0 :   0.0 :  None : False : False : Integers
#         ('C', 'Feb') :     0 :   0.0 :  None : False : False : Integers
#         ('C', 'Jan') :     0 :   0.0 :  None : False : False : Integers
#         ('C', 'Jul') :     0 :   0.0 :  None : False : False : Integers
#         ('C', 'Jun') :     0 :   0.0 :  None : False : False : Integers
#         ('C', 'Mar') :     0 :   0.0 :  None : False : False : Integers
#         ('C', 'May') :     0 :   0.0 :  None : False : False : Integers
#         ('C', 'Nov') :     0 :   0.0 :  None : False : False : Integers
#         ('C', 'Oct') :     0 :   0.0 :  None : False : False : Integers
#         ('C', 'Sep') :     0 :   0.0 :  None : False : False : Integers
#
# 1 Objective Declarations
#     value : Size=1, Index=None, Active=True
#         Key  : Active : Sense    : Expression
#         None :   True : minimize : 154.320987654321*x[A,Jan] + 216.0*y[A,Jan] + 164.4736842105263*x[A,Feb] + 216.0*y[A,Feb] + 166.66666666666666*x[A,Mar] + 216.0*y[A,Mar] + 156.25*x[A,Apr] + 216.0*y[A,Apr] + 160.25641025641025*x[A,May] + 216.0*y[A,May] + 171.23287671232876*x[A,Jun] + 216.0*y[A,Jun] + 183.8235294117647*x[A,Jul] + 216.0*y[A,Jul] + 164.4736842105263*x[A,Aug] + 216.0*y[A,Aug] + 154.320987654321*x[A,Sep] + 216.0*y[A,Sep] + 171.23287671232876*x[A,Oct] + 216.0*y[A,Oct] + 183.8235294117647*x[A,Nov] + 216.0*y[A,Nov] + 192.3076923076923*x[A,Dec] + 216.0*y[A,Dec] + 141.46090534979422*x[B,Jan] + 180.0*y[B,Jan] + 150.76754385964912*x[B,Feb] + 180.0*y[B,Feb] + 152.77777777777777*x[B,Mar] + 180.0*y[B,Mar] + 143.22916666666666*x[B,Apr] + 180.0*y[B,Apr] + 146.90170940170938*x[B,May] + 180.0*y[B,May] + 156.9634703196347*x[B,Jun] + 180.0*y[B,Jun] + 168.50490196078428*x[B,Jul] + 180.0*y[B,Jul] + 150.76754385964912*x[B,Aug] + 180.0*y[B,Aug] + 141.46090534979422*x[B,Sep] + 180.0*y[B,Sep] + 156.9634703196347*x[B,Oct] + 180.0*y[B,Oct] + 168.50490196078428*x[B,Nov] + 180.0*y[B,Nov] + 176.28205128205127*x[B,Dec] + 180.0*y[B,Dec] + 136.31687242798353*x[C,Jan] + 192.0*y[C,Jan] + 145.28508771929825*x[C,Feb] + 192.0*y[C,Feb] + 147.22222222222223*x[C,Mar] + 192.0*y[C,Mar] + 138.02083333333334*x[C,Apr] + 192.0*y[C,Apr] + 141.55982905982907*x[C,May] + 192.0*y[C,May] + 151.25570776255708*x[C,Jun] + 192.0*y[C,Jun] + 162.37745098039215*x[C,Jul] + 192.0*y[C,Jul] + 145.28508771929825*x[C,Aug] + 192.0*y[C,Aug] + 136.31687242798353*x[C,Sep] + 192.0*y[C,Sep] + 151.25570776255708*x[C,Oct] + 192.0*y[C,Oct] + 162.37745098039215*x[C,Nov] + 192.0*y[C,Nov] + 169.87179487179486*x[C,Dec] + 192.0*y[C,Dec]
#
# 2 Constraint Declarations
#     demandserviced : Size=36, Index=demandserviced_index, Active=True
#         Key          : Lower  : Body                : Upper  : Active
#         ('A', 'Apr') : 2297.0 : x[A,Apr] + y[A,Apr] : 2297.0 :   True
#         ('A', 'Aug') : 3371.0 : x[A,Aug] + y[A,Aug] : 3371.0 :   True
#         ('A', 'Dec') : 5183.0 : x[A,Dec] + y[A,Dec] : 5183.0 :   True
#         ('A', 'Feb') : 4878.0 : x[A,Feb] + y[A,Feb] : 4878.0 :   True
#         ('A', 'Jan') : 5240.0 : x[A,Jan] + y[A,Jan] : 5240.0 :   True
#         ('A', 'Jul') : 5334.0 : x[A,Jul] + y[A,Jul] : 5334.0 :   True
#         ('A', 'Jun') : 2275.0 : x[A,Jun] + y[A,Jun] : 2275.0 :   True
#         ('A', 'Mar') : 5942.0 : x[A,Mar] + y[A,Mar] : 5942.0 :   True
#         ('A', 'May') : 1992.0 : x[A,May] + y[A,May] : 1992.0 :   True
#         ('A', 'Nov') : 4284.0 : x[A,Nov] + y[A,Nov] : 4284.0 :   True
#         ('A', 'Oct') : 3529.0 : x[A,Oct] + y[A,Oct] : 3529.0 :   True
#         ('A', 'Sep') : 3759.0 : x[A,Sep] + y[A,Sep] : 3759.0 :   True
#         ('B', 'Apr') : 2338.0 : x[B,Apr] + y[B,Apr] : 2338.0 :   True
#         ('B', 'Aug') : 2620.0 : x[B,Aug] + y[B,Aug] : 2620.0 :   True
#         ('B', 'Dec') : 4227.0 : x[B,Dec] + y[B,Dec] : 4227.0 :   True
#         ('B', 'Feb') : 2628.0 : x[B,Feb] + y[B,Feb] : 2628.0 :   True
#         ('B', 'Jan') : 4927.0 : x[B,Jan] + y[B,Jan] : 4927.0 :   True
#         ('B', 'Jul') : 4271.0 : x[B,Jul] + y[B,Jul] : 4271.0 :   True
#         ('B', 'Jun') : 3147.0 : x[B,Jun] + y[B,Jun] : 3147.0 :   True
#         ('B', 'Mar') : 2974.0 : x[B,Mar] + y[B,Mar] : 2974.0 :   True
#         ('B', 'May') : 4020.0 : x[B,May] + y[B,May] : 4020.0 :   True
#         ('B', 'Nov') : 3137.0 : x[B,Nov] + y[B,Nov] : 3137.0 :   True
#         ('B', 'Oct') : 4155.0 : x[B,Oct] + y[B,Oct] : 4155.0 :   True
#         ('B', 'Sep') : 4517.0 : x[B,Sep] + y[B,Sep] : 4517.0 :   True
#         ('C', 'Apr') : 2261.0 : x[C,Apr] + y[C,Apr] : 2261.0 :   True
#         ('C', 'Aug') : 2496.0 : x[C,Aug] + y[C,Aug] : 2496.0 :   True
#         ('C', 'Dec') : 1998.0 : x[C,Dec] + y[C,Dec] : 1998.0 :   True
#         ('C', 'Feb') : 1967.0 : x[C,Feb] + y[C,Feb] : 1967.0 :   True
#         ('C', 'Jan') : 1162.0 : x[C,Jan] + y[C,Jan] : 1162.0 :   True
#         ('C', 'Jul') : 2489.0 : x[C,Jul] + y[C,Jul] : 2489.0 :   True
#         ('C', 'Jun') : 1642.0 : x[C,Jun] + y[C,Jun] : 1642.0 :   True
#         ('C', 'Mar') : 1898.0 : x[C,Mar] + y[C,Mar] : 1898.0 :   True
#         ('C', 'May') : 2030.0 : x[C,May] + y[C,May] : 2030.0 :   True
#         ('C', 'Nov') :  963.0 : x[C,Nov] + y[C,Nov] :  963.0 :   True
#         ('C', 'Oct') : 2421.0 : x[C,Oct] + y[C,Oct] : 2421.0 :   True
#         ('C', 'Sep') :  922.0 : x[C,Sep] + y[C,Sep] :  922.0 :   True
#     max_outsourced : Size=36, Index=max_outsourced_index, Active=True
#         Key          : Lower : Body                            : Upper : Active
#         ('A', 'Apr') :  -Inf : 0.00043535045711797995*y[A,Apr] :   0.1 :   True
#         ('A', 'Aug') :  -Inf :  0.0002966478789676654*y[A,Aug] :   0.1 :   True
#         ('A', 'Dec') :  -Inf : 0.00019293845263360988*y[A,Dec] :   0.1 :   True
#         ('A', 'Feb') :  -Inf :  0.0002050020500205002*y[A,Feb] :   0.1 :   True
#         ('A', 'Jan') :  -Inf : 0.00019083969465648855*y[A,Jan] :   0.1 :   True
#         ('A', 'Jul') :  -Inf : 0.00018747656542932134*y[A,Jul] :   0.1 :   True
#         ('A', 'Jun') :  -Inf : 0.00043956043956043956*y[A,Jun] :   0.1 :   True
#         ('A', 'Mar') :  -Inf :  0.0001682935038707506*y[A,Mar] :   0.1 :   True
#         ('A', 'May') :  -Inf :   0.000502008032128514*y[A,May] :   0.1 :   True
#         ('A', 'Nov') :  -Inf : 0.00023342670401493932*y[A,Nov] :   0.1 :   True
#         ('A', 'Oct') :  -Inf : 0.00028336639274582036*y[A,Oct] :   0.1 :   True
#         ('A', 'Sep') :  -Inf : 0.00026602819898909286*y[A,Sep] :   0.1 :   True
#         ('B', 'Apr') :  -Inf :   0.000427715996578272*y[B,Apr] :   0.1 :   True
#         ('B', 'Aug') :  -Inf :  0.0003816793893129771*y[B,Aug] :   0.1 :   True
#         ('B', 'Dec') :  -Inf :  0.0002365744026496333*y[B,Dec] :   0.1 :   True
#         ('B', 'Feb') :  -Inf :   0.000380517503805175*y[B,Feb] :   0.1 :   True
#         ('B', 'Jan') :  -Inf : 0.00020296326364927948*y[B,Jan] :   0.1 :   True
#         ('B', 'Jul') :  -Inf : 0.00023413720440177945*y[B,Jul] :   0.1 :   True
#         ('B', 'Jun') :  -Inf : 0.00031776294884016526*y[B,Jun] :   0.1 :   True
#         ('B', 'Mar') :  -Inf :  0.0003362474781439139*y[B,Mar] :   0.1 :   True
#         ('B', 'May') :  -Inf :  0.0002487562189054726*y[B,May] :   0.1 :   True
#         ('B', 'Nov') :  -Inf :   0.000318775900541919*y[B,Nov] :   0.1 :   True
#         ('B', 'Oct') :  -Inf : 0.00024067388688327315*y[B,Oct] :   0.1 :   True
#         ('B', 'Sep') :  -Inf : 0.00022138587558113792*y[B,Sep] :   0.1 :   True
#         ('C', 'Apr') :  -Inf :  0.0004422821760283061*y[C,Apr] :   0.1 :   True
#         ('C', 'Aug') :  -Inf : 0.00040064102564102563*y[C,Aug] :   0.1 :   True
#         ('C', 'Dec') :  -Inf :  0.0005005005005005005*y[C,Dec] :   0.1 :   True
#         ('C', 'Feb') :  -Inf :  0.0005083884087442806*y[C,Feb] :   0.1 :   True
#         ('C', 'Jan') :  -Inf :  0.0008605851979345956*y[C,Jan] :   0.1 :   True
#         ('C', 'Jul') :  -Inf :  0.0004017677782241864*y[C,Jul] :   0.1 :   True
#         ('C', 'Jun') :  -Inf :  0.0006090133982947625*y[C,Jun] :   0.1 :   True
#         ('C', 'Mar') :  -Inf :  0.0005268703898840885*y[C,Mar] :   0.1 :   True
#         ('C', 'May') :  -Inf :  0.0004926108374384236*y[C,May] :   0.1 :   True
#         ('C', 'Nov') :  -Inf :  0.0010384215991692627*y[C,Nov] :   0.1 :   True
#         ('C', 'Oct') :  -Inf :  0.0004130524576621231*y[C,Oct] :   0.1 :   True
#         ('C', 'Sep') :  -Inf :  0.0010845986984815619*y[C,Sep] :   0.1 :   True
#
# 17 Declarations: x_index_0 x_index_1 x_index x y_index_0 y_index_1 y_index y max_outsourced_index_0 max_outsourced_index_1 max_outsourced_index max_outsourced demandserviced_index_0 demandserviced_index_1 demandserviced_index demandserviced value

# %%
# Print the value of the objective function
model.value()
# Out:
# 18144899.66385416

# %%
# Creating dataframe for the results
# Creating dataframe for the results
#Creating an empty list
output3_2 = []

# For every iteration, the code below will create a list containing 6 values - 
# 1. count of applications managed by own staff (OwnStaff)
# 2. count of application managed by outsourced vendor (Outsourced)
# 3. demand (Demand) for each state for each month
# 4. number of FTE (own staff required)
# 5. percentage of application outosurced (PercentOutsourced)
# 6. cost of application processing (Total Cost)

for s in state:
    for m in month:
        
        #Demand for each state for each month
        Dem=Demand[s,m]
       
        #count of applications managed by own staff (OwnStaff)
        OwnStaff=model.x[s,m].value
        
        #count of applications managed by outsourced vendor (Outsourced)
        Outsourced=model.y[s,m].value
        
        #Number of FTE
        FTE=round(model.x[s,m].value /FTE_MgAppServed/StaffAvPer[s,m],2)
        
        #percentage of application outosurced (PercentOutsourced)
        PercentOutsourced=round(model.y[s,m].value / Demand[s,m]*100,2)
        
        
        #cost of application processing (Total Cost)
        ProcessingCost=round((model.x[s,m].value*FTE_Salary[s,m]/FTE_MgAppServed/StaffAvPer[s,m])\
                        +(model.y[s,m].value*outsourcecost[s,m]),2)
                
        output3_2.append([s,m,Dem,OwnStaff,Outsourced,FTE, PercentOutsourced,round(ProcessingCost,2)])
        
output3_2 = pd.DataFrame(output3_2,columns=['State','Month','Demand','OwnStaff','Outsourced','FTE',\
                                            'PercentOutsourced','Cost20%Outsourced'])
output3_2
# Out:
#    State Month  Demand  OwnStaff  Outsourced     FTE  PercentOutsourced  \
# 0      A   Jan    5240    5240.0         0.0  161.73                0.0
# 1      A   Feb    4878    4878.0         0.0  160.46                0.0
# 2      A   Mar    5942    5942.0         0.0  198.07                0.0
# 3      A   Apr    2297    2297.0         0.0   71.78                0.0
# 4      A   May    1992    1992.0         0.0   63.85                0.0
# 5      A   Jun    2275    2275.0         0.0   77.91                0.0
# 6      A   Jul    5334    5334.0         0.0  196.10                0.0
# 7      A   Aug    3371    3371.0         0.0  110.89                0.0
# 8      A   Sep    3759    3759.0         0.0  116.02                0.0
# 9      A   Oct    3529    3529.0         0.0  120.86                0.0
# 10     A   Nov    4284    4284.0         0.0  157.50                0.0
# 11     A   Dec    5183    5183.0         0.0  199.35                0.0
# 12     B   Jan    4927    4927.0         0.0  152.07                0.0
# 13     B   Feb    2628    2628.0         0.0   86.45                0.0
# 14     B   Mar    2974    2974.0         0.0   99.13                0.0
# 15     B   Apr    2338    2338.0         0.0   73.06                0.0
# 16     B   May    4020    4020.0         0.0  128.85                0.0
# 17     B   Jun    3147    3147.0         0.0  107.77                0.0
# 18     B   Jul    4271    4271.0         0.0  157.02                0.0
# 19     B   Aug    2620    2620.0         0.0   86.18                0.0
# 20     B   Sep    4517    4517.0         0.0  139.41                0.0
# 21     B   Oct    4155    4155.0         0.0  142.29                0.0
# 22     B   Nov    3137    3137.0         0.0  115.33                0.0
# 23     B   Dec    4227    4227.0         0.0  162.58                0.0
# 24     C   Jan    1162    1162.0         0.0   35.86                0.0
# 25     C   Feb    1967    1967.0         0.0   64.70                0.0
# 26     C   Mar    1898    1898.0         0.0   63.27                0.0
# 27     C   Apr    2261    2261.0         0.0   70.66                0.0
# 28     C   May    2030    2030.0         0.0   65.06                0.0
# 29     C   Jun    1642    1642.0         0.0   56.23                0.0
# 30     C   Jul    2489    2489.0         0.0   91.51                0.0
# 31     C   Aug    2496    2496.0         0.0   82.11                0.0
# 32     C   Sep     922     922.0         0.0   28.46                0.0
# 33     C   Oct    2421    2421.0         0.0   82.91                0.0
# 34     C   Nov     963     963.0         0.0   35.40                0.0
# 35     C   Dec    1998    1998.0         0.0   76.85                0.0
#
#     Cost20%Outsourced
# 0           808641.98
# 1           802302.63
# 2           990333.33
# 3           358906.25
# 4           319230.77
# 5           389554.79
# 6           980514.71
# 7           554440.79
# 8           580092.59
# 9           604280.82
# 10          787500.00
# 11          996730.77
# 12          696977.88
# 13          396217.11
# 14          454361.11
# 15          334869.79
# 16          590544.87
# 17          493964.04
# 18          719684.44
# 19          395010.96
# 20          638978.91
# 21          652183.22
# 22          528599.88
# 23          745144.23
# 24          158400.21
# 25          285775.77
# 26          279427.78
# 27          312065.10
# 28          287366.45
# 29          248361.87
# 30          404157.48
# 31          362631.58
# 32          125684.16
# 33          366190.07
# 34          156369.49
# 35          339403.85

# %%
# Print the value of the objective function
print(round(sum(output3_2['Cost20%Outsourced']/1000000),3), "millions")
# Out:
# 18.145 millions

# %% [markdown]
# **`Checkpoint 3:`** On increasing the outsourcing cost by 20%, the company has to spend around 18.14 m$, which is slightly more than the previous case .

# %%
# Average optimal percentage of outsourcing 

print(round(sum(output3_2['Cost20%Outsourced'])/1000000,2)," millions is total processing cost with 10% Outsourcing limit and 20% increase in outsource cost")
      
print(round((sum(output3_2['Cost20%Outsourced'])-sum(output2['BaseProcesingCost']))/1000000,2), \
      "millions is total processing cost with 10% Outsourcing limit and 20% increase in outsource cost compared to base case \n")
    
print(round(sum(output2['BaseProcesingCost'])/sum(output2['Demand']),2),\
            " rupees is processing cost per application for Base Case")
      
print(round(sum(output3_2['Cost20%Outsourced'])/sum(output2['Demand']),2), \
      " rupees is processing cost per application with 10% Outsourcing limit and 20% increase in outsource cost \n")

print(round((sum(output3_2['Cost20%Outsourced'])-sum(output2['BaseProcesingCost']))/sum(output2['Demand']),2), \
      " rupees is additional processing cost per application with 10% Outsourcing limit and 20% increase in outsource cost compared to base case")
# Out:
# 18.14  millions is total processing cost with 10% Outsourcing limit and 20% increase in outsource cost
# 0.18 millions is total processing cost with 10% Outsourcing limit and 20% increase in outsource cost compared to base case
#
# 158.55  rupees is processing cost per application for Base Case
# 160.16  rupees is processing cost per application with 10% Outsourcing limit and 20% increase in outsource cost
#
# 1.61  rupees is additional processing cost per application with 10% Outsourcing limit and 20% increase in outsource cost compared to base case

# %%
# Print the value of the objective function
print(round(sum(output3_2['PercentOutsourced'])))
# Out:
# 0

# %%
# Here optimal outsource percentage is 0%.

# %%
# Writing the results in to an Excel sheet

# Importing the required library
from openpyxl import load_workbook

book = load_workbook("Staffing+Data.xlsx")

# create excel writer object
writer = pd.ExcelWriter("Staffing+Data.xlsx", engine = 'openpyxl')

#Assigning the workbook to the writer object
writer.book = book

# write dataframe to excel sheet named 'Staffing+Data.xlsx'
output3_2.to_excel(writer, sheet_name='Question 3 Scenario 2')

# save the excel file
writer.save()
print('DataFrame is written successfully to Excel Sheet.')
# Out:
# DataFrame is written successfully to Excel Sheet.

# %% [markdown]
# # Question 4
#
# #### Worst-case and best-case analysis based on the staffs' availability.
#
# Assuming that the distribution is the same across all the states,
#
# #### 4.1 Worst case analysis
#
# - 4.1.1 What is the optimal number of staff members for the worst and best cases?
#
# - 4.1.2 What is the percentage of outsourcing for the worst and best cases?
#
# - 4.1.3 What is the average cost per application for the worst and best cases?
#
#
# #### 4.2 Best case analysis
#
# - 4.2.1 What is the optimal number of staff members for the worst and best cases?
#
# - 4.2.2 What is the percentage of outsourcing for the worst and best cases?
#
# - 4.2.3 What is the average cost per application for the worst and best cases?

# %% [markdown]
# #### Expected output:
#
# For each of the subtasks (4.1 and 4.2) create a data frame containing the number of outsourced applications and the number of FTEs for each state-month combination. You can choose to have extra columns like staff availability, demand etc. in your dataframe apart from the ones mentioned earlier. Also, print the overall average percentage of outsourced applications and the overall average cost per application.

# %% [markdown]
# ### 4.1 Worst Case Analysis

# %% [markdown]
# #### 4.1.1 Optimal number of staff members

# %%
# Creating a model instance
model = ConcreteModel()

# %%
# Define Pyomo sets and Parameters

# Outsourcing limit for State A is 30% and State B is 40%.

# Outscourcing cost need to remain unchanged which we increased by 20% earlier

for i in outsourcecost.keys():
    outsourcecost[i]=outsourcecost[i]/1.2
print(outsourcecost)
# Out:
# {('A', 'Jan'): 180.0, ('A', 'Feb'): 180.0, ('A', 'Mar'): 180.0, ('A', 'Apr'): 180.0, ('A', 'May'): 180.0, ('A', 'Jun'): 180.0, ('A', 'Jul'): 180.0, ('A', 'Aug'): 180.0, ('A', 'Sep'): 180.0, ('A', 'Oct'): 180.0, ('A', 'Nov'): 180.0, ('A', 'Dec'): 180.0, ('B', 'Jan'): 150.0, ('B', 'Feb'): 150.0, ('B', 'Mar'): 150.0, ('B', 'Apr'): 150.0, ('B', 'May'): 150.0, ('B', 'Jun'): 150.0, ('B', 'Jul'): 150.0, ('B', 'Aug'): 150.0, ('B', 'Sep'): 150.0, ('B', 'Oct'): 150.0, ('B', 'Nov'): 150.0, ('B', 'Dec'): 150.0, ('C', 'Jan'): 160.0, ('C', 'Feb'): 160.0, ('C', 'Mar'): 160.0, ('C', 'Apr'): 160.0, ('C', 'May'): 160.0, ('C', 'Jun'): 160.0, ('C', 'Jul'): 160.0, ('C', 'Aug'): 160.0, ('C', 'Sep'): 160.0, ('C', 'Oct'): 160.0, ('C', 'Nov'): 160.0, ('C', 'Dec'): 160.0}

# %%
# Decision variables

#Number of applications managed by Staff or own employee
model.x = Var(state, month, within=Integers, bounds=(0,None))

#Number of applications managed by Outsourced vendor
model.y = Var(state, month, within=Integers, bounds=(0,None))

# %%
# Objective function

#Total processing cost = Salary cost for inhouse processed applications + processing cost for outsourced applications
#outsourcing cost is equal to outsourced applications count (Y) mutplied by outsourcing cost per application
#salary cost is decision variable (X)  * employee salary adjusted for servicerate and availability rate

def obj_rule(model):
    
    return sum(((model.x[s,m]*FTE_Salary[s,m]/FTE_MgAppServed/StaffAv_LB[s,m])
               +(model.y[s,m])*outsourcecost[s,m])
                for s in state for m in month)

model.value = Objective(rule=obj_rule, sense= minimize) # Minimize the total cost for the application approval process

# %%
# Constraints

#Regulatory requirement of maximum percentage of applications that can be outsourced

def max_outsourced_perstate_permonth(model,s,m):
    return (model.y[s,m]/Demand[s,m]) <= regulation_base[s]
                   
model.max_outsourced = Constraint(state, month, rule=max_outsourced_perstate_permonth)

# %%
# Constraints

#entire demand should be serviced

def demand_serviced(model,s,m):
    return (model.x[s,m]+ model.y[s,m]) == Demand[s,m]
                   
model.demandserviced = Constraint(state, month, rule=demand_serviced)

# %%
# Invoking the solver

result = SolverFactory('glpk').solve(model)
result.write()
# Out:
# # ==========================================================
# # = Solver Results                                         =
# # ==========================================================
# # ----------------------------------------------------------
# #   Problem Information
# # ----------------------------------------------------------
# Problem:
# - Name: unknown
#   Lower bound: 19599482.5167888
#   Upper bound: 19599482.5167888
#   Number of objectives: 1
#   Number of constraints: 73
#   Number of variables: 73
#   Number of nonzeros: 109
#   Sense: minimize
# # ----------------------------------------------------------
# #   Solver Information
# # ----------------------------------------------------------
# Solver:
# - Status: ok
#   Termination condition: optimal
#   Statistics:
#     Branch and bound:
#       Number of bounded subproblems: 1
#       Number of created subproblems: 1
#   Error rc: 0
#   Time: 0.12562918663024902
# # ----------------------------------------------------------
# #   Solution Information
# # ----------------------------------------------------------
# Solution:
# - number of solutions: 0
#   number of solutions displayed: 0

# %%
# Model parameters after optimization
model.pprint()
# Out:
# 12 Set Declarations
#     demandserviced_index : Size=1, Index=None, Ordered=False
#         Key  : Dimen : Domain                                        : Size : Members
#         None :     2 : demandserviced_index_0*demandserviced_index_1 :   36 : {('A', 'Apr'), ('A', 'Aug'), ('A', 'Dec'), ('A', 'Feb'), ('A', 'Jan'), ('A', 'Jul'), ('A', 'Jun'), ('A', 'Mar'), ('A', 'May'), ('A', 'Nov'), ('A', 'Oct'), ('A', 'Sep'), ('B', 'Apr'), ('B', 'Aug'), ('B', 'Dec'), ('B', 'Feb'), ('B', 'Jan'), ('B', 'Jul'), ('B', 'Jun'), ('B', 'Mar'), ('B', 'May'), ('B', 'Nov'), ('B', 'Oct'), ('B', 'Sep'), ('C', 'Apr'), ('C', 'Aug'), ('C', 'Dec'), ('C', 'Feb'), ('C', 'Jan'), ('C', 'Jul'), ('C', 'Jun'), ('C', 'Mar'), ('C', 'May'), ('C', 'Nov'), ('C', 'Oct'), ('C', 'Sep')}
#     demandserviced_index_0 : Size=1, Index=None, Ordered=False
#         Key  : Dimen : Domain : Size : Members
#         None :     1 :    Any :    3 : {'A', 'B', 'C'}
#     demandserviced_index_1 : Size=1, Index=None, Ordered=False
#         Key  : Dimen : Domain : Size : Members
#         None :     1 :    Any :   12 : {'Apr', 'Aug', 'Dec', 'Feb', 'Jan', 'Jul', 'Jun', 'Mar', 'May', 'Nov', 'Oct', 'Sep'}
#     max_outsourced_index : Size=1, Index=None, Ordered=False
#         Key  : Dimen : Domain                                        : Size : Members
#         None :     2 : max_outsourced_index_0*max_outsourced_index_1 :   36 : {('A', 'Apr'), ('A', 'Aug'), ('A', 'Dec'), ('A', 'Feb'), ('A', 'Jan'), ('A', 'Jul'), ('A', 'Jun'), ('A', 'Mar'), ('A', 'May'), ('A', 'Nov'), ('A', 'Oct'), ('A', 'Sep'), ('B', 'Apr'), ('B', 'Aug'), ('B', 'Dec'), ('B', 'Feb'), ('B', 'Jan'), ('B', 'Jul'), ('B', 'Jun'), ('B', 'Mar'), ('B', 'May'), ('B', 'Nov'), ('B', 'Oct'), ('B', 'Sep'), ('C', 'Apr'), ('C', 'Aug'), ('C', 'Dec'), ('C', 'Feb'), ('C', 'Jan'), ('C', 'Jul'), ('C', 'Jun'), ('C', 'Mar'), ('C', 'May'), ('C', 'Nov'), ('C', 'Oct'), ('C', 'Sep')}
#     max_outsourced_index_0 : Size=1, Index=None, Ordered=False
#         Key  : Dimen : Domain : Size : Members
#         None :     1 :    Any :    3 : {'A', 'B', 'C'}
#     max_outsourced_index_1 : Size=1, Index=None, Ordered=False
#         Key  : Dimen : Domain : Size : Members
#         None :     1 :    Any :   12 : {'Apr', 'Aug', 'Dec', 'Feb', 'Jan', 'Jul', 'Jun', 'Mar', 'May', 'Nov', 'Oct', 'Sep'}
#     x_index : Size=1, Index=None, Ordered=False
#         Key  : Dimen : Domain              : Size : Members
#         None :     2 : x_index_0*x_index_1 :   36 : {('A', 'Apr'), ('A', 'Aug'), ('A', 'Dec'), ('A', 'Feb'), ('A', 'Jan'), ('A', 'Jul'), ('A', 'Jun'), ('A', 'Mar'), ('A', 'May'), ('A', 'Nov'), ('A', 'Oct'), ('A', 'Sep'), ('B', 'Apr'), ('B', 'Aug'), ('B', 'Dec'), ('B', 'Feb'), ('B', 'Jan'), ('B', 'Jul'), ('B', 'Jun'), ('B', 'Mar'), ('B', 'May'), ('B', 'Nov'), ('B', 'Oct'), ('B', 'Sep'), ('C', 'Apr'), ('C', 'Aug'), ('C', 'Dec'), ('C', 'Feb'), ('C', 'Jan'), ('C', 'Jul'), ('C', 'Jun'), ('C', 'Mar'), ('C', 'May'), ('C', 'Nov'), ('C', 'Oct'), ('C', 'Sep')}
#     x_index_0 : Size=1, Index=None, Ordered=False
#         Key  : Dimen : Domain : Size : Members
#         None :     1 :    Any :    3 : {'A', 'B', 'C'}
#     x_index_1 : Size=1, Index=None, Ordered=False
#         Key  : Dimen : Domain : Size : Members
#         None :     1 :    Any :   12 : {'Apr', 'Aug', 'Dec', 'Feb', 'Jan', 'Jul', 'Jun', 'Mar', 'May', 'Nov', 'Oct', 'Sep'}
#     y_index : Size=1, Index=None, Ordered=False
#         Key  : Dimen : Domain              : Size : Members
#         None :     2 : y_index_0*y_index_1 :   36 : {('A', 'Apr'), ('A', 'Aug'), ('A', 'Dec'), ('A', 'Feb'), ('A', 'Jan'), ('A', 'Jul'), ('A', 'Jun'), ('A', 'Mar'), ('A', 'May'), ('A', 'Nov'), ('A', 'Oct'), ('A', 'Sep'), ('B', 'Apr'), ('B', 'Aug'), ('B', 'Dec'), ('B', 'Feb'), ('B', 'Jan'), ('B', 'Jul'), ('B', 'Jun'), ('B', 'Mar'), ('B', 'May'), ('B', 'Nov'), ('B', 'Oct'), ('B', 'Sep'), ('C', 'Apr'), ('C', 'Aug'), ('C', 'Dec'), ('C', 'Feb'), ('C', 'Jan'), ('C', 'Jul'), ('C', 'Jun'), ('C', 'Mar'), ('C', 'May'), ('C', 'Nov'), ('C', 'Oct'), ('C', 'Sep')}
#     y_index_0 : Size=1, Index=None, Ordered=False
#         Key  : Dimen : Domain : Size : Members
#         None :     1 :    Any :    3 : {'A', 'B', 'C'}
#     y_index_1 : Size=1, Index=None, Ordered=False
#         Key  : Dimen : Domain : Size : Members
#         None :     1 :    Any :   12 : {'Apr', 'Aug', 'Dec', 'Feb', 'Jan', 'Jul', 'Jun', 'Mar', 'May', 'Nov', 'Oct', 'Sep'}
#
# 2 Var Declarations
#     x : Size=36, Index=x_index
#         Key          : Lower : Value  : Upper : Fixed : Stale : Domain
#         ('A', 'Apr') :     0 : 2297.0 :  None : False : False : Integers
#         ('A', 'Aug') :     0 : 2360.0 :  None : False : False : Integers
#         ('A', 'Dec') :     0 : 3629.0 :  None : False : False : Integers
#         ('A', 'Feb') :     0 : 3415.0 :  None : False : False : Integers
#         ('A', 'Jan') :     0 : 5240.0 :  None : False : False : Integers
#         ('A', 'Jul') :     0 : 3734.0 :  None : False : False : Integers
#         ('A', 'Jun') :     0 : 1593.0 :  None : False : False : Integers
#         ('A', 'Mar') :     0 : 5942.0 :  None : False : False : Integers
#         ('A', 'May') :     0 : 1992.0 :  None : False : False : Integers
#         ('A', 'Nov') :     0 : 2999.0 :  None : False : False : Integers
#         ('A', 'Oct') :     0 : 2471.0 :  None : False : False : Integers
#         ('A', 'Sep') :     0 : 3759.0 :  None : False : False : Integers
#         ('B', 'Apr') :     0 : 1403.0 :  None : False : False : Integers
#         ('B', 'Aug') :     0 : 1572.0 :  None : False : False : Integers
#         ('B', 'Dec') :     0 : 2537.0 :  None : False : False : Integers
#         ('B', 'Feb') :     0 : 1577.0 :  None : False : False : Integers
#         ('B', 'Jan') :     0 : 2957.0 :  None : False : False : Integers
#         ('B', 'Jul') :     0 : 2563.0 :  None : False : False : Integers
#         ('B', 'Jun') :     0 : 1889.0 :  None : False : False : Integers
#         ('B', 'Mar') :     0 : 1785.0 :  None : False : False : Integers
#         ('B', 'May') :     0 : 2412.0 :  None : False : False : Integers
#         ('B', 'Nov') :     0 : 1883.0 :  None : False : False : Integers
#         ('B', 'Oct') :     0 : 2493.0 :  None : False : False : Integers
#         ('B', 'Sep') :     0 : 2711.0 :  None : False : False : Integers
#         ('C', 'Apr') :     0 : 2261.0 :  None : False : False : Integers
#         ('C', 'Aug') :     0 :    0.0 :  None : False : False : Integers
#         ('C', 'Dec') :     0 :    0.0 :  None : False : False : Integers
#         ('C', 'Feb') :     0 :    0.0 :  None : False : False : Integers
#         ('C', 'Jan') :     0 : 1162.0 :  None : False : False : Integers
#         ('C', 'Jul') :     0 :    0.0 :  None : False : False : Integers
#         ('C', 'Jun') :     0 :    0.0 :  None : False : False : Integers
#         ('C', 'Mar') :     0 : 1898.0 :  None : False : False : Integers
#         ('C', 'May') :     0 : 2030.0 :  None : False : False : Integers
#         ('C', 'Nov') :     0 :    0.0 :  None : False : False : Integers
#         ('C', 'Oct') :     0 :    0.0 :  None : False : False : Integers
#         ('C', 'Sep') :     0 :  922.0 :  None : False : False : Integers
#     y : Size=36, Index=y_index
#         Key          : Lower : Value  : Upper : Fixed : Stale : Domain
#         ('A', 'Apr') :     0 :    0.0 :  None : False : False : Integers
#         ('A', 'Aug') :     0 : 1011.0 :  None : False : False : Integers
#         ('A', 'Dec') :     0 : 1554.0 :  None : False : False : Integers
#         ('A', 'Feb') :     0 : 1463.0 :  None : False : False : Integers
#         ('A', 'Jan') :     0 :    0.0 :  None : False : False : Integers
#         ('A', 'Jul') :     0 : 1600.0 :  None : False : False : Integers
#         ('A', 'Jun') :     0 :  682.0 :  None : False : False : Integers
#         ('A', 'Mar') :     0 :    0.0 :  None : False : False : Integers
#         ('A', 'May') :     0 :    0.0 :  None : False : False : Integers
#         ('A', 'Nov') :     0 : 1285.0 :  None : False : False : Integers
#         ('A', 'Oct') :     0 : 1058.0 :  None : False : False : Integers
#         ('A', 'Sep') :     0 :    0.0 :  None : False : False : Integers
#         ('B', 'Apr') :     0 :  935.0 :  None : False : False : Integers
#         ('B', 'Aug') :     0 : 1048.0 :  None : False : False : Integers
#         ('B', 'Dec') :     0 : 1690.0 :  None : False : False : Integers
#         ('B', 'Feb') :     0 : 1051.0 :  None : False : False : Integers
#         ('B', 'Jan') :     0 : 1970.0 :  None : False : False : Integers
#         ('B', 'Jul') :     0 : 1708.0 :  None : False : False : Integers
#         ('B', 'Jun') :     0 : 1258.0 :  None : False : False : Integers
#         ('B', 'Mar') :     0 : 1189.0 :  None : False : False : Integers
#         ('B', 'May') :     0 : 1608.0 :  None : False : False : Integers
#         ('B', 'Nov') :     0 : 1254.0 :  None : False : False : Integers
#         ('B', 'Oct') :     0 : 1662.0 :  None : False : False : Integers
#         ('B', 'Sep') :     0 : 1806.0 :  None : False : False : Integers
#         ('C', 'Apr') :     0 :    0.0 :  None : False : False : Integers
#         ('C', 'Aug') :     0 : 2496.0 :  None : False : False : Integers
#         ('C', 'Dec') :     0 : 1998.0 :  None : False : False : Integers
#         ('C', 'Feb') :     0 : 1967.0 :  None : False : False : Integers
#         ('C', 'Jan') :     0 :    0.0 :  None : False : False : Integers
#         ('C', 'Jul') :     0 : 2489.0 :  None : False : False : Integers
#         ('C', 'Jun') :     0 : 1642.0 :  None : False : False : Integers
#         ('C', 'Mar') :     0 :    0.0 :  None : False : False : Integers
#         ('C', 'May') :     0 :    0.0 :  None : False : False : Integers
#         ('C', 'Nov') :     0 :  963.0 :  None : False : False : Integers
#         ('C', 'Oct') :     0 : 2421.0 :  None : False : False : Integers
#         ('C', 'Sep') :     0 :    0.0 :  None : False : False : Integers
#
# 1 Objective Declarations
#     value : Size=1, Index=None, Active=True
#         Key  : Active : Sense    : Expression
#         None :   True : minimize : 178.57142857142858*x[A,Jan] + 180.0*y[A,Jan] + 192.3076923076923*x[A,Feb] + 180.0*y[A,Feb] + 178.57142857142858*x[A,Mar] + 180.0*y[A,Mar] + 166.66666666666666*x[A,Apr] + 180.0*y[A,Apr] + 178.57142857142858*x[A,May] + 180.0*y[A,May] + 192.3076923076923*x[A,Jun] + 180.0*y[A,Jun] + 208.33333333333334*x[A,Jul] + 180.0*y[A,Jul] + 192.3076923076923*x[A,Aug] + 180.0*y[A,Aug] + 178.57142857142858*x[A,Sep] + 180.0*y[A,Sep] + 192.3076923076923*x[A,Oct] + 180.0*y[A,Oct] + 208.33333333333334*x[A,Nov] + 180.0*y[A,Nov] + 208.33333333333334*x[A,Dec] + 180.0*y[A,Dec] + 163.6904761904762*x[B,Jan] + 150.0*y[B,Jan] + 176.28205128205127*x[B,Feb] + 150.0*y[B,Feb] + 163.6904761904762*x[B,Mar] + 150.0*y[B,Mar] + 152.77777777777777*x[B,Apr] + 150.0*y[B,Apr] + 163.6904761904762*x[B,May] + 150.0*y[B,May] + 176.28205128205127*x[B,Jun] + 150.0*y[B,Jun] + 190.97222222222223*x[B,Jul] + 150.0*y[B,Jul] + 176.28205128205127*x[B,Aug] + 150.0*y[B,Aug] + 163.6904761904762*x[B,Sep] + 150.0*y[B,Sep] + 176.28205128205127*x[B,Oct] + 150.0*y[B,Oct] + 190.97222222222223*x[B,Nov] + 150.0*y[B,Nov] + 190.97222222222223*x[B,Dec] + 150.0*y[B,Dec] + 157.73809523809524*x[C,Jan] + 160.0*y[C,Jan] + 169.87179487179486*x[C,Feb] + 160.0*y[C,Feb] + 157.73809523809524*x[C,Mar] + 160.0*y[C,Mar] + 147.22222222222223*x[C,Apr] + 160.0*y[C,Apr] + 157.73809523809524*x[C,May] + 160.0*y[C,May] + 169.87179487179486*x[C,Jun] + 160.0*y[C,Jun] + 184.0277777777778*x[C,Jul] + 160.0*y[C,Jul] + 169.87179487179486*x[C,Aug] + 160.0*y[C,Aug] + 157.73809523809524*x[C,Sep] + 160.0*y[C,Sep] + 169.87179487179486*x[C,Oct] + 160.0*y[C,Oct] + 184.0277777777778*x[C,Nov] + 160.0*y[C,Nov] + 184.0277777777778*x[C,Dec] + 160.0*y[C,Dec]
#
# 2 Constraint Declarations
#     demandserviced : Size=36, Index=demandserviced_index, Active=True
#         Key          : Lower  : Body                : Upper  : Active
#         ('A', 'Apr') : 2297.0 : x[A,Apr] + y[A,Apr] : 2297.0 :   True
#         ('A', 'Aug') : 3371.0 : x[A,Aug] + y[A,Aug] : 3371.0 :   True
#         ('A', 'Dec') : 5183.0 : x[A,Dec] + y[A,Dec] : 5183.0 :   True
#         ('A', 'Feb') : 4878.0 : x[A,Feb] + y[A,Feb] : 4878.0 :   True
#         ('A', 'Jan') : 5240.0 : x[A,Jan] + y[A,Jan] : 5240.0 :   True
#         ('A', 'Jul') : 5334.0 : x[A,Jul] + y[A,Jul] : 5334.0 :   True
#         ('A', 'Jun') : 2275.0 : x[A,Jun] + y[A,Jun] : 2275.0 :   True
#         ('A', 'Mar') : 5942.0 : x[A,Mar] + y[A,Mar] : 5942.0 :   True
#         ('A', 'May') : 1992.0 : x[A,May] + y[A,May] : 1992.0 :   True
#         ('A', 'Nov') : 4284.0 : x[A,Nov] + y[A,Nov] : 4284.0 :   True
#         ('A', 'Oct') : 3529.0 : x[A,Oct] + y[A,Oct] : 3529.0 :   True
#         ('A', 'Sep') : 3759.0 : x[A,Sep] + y[A,Sep] : 3759.0 :   True
#         ('B', 'Apr') : 2338.0 : x[B,Apr] + y[B,Apr] : 2338.0 :   True
#         ('B', 'Aug') : 2620.0 : x[B,Aug] + y[B,Aug] : 2620.0 :   True
#         ('B', 'Dec') : 4227.0 : x[B,Dec] + y[B,Dec] : 4227.0 :   True
#         ('B', 'Feb') : 2628.0 : x[B,Feb] + y[B,Feb] : 2628.0 :   True
#         ('B', 'Jan') : 4927.0 : x[B,Jan] + y[B,Jan] : 4927.0 :   True
#         ('B', 'Jul') : 4271.0 : x[B,Jul] + y[B,Jul] : 4271.0 :   True
#         ('B', 'Jun') : 3147.0 : x[B,Jun] + y[B,Jun] : 3147.0 :   True
#         ('B', 'Mar') : 2974.0 : x[B,Mar] + y[B,Mar] : 2974.0 :   True
#         ('B', 'May') : 4020.0 : x[B,May] + y[B,May] : 4020.0 :   True
#         ('B', 'Nov') : 3137.0 : x[B,Nov] + y[B,Nov] : 3137.0 :   True
#         ('B', 'Oct') : 4155.0 : x[B,Oct] + y[B,Oct] : 4155.0 :   True
#         ('B', 'Sep') : 4517.0 : x[B,Sep] + y[B,Sep] : 4517.0 :   True
#         ('C', 'Apr') : 2261.0 : x[C,Apr] + y[C,Apr] : 2261.0 :   True
#         ('C', 'Aug') : 2496.0 : x[C,Aug] + y[C,Aug] : 2496.0 :   True
#         ('C', 'Dec') : 1998.0 : x[C,Dec] + y[C,Dec] : 1998.0 :   True
#         ('C', 'Feb') : 1967.0 : x[C,Feb] + y[C,Feb] : 1967.0 :   True
#         ('C', 'Jan') : 1162.0 : x[C,Jan] + y[C,Jan] : 1162.0 :   True
#         ('C', 'Jul') : 2489.0 : x[C,Jul] + y[C,Jul] : 2489.0 :   True
#         ('C', 'Jun') : 1642.0 : x[C,Jun] + y[C,Jun] : 1642.0 :   True
#         ('C', 'Mar') : 1898.0 : x[C,Mar] + y[C,Mar] : 1898.0 :   True
#         ('C', 'May') : 2030.0 : x[C,May] + y[C,May] : 2030.0 :   True
#         ('C', 'Nov') :  963.0 : x[C,Nov] + y[C,Nov] :  963.0 :   True
#         ('C', 'Oct') : 2421.0 : x[C,Oct] + y[C,Oct] : 2421.0 :   True
#         ('C', 'Sep') :  922.0 : x[C,Sep] + y[C,Sep] :  922.0 :   True
#     max_outsourced : Size=36, Index=max_outsourced_index, Active=True
#         Key          : Lower : Body                            : Upper : Active
#         ('A', 'Apr') :  -Inf : 0.00043535045711797995*y[A,Apr] :   0.3 :   True
#         ('A', 'Aug') :  -Inf :  0.0002966478789676654*y[A,Aug] :   0.3 :   True
#         ('A', 'Dec') :  -Inf : 0.00019293845263360988*y[A,Dec] :   0.3 :   True
#         ('A', 'Feb') :  -Inf :  0.0002050020500205002*y[A,Feb] :   0.3 :   True
#         ('A', 'Jan') :  -Inf : 0.00019083969465648855*y[A,Jan] :   0.3 :   True
#         ('A', 'Jul') :  -Inf : 0.00018747656542932134*y[A,Jul] :   0.3 :   True
#         ('A', 'Jun') :  -Inf : 0.00043956043956043956*y[A,Jun] :   0.3 :   True
#         ('A', 'Mar') :  -Inf :  0.0001682935038707506*y[A,Mar] :   0.3 :   True
#         ('A', 'May') :  -Inf :   0.000502008032128514*y[A,May] :   0.3 :   True
#         ('A', 'Nov') :  -Inf : 0.00023342670401493932*y[A,Nov] :   0.3 :   True
#         ('A', 'Oct') :  -Inf : 0.00028336639274582036*y[A,Oct] :   0.3 :   True
#         ('A', 'Sep') :  -Inf : 0.00026602819898909286*y[A,Sep] :   0.3 :   True
#         ('B', 'Apr') :  -Inf :   0.000427715996578272*y[B,Apr] :   0.4 :   True
#         ('B', 'Aug') :  -Inf :  0.0003816793893129771*y[B,Aug] :   0.4 :   True
#         ('B', 'Dec') :  -Inf :  0.0002365744026496333*y[B,Dec] :   0.4 :   True
#         ('B', 'Feb') :  -Inf :   0.000380517503805175*y[B,Feb] :   0.4 :   True
#         ('B', 'Jan') :  -Inf : 0.00020296326364927948*y[B,Jan] :   0.4 :   True
#         ('B', 'Jul') :  -Inf : 0.00023413720440177945*y[B,Jul] :   0.4 :   True
#         ('B', 'Jun') :  -Inf : 0.00031776294884016526*y[B,Jun] :   0.4 :   True
#         ('B', 'Mar') :  -Inf :  0.0003362474781439139*y[B,Mar] :   0.4 :   True
#         ('B', 'May') :  -Inf :  0.0002487562189054726*y[B,May] :   0.4 :   True
#         ('B', 'Nov') :  -Inf :   0.000318775900541919*y[B,Nov] :   0.4 :   True
#         ('B', 'Oct') :  -Inf : 0.00024067388688327315*y[B,Oct] :   0.4 :   True
#         ('B', 'Sep') :  -Inf : 0.00022138587558113792*y[B,Sep] :   0.4 :   True
#         ('C', 'Apr') :  -Inf :  0.0004422821760283061*y[C,Apr] :   1.0 :   True
#         ('C', 'Aug') :  -Inf : 0.00040064102564102563*y[C,Aug] :   1.0 :   True
#         ('C', 'Dec') :  -Inf :  0.0005005005005005005*y[C,Dec] :   1.0 :   True
#         ('C', 'Feb') :  -Inf :  0.0005083884087442806*y[C,Feb] :   1.0 :   True
#         ('C', 'Jan') :  -Inf :  0.0008605851979345956*y[C,Jan] :   1.0 :   True
#         ('C', 'Jul') :  -Inf :  0.0004017677782241864*y[C,Jul] :   1.0 :   True
#         ('C', 'Jun') :  -Inf :  0.0006090133982947625*y[C,Jun] :   1.0 :   True
#         ('C', 'Mar') :  -Inf :  0.0005268703898840885*y[C,Mar] :   1.0 :   True
#         ('C', 'May') :  -Inf :  0.0004926108374384236*y[C,May] :   1.0 :   True
#         ('C', 'Nov') :  -Inf :  0.0010384215991692627*y[C,Nov] :   1.0 :   True
#         ('C', 'Oct') :  -Inf :  0.0004130524576621231*y[C,Oct] :   1.0 :   True
#         ('C', 'Sep') :  -Inf :  0.0010845986984815619*y[C,Sep] :   1.0 :   True
#
# 17 Declarations: x_index_0 x_index_1 x_index x y_index_0 y_index_1 y_index y value max_outsourced_index_0 max_outsourced_index_1 max_outsourced_index max_outsourced demandserviced_index_0 demandserviced_index_1 demandserviced_index demandserviced

# %%
# Print the value of the objective function
model.value()
# Out:
# 19599482.516788762

# %% [markdown]
# **`Checkpoint 4:`** The company has to spend around 19.6 m$ in total for the application approval process if the staffs are working with the minimum availability.

# %%
# Creating dataframe for the results

#Creating an empty list
output4_1 = []

# For every iteration, the code below will create a list containing 6 values - 
# 1. count of applications managed by own staff (OwnStaff)
# 2. count of application managed by outsourced vendor (Outsourced)
# 3. demand (Demand) for each state for each month
# 4. number of FTE (own staff required)
# 5. percentage of application outosurced (PercentOutsourced)
# 6. cost of application processing (Total Cost)

for s in state:
    for m in month:
        
        #Demand for each state for each month
        Dem=Demand[s,m]
       
        #count of applications managed by own staff (OwnStaff)
        OwnStaff=model.x[s,m].value
        
        #count of applications managed by outsourced vendor (Outsourced)
        Outsourced=model.y[s,m].value
        
        #Number of FTE
        FTE=round(model.x[s,m].value /FTE_MgAppServed/StaffAv_LB[s,m],2)
        
        #percentage of application outosurced (PercentOutsourced)
        PercentOutsourced=round(model.y[s,m].value / Demand[s,m]*100,2)
        
        
        #cost of application processing (Total Cost)
        ProcessingCost=round((model.x[s,m].value*FTE_Salary[s,m]/FTE_MgAppServed/StaffAv_LB[s,m])\
                        +(model.y[s,m].value*outsourcecost[s,m]),2)
                
        output4_1.append([s,m,Dem,OwnStaff,Outsourced,FTE, PercentOutsourced,round(ProcessingCost,2)])
        
output4_1 = pd.DataFrame(output4_1,columns=['State','Month','Demand','OwnStaff','Outsourced','FTE',\
                                            'PercentOutsourced','Application_Cost'])
output4_1
# Out:
#    State Month  Demand  OwnStaff  Outsourced     FTE  PercentOutsourced  \
# 0      A   Jan    5240    5240.0         0.0  187.14               0.00
# 1      A   Feb    4878    3415.0      1463.0  131.35              29.99
# 2      A   Mar    5942    5942.0         0.0  212.21               0.00
# 3      A   Apr    2297    2297.0         0.0   76.57               0.00
# 4      A   May    1992    1992.0         0.0   71.14               0.00
# 5      A   Jun    2275    1593.0       682.0   61.27              29.98
# 6      A   Jul    5334    3734.0      1600.0  155.58              30.00
# 7      A   Aug    3371    2360.0      1011.0   90.77              29.99
# 8      A   Sep    3759    3759.0         0.0  134.25               0.00
# 9      A   Oct    3529    2471.0      1058.0   95.04              29.98
# 10     A   Nov    4284    2999.0      1285.0  124.96              30.00
# 11     A   Dec    5183    3629.0      1554.0  151.21              29.98
# 12     B   Jan    4927    2957.0      1970.0  105.61              39.98
# 13     B   Feb    2628    1577.0      1051.0   60.65              39.99
# 14     B   Mar    2974    1785.0      1189.0   63.75              39.98
# 15     B   Apr    2338    1403.0       935.0   46.77              39.99
# 16     B   May    4020    2412.0      1608.0   86.14              40.00
# 17     B   Jun    3147    1889.0      1258.0   72.65              39.97
# 18     B   Jul    4271    2563.0      1708.0  106.79              39.99
# 19     B   Aug    2620    1572.0      1048.0   60.46              40.00
# 20     B   Sep    4517    2711.0      1806.0   96.82              39.98
# 21     B   Oct    4155    2493.0      1662.0   95.88              40.00
# 22     B   Nov    3137    1883.0      1254.0   78.46              39.97
# 23     B   Dec    4227    2537.0      1690.0  105.71              39.98
# 24     C   Jan    1162    1162.0         0.0   41.50               0.00
# 25     C   Feb    1967       0.0      1967.0    0.00             100.00
# 26     C   Mar    1898    1898.0         0.0   67.79               0.00
# 27     C   Apr    2261    2261.0         0.0   75.37               0.00
# 28     C   May    2030    2030.0         0.0   72.50               0.00
# 29     C   Jun    1642       0.0      1642.0    0.00             100.00
# 30     C   Jul    2489       0.0      2489.0    0.00             100.00
# 31     C   Aug    2496       0.0      2496.0    0.00             100.00
# 32     C   Sep     922     922.0         0.0   32.93               0.00
# 33     C   Oct    2421       0.0      2421.0    0.00             100.00
# 34     C   Nov     963       0.0       963.0    0.00             100.00
# 35     C   Dec    1998       0.0      1998.0    0.00             100.00
#
#     Application_Cost
# 0          935714.29
# 1          920070.77
# 2         1061071.43
# 3          382833.33
# 4          355714.29
# 5          429106.15
# 6         1065916.67
# 7          635826.15
# 8          671250.00
# 9          665632.31
# 10         856091.67
# 11        1035761.67
# 12         779532.74
# 13         435646.79
# 14         470537.50
# 15         354597.22
# 16         636021.43
# 17         521696.79
# 18         745661.81
# 19         434315.38
# 20         714664.88
# 21         688771.15
# 22         547700.69
# 23         737996.53
# 24         183291.67
# 25         314720.00
# 26         299386.90
# 27         332869.44
# 28         320208.33
# 29         262720.00
# 30         398240.00
# 31         399360.00
# 32         145434.52
# 33         387360.00
# 34         154080.00
# 35         319680.00

# %%
# Print the value of the objective function
print(round(sum(output4_1['Application_Cost']/1000000),3), "millions")
# Out:
# 19.599 millions

# %% [markdown]
# #### 4.1.2 Percentage of outsourced applications

# %%
# write your code here

# Percentage of outsource application
print(round(sum(output4_1['PercentOutsourced']/36),3))
# Out:
# 38.604

# %% [markdown]
# #### 4.1.3 Average cost per application

# %%
# write your code here

print(round(sum(output4_1['Application_Cost'])/sum(output4_1['Demand']),2), \
      " rupees is average cost per application in worst case. \n")
# Out:
# 173.0  rupees is average cost per application in worst case.

# %% [markdown]
# #### Optimal number of staff members for the worst cases

# %%
# Finding optimal number of inhouse staff members for all the state combined in the worst-case

print(sum(output4_1['OwnStaff']))
# Out:
# 73486.0

# %%
# Writing the results in to an Excel sheet

# Importing the required library
from openpyxl import load_workbook

book = load_workbook("Staffing+Data.xlsx")

# create excel writer object
writer = pd.ExcelWriter("Staffing+Data.xlsx", engine = 'openpyxl')

#Assigning the workbook to the writer object
writer.book = book

# write dataframe to excel sheet named 'Staffing+Data.xlsx'
output4_1.to_excel(writer, sheet_name='Question 4 Scenario 1')

# save the excel file
writer.save()
print('DataFrame is written successfully to Excel Sheet.')
# Out:
# DataFrame is written successfully to Excel Sheet.

# %% [markdown]
# ### 4.2  Best Case Analysis

# %% [markdown]
# #### 4.2.1 Optimal number of staff members

# %%
# Creating a model instance
model = ConcreteModel()

# %%
# Define Pyomo sets and Parameters

# ** Employee Cost - Monthly Salary across each state  : employeecost
# ** Service Rate - Maximum applications that can be processed per FTE  : FTE_MgAppServed
# ** Availability Rate - Percentage of avaialability for FTE for each state for each month : StaffAv_UB
# for Outsourced processing
# ** Outsourcing Cost - Outsourced processing cost per application :  outsourcecost
# for contraint definitions
# ** regulatory limit on percentage of application that can be outsourced : regulation_base
# ** demand for each state each month that needs to be completely serviced : Demand

# %%
# Decision variables

# Decision variables

#Number of applications managed by Staff or own employee
model.x = Var(state, month, within=Integers, bounds=(0,None))

#Number of applications managed by Outsourced vendor
model.y = Var(state, month, within=Integers, bounds=(0,None))

# %%
# Objective function

#Total processing cost = Salary cost for inhouse processed applications + processing cost for outsourced applications
#outsourcing cost is equal to outsourced applications count (Y) mutplied by outsourcing cost per application
#salary cost is decision variable (X)  * employee salary adjusted for servicerate and availability rate

def obj_rule(model):
    
    return sum(((model.x[s,m]*FTE_Salary[s,m]/FTE_MgAppServed/StaffAv_UB[s,m])
               +(model.y[s,m])*outsourcecost[s,m])
                for s in state for m in month)

model.value = Objective(rule=obj_rule, sense= minimize) # Minimize the total cost for the application approval process

# %%
# Constraints

#Regulatory requirement of maximum percentage of applications that can be outsourced

def max_outsourced_perstate_permonth(model,s,m):
    return (model.y[s,m]/Demand[s,m]) <= regulation_base[s]
                   
model.max_outsourced = Constraint(state, month, rule=max_outsourced_perstate_permonth)

# %%
# Constraints

#entire demand should be serviced

def demand_serviced(model,s,m):
    return (model.x[s,m]+ model.y[s,m]) == Demand[s,m]
                   
model.demandserviced = Constraint(state, month, rule=demand_serviced)

# %%
# Invoking the solver

result = SolverFactory('glpk').solve(model)
result.write()
# Out:
# # ==========================================================
# # = Solver Results                                         =
# # ==========================================================
# # ----------------------------------------------------------
# #   Problem Information
# # ----------------------------------------------------------
# Problem:
# - Name: unknown
#   Lower bound: 16527535.6379357
#   Upper bound: 16527535.6379357
#   Number of objectives: 1
#   Number of constraints: 73
#   Number of variables: 73
#   Number of nonzeros: 109
#   Sense: minimize
# # ----------------------------------------------------------
# #   Solver Information
# # ----------------------------------------------------------
# Solver:
# - Status: ok
#   Termination condition: optimal
#   Statistics:
#     Branch and bound:
#       Number of bounded subproblems: 1
#       Number of created subproblems: 1
#   Error rc: 0
#   Time: 0.14061188697814941
# # ----------------------------------------------------------
# #   Solution Information
# # ----------------------------------------------------------
# Solution:
# - number of solutions: 0
#   number of solutions displayed: 0

# %%
# Model parameters after optimization
model.pprint()
# Out:
# 12 Set Declarations
#     demandserviced_index : Size=1, Index=None, Ordered=False
#         Key  : Dimen : Domain                                        : Size : Members
#         None :     2 : demandserviced_index_0*demandserviced_index_1 :   36 : {('A', 'Apr'), ('A', 'Aug'), ('A', 'Dec'), ('A', 'Feb'), ('A', 'Jan'), ('A', 'Jul'), ('A', 'Jun'), ('A', 'Mar'), ('A', 'May'), ('A', 'Nov'), ('A', 'Oct'), ('A', 'Sep'), ('B', 'Apr'), ('B', 'Aug'), ('B', 'Dec'), ('B', 'Feb'), ('B', 'Jan'), ('B', 'Jul'), ('B', 'Jun'), ('B', 'Mar'), ('B', 'May'), ('B', 'Nov'), ('B', 'Oct'), ('B', 'Sep'), ('C', 'Apr'), ('C', 'Aug'), ('C', 'Dec'), ('C', 'Feb'), ('C', 'Jan'), ('C', 'Jul'), ('C', 'Jun'), ('C', 'Mar'), ('C', 'May'), ('C', 'Nov'), ('C', 'Oct'), ('C', 'Sep')}
#     demandserviced_index_0 : Size=1, Index=None, Ordered=False
#         Key  : Dimen : Domain : Size : Members
#         None :     1 :    Any :    3 : {'A', 'B', 'C'}
#     demandserviced_index_1 : Size=1, Index=None, Ordered=False
#         Key  : Dimen : Domain : Size : Members
#         None :     1 :    Any :   12 : {'Apr', 'Aug', 'Dec', 'Feb', 'Jan', 'Jul', 'Jun', 'Mar', 'May', 'Nov', 'Oct', 'Sep'}
#     max_outsourced_index : Size=1, Index=None, Ordered=False
#         Key  : Dimen : Domain                                        : Size : Members
#         None :     2 : max_outsourced_index_0*max_outsourced_index_1 :   36 : {('A', 'Apr'), ('A', 'Aug'), ('A', 'Dec'), ('A', 'Feb'), ('A', 'Jan'), ('A', 'Jul'), ('A', 'Jun'), ('A', 'Mar'), ('A', 'May'), ('A', 'Nov'), ('A', 'Oct'), ('A', 'Sep'), ('B', 'Apr'), ('B', 'Aug'), ('B', 'Dec'), ('B', 'Feb'), ('B', 'Jan'), ('B', 'Jul'), ('B', 'Jun'), ('B', 'Mar'), ('B', 'May'), ('B', 'Nov'), ('B', 'Oct'), ('B', 'Sep'), ('C', 'Apr'), ('C', 'Aug'), ('C', 'Dec'), ('C', 'Feb'), ('C', 'Jan'), ('C', 'Jul'), ('C', 'Jun'), ('C', 'Mar'), ('C', 'May'), ('C', 'Nov'), ('C', 'Oct'), ('C', 'Sep')}
#     max_outsourced_index_0 : Size=1, Index=None, Ordered=False
#         Key  : Dimen : Domain : Size : Members
#         None :     1 :    Any :    3 : {'A', 'B', 'C'}
#     max_outsourced_index_1 : Size=1, Index=None, Ordered=False
#         Key  : Dimen : Domain : Size : Members
#         None :     1 :    Any :   12 : {'Apr', 'Aug', 'Dec', 'Feb', 'Jan', 'Jul', 'Jun', 'Mar', 'May', 'Nov', 'Oct', 'Sep'}
#     x_index : Size=1, Index=None, Ordered=False
#         Key  : Dimen : Domain              : Size : Members
#         None :     2 : x_index_0*x_index_1 :   36 : {('A', 'Apr'), ('A', 'Aug'), ('A', 'Dec'), ('A', 'Feb'), ('A', 'Jan'), ('A', 'Jul'), ('A', 'Jun'), ('A', 'Mar'), ('A', 'May'), ('A', 'Nov'), ('A', 'Oct'), ('A', 'Sep'), ('B', 'Apr'), ('B', 'Aug'), ('B', 'Dec'), ('B', 'Feb'), ('B', 'Jan'), ('B', 'Jul'), ('B', 'Jun'), ('B', 'Mar'), ('B', 'May'), ('B', 'Nov'), ('B', 'Oct'), ('B', 'Sep'), ('C', 'Apr'), ('C', 'Aug'), ('C', 'Dec'), ('C', 'Feb'), ('C', 'Jan'), ('C', 'Jul'), ('C', 'Jun'), ('C', 'Mar'), ('C', 'May'), ('C', 'Nov'), ('C', 'Oct'), ('C', 'Sep')}
#     x_index_0 : Size=1, Index=None, Ordered=False
#         Key  : Dimen : Domain : Size : Members
#         None :     1 :    Any :    3 : {'A', 'B', 'C'}
#     x_index_1 : Size=1, Index=None, Ordered=False
#         Key  : Dimen : Domain : Size : Members
#         None :     1 :    Any :   12 : {'Apr', 'Aug', 'Dec', 'Feb', 'Jan', 'Jul', 'Jun', 'Mar', 'May', 'Nov', 'Oct', 'Sep'}
#     y_index : Size=1, Index=None, Ordered=False
#         Key  : Dimen : Domain              : Size : Members
#         None :     2 : y_index_0*y_index_1 :   36 : {('A', 'Apr'), ('A', 'Aug'), ('A', 'Dec'), ('A', 'Feb'), ('A', 'Jan'), ('A', 'Jul'), ('A', 'Jun'), ('A', 'Mar'), ('A', 'May'), ('A', 'Nov'), ('A', 'Oct'), ('A', 'Sep'), ('B', 'Apr'), ('B', 'Aug'), ('B', 'Dec'), ('B', 'Feb'), ('B', 'Jan'), ('B', 'Jul'), ('B', 'Jun'), ('B', 'Mar'), ('B', 'May'), ('B', 'Nov'), ('B', 'Oct'), ('B', 'Sep'), ('C', 'Apr'), ('C', 'Aug'), ('C', 'Dec'), ('C', 'Feb'), ('C', 'Jan'), ('C', 'Jul'), ('C', 'Jun'), ('C', 'Mar'), ('C', 'May'), ('C', 'Nov'), ('C', 'Oct'), ('C', 'Sep')}
#     y_index_0 : Size=1, Index=None, Ordered=False
#         Key  : Dimen : Domain : Size : Members
#         None :     1 :    Any :    3 : {'A', 'B', 'C'}
#     y_index_1 : Size=1, Index=None, Ordered=False
#         Key  : Dimen : Domain : Size : Members
#         None :     1 :    Any :   12 : {'Apr', 'Aug', 'Dec', 'Feb', 'Jan', 'Jul', 'Jun', 'Mar', 'May', 'Nov', 'Oct', 'Sep'}
#
# 2 Var Declarations
#     x : Size=36, Index=x_index
#         Key          : Lower : Value  : Upper : Fixed : Stale : Domain
#         ('A', 'Apr') :     0 : 2297.0 :  None : False : False : Integers
#         ('A', 'Aug') :     0 : 3371.0 :  None : False : False : Integers
#         ('A', 'Dec') :     0 : 5183.0 :  None : False : False : Integers
#         ('A', 'Feb') :     0 : 4878.0 :  None : False : False : Integers
#         ('A', 'Jan') :     0 : 5240.0 :  None : False : False : Integers
#         ('A', 'Jul') :     0 : 5334.0 :  None : False : False : Integers
#         ('A', 'Jun') :     0 : 2275.0 :  None : False : False : Integers
#         ('A', 'Mar') :     0 : 5942.0 :  None : False : False : Integers
#         ('A', 'May') :     0 : 1992.0 :  None : False : False : Integers
#         ('A', 'Nov') :     0 : 4284.0 :  None : False : False : Integers
#         ('A', 'Oct') :     0 : 3529.0 :  None : False : False : Integers
#         ('A', 'Sep') :     0 : 3759.0 :  None : False : False : Integers
#         ('B', 'Apr') :     0 : 2338.0 :  None : False : False : Integers
#         ('B', 'Aug') :     0 : 2620.0 :  None : False : False : Integers
#         ('B', 'Dec') :     0 : 2537.0 :  None : False : False : Integers
#         ('B', 'Feb') :     0 : 2628.0 :  None : False : False : Integers
#         ('B', 'Jan') :     0 : 4927.0 :  None : False : False : Integers
#         ('B', 'Jul') :     0 : 2563.0 :  None : False : False : Integers
#         ('B', 'Jun') :     0 : 3147.0 :  None : False : False : Integers
#         ('B', 'Mar') :     0 : 2974.0 :  None : False : False : Integers
#         ('B', 'May') :     0 : 4020.0 :  None : False : False : Integers
#         ('B', 'Nov') :     0 : 1883.0 :  None : False : False : Integers
#         ('B', 'Oct') :     0 : 4155.0 :  None : False : False : Integers
#         ('B', 'Sep') :     0 : 4517.0 :  None : False : False : Integers
#         ('C', 'Apr') :     0 : 2261.0 :  None : False : False : Integers
#         ('C', 'Aug') :     0 : 2496.0 :  None : False : False : Integers
#         ('C', 'Dec') :     0 : 1998.0 :  None : False : False : Integers
#         ('C', 'Feb') :     0 : 1967.0 :  None : False : False : Integers
#         ('C', 'Jan') :     0 : 1162.0 :  None : False : False : Integers
#         ('C', 'Jul') :     0 : 2489.0 :  None : False : False : Integers
#         ('C', 'Jun') :     0 : 1642.0 :  None : False : False : Integers
#         ('C', 'Mar') :     0 : 1898.0 :  None : False : False : Integers
#         ('C', 'May') :     0 : 2030.0 :  None : False : False : Integers
#         ('C', 'Nov') :     0 :  963.0 :  None : False : False : Integers
#         ('C', 'Oct') :     0 : 2421.0 :  None : False : False : Integers
#         ('C', 'Sep') :     0 :  922.0 :  None : False : False : Integers
#     y : Size=36, Index=y_index
#         Key          : Lower : Value  : Upper : Fixed : Stale : Domain
#         ('A', 'Apr') :     0 :    0.0 :  None : False : False : Integers
#         ('A', 'Aug') :     0 :    0.0 :  None : False : False : Integers
#         ('A', 'Dec') :     0 :    0.0 :  None : False : False : Integers
#         ('A', 'Feb') :     0 :    0.0 :  None : False : False : Integers
#         ('A', 'Jan') :     0 :    0.0 :  None : False : False : Integers
#         ('A', 'Jul') :     0 :    0.0 :  None : False : False : Integers
#         ('A', 'Jun') :     0 :    0.0 :  None : False : False : Integers
#         ('A', 'Mar') :     0 :    0.0 :  None : False : False : Integers
#         ('A', 'May') :     0 :    0.0 :  None : False : False : Integers
#         ('A', 'Nov') :     0 :    0.0 :  None : False : False : Integers
#         ('A', 'Oct') :     0 :    0.0 :  None : False : False : Integers
#         ('A', 'Sep') :     0 :    0.0 :  None : False : False : Integers
#         ('B', 'Apr') :     0 :    0.0 :  None : False : False : Integers
#         ('B', 'Aug') :     0 :    0.0 :  None : False : False : Integers
#         ('B', 'Dec') :     0 : 1690.0 :  None : False : False : Integers
#         ('B', 'Feb') :     0 :    0.0 :  None : False : False : Integers
#         ('B', 'Jan') :     0 :    0.0 :  None : False : False : Integers
#         ('B', 'Jul') :     0 : 1708.0 :  None : False : False : Integers
#         ('B', 'Jun') :     0 :    0.0 :  None : False : False : Integers
#         ('B', 'Mar') :     0 :    0.0 :  None : False : False : Integers
#         ('B', 'May') :     0 :    0.0 :  None : False : False : Integers
#         ('B', 'Nov') :     0 : 1254.0 :  None : False : False : Integers
#         ('B', 'Oct') :     0 :    0.0 :  None : False : False : Integers
#         ('B', 'Sep') :     0 :    0.0 :  None : False : False : Integers
#         ('C', 'Apr') :     0 :    0.0 :  None : False : False : Integers
#         ('C', 'Aug') :     0 :    0.0 :  None : False : False : Integers
#         ('C', 'Dec') :     0 :    0.0 :  None : False : False : Integers
#         ('C', 'Feb') :     0 :    0.0 :  None : False : False : Integers
#         ('C', 'Jan') :     0 :    0.0 :  None : False : False : Integers
#         ('C', 'Jul') :     0 :    0.0 :  None : False : False : Integers
#         ('C', 'Jun') :     0 :    0.0 :  None : False : False : Integers
#         ('C', 'Mar') :     0 :    0.0 :  None : False : False : Integers
#         ('C', 'May') :     0 :    0.0 :  None : False : False : Integers
#         ('C', 'Nov') :     0 :    0.0 :  None : False : False : Integers
#         ('C', 'Oct') :     0 :    0.0 :  None : False : False : Integers
#         ('C', 'Sep') :     0 :    0.0 :  None : False : False : Integers
#
# 1 Objective Declarations
#     value : Size=1, Index=None, Active=True
#         Key  : Active : Sense    : Expression
#         None :   True : minimize : 138.88888888888889*x[A,Jan] + 180.0*y[A,Jan] + 147.05882352941177*x[A,Feb] + 180.0*y[A,Feb] + 156.25*x[A,Mar] + 180.0*y[A,Mar] + 147.05882352941177*x[A,Apr] + 180.0*y[A,Apr] + 147.05882352941177*x[A,May] + 180.0*y[A,May] + 156.25*x[A,Jun] + 180.0*y[A,Jun] + 166.66666666666666*x[A,Jul] + 180.0*y[A,Jul] + 147.05882352941177*x[A,Aug] + 180.0*y[A,Aug] + 138.88888888888889*x[A,Sep] + 180.0*y[A,Sep] + 156.25*x[A,Oct] + 180.0*y[A,Oct] + 166.66666666666666*x[A,Nov] + 180.0*y[A,Nov] + 178.57142857142858*x[A,Dec] + 180.0*y[A,Dec] + 127.31481481481481*x[B,Jan] + 150.0*y[B,Jan] + 134.80392156862746*x[B,Feb] + 150.0*y[B,Feb] + 143.22916666666666*x[B,Mar] + 150.0*y[B,Mar] + 134.80392156862746*x[B,Apr] + 150.0*y[B,Apr] + 134.80392156862746*x[B,May] + 150.0*y[B,May] + 143.22916666666666*x[B,Jun] + 150.0*y[B,Jun] + 152.77777777777777*x[B,Jul] + 150.0*y[B,Jul] + 134.80392156862746*x[B,Aug] + 150.0*y[B,Aug] + 127.31481481481481*x[B,Sep] + 150.0*y[B,Sep] + 143.22916666666666*x[B,Oct] + 150.0*y[B,Oct] + 152.77777777777777*x[B,Nov] + 150.0*y[B,Nov] + 163.6904761904762*x[B,Dec] + 150.0*y[B,Dec] + 122.68518518518519*x[C,Jan] + 160.0*y[C,Jan] + 129.90196078431373*x[C,Feb] + 160.0*y[C,Feb] + 138.02083333333334*x[C,Mar] + 160.0*y[C,Mar] + 129.90196078431373*x[C,Apr] + 160.0*y[C,Apr] + 129.90196078431373*x[C,May] + 160.0*y[C,May] + 138.02083333333334*x[C,Jun] + 160.0*y[C,Jun] + 147.22222222222223*x[C,Jul] + 160.0*y[C,Jul] + 129.90196078431373*x[C,Aug] + 160.0*y[C,Aug] + 122.68518518518519*x[C,Sep] + 160.0*y[C,Sep] + 138.02083333333334*x[C,Oct] + 160.0*y[C,Oct] + 147.22222222222223*x[C,Nov] + 160.0*y[C,Nov] + 157.73809523809524*x[C,Dec] + 160.0*y[C,Dec]
#
# 2 Constraint Declarations
#     demandserviced : Size=36, Index=demandserviced_index, Active=True
#         Key          : Lower  : Body                : Upper  : Active
#         ('A', 'Apr') : 2297.0 : x[A,Apr] + y[A,Apr] : 2297.0 :   True
#         ('A', 'Aug') : 3371.0 : x[A,Aug] + y[A,Aug] : 3371.0 :   True
#         ('A', 'Dec') : 5183.0 : x[A,Dec] + y[A,Dec] : 5183.0 :   True
#         ('A', 'Feb') : 4878.0 : x[A,Feb] + y[A,Feb] : 4878.0 :   True
#         ('A', 'Jan') : 5240.0 : x[A,Jan] + y[A,Jan] : 5240.0 :   True
#         ('A', 'Jul') : 5334.0 : x[A,Jul] + y[A,Jul] : 5334.0 :   True
#         ('A', 'Jun') : 2275.0 : x[A,Jun] + y[A,Jun] : 2275.0 :   True
#         ('A', 'Mar') : 5942.0 : x[A,Mar] + y[A,Mar] : 5942.0 :   True
#         ('A', 'May') : 1992.0 : x[A,May] + y[A,May] : 1992.0 :   True
#         ('A', 'Nov') : 4284.0 : x[A,Nov] + y[A,Nov] : 4284.0 :   True
#         ('A', 'Oct') : 3529.0 : x[A,Oct] + y[A,Oct] : 3529.0 :   True
#         ('A', 'Sep') : 3759.0 : x[A,Sep] + y[A,Sep] : 3759.0 :   True
#         ('B', 'Apr') : 2338.0 : x[B,Apr] + y[B,Apr] : 2338.0 :   True
#         ('B', 'Aug') : 2620.0 : x[B,Aug] + y[B,Aug] : 2620.0 :   True
#         ('B', 'Dec') : 4227.0 : x[B,Dec] + y[B,Dec] : 4227.0 :   True
#         ('B', 'Feb') : 2628.0 : x[B,Feb] + y[B,Feb] : 2628.0 :   True
#         ('B', 'Jan') : 4927.0 : x[B,Jan] + y[B,Jan] : 4927.0 :   True
#         ('B', 'Jul') : 4271.0 : x[B,Jul] + y[B,Jul] : 4271.0 :   True
#         ('B', 'Jun') : 3147.0 : x[B,Jun] + y[B,Jun] : 3147.0 :   True
#         ('B', 'Mar') : 2974.0 : x[B,Mar] + y[B,Mar] : 2974.0 :   True
#         ('B', 'May') : 4020.0 : x[B,May] + y[B,May] : 4020.0 :   True
#         ('B', 'Nov') : 3137.0 : x[B,Nov] + y[B,Nov] : 3137.0 :   True
#         ('B', 'Oct') : 4155.0 : x[B,Oct] + y[B,Oct] : 4155.0 :   True
#         ('B', 'Sep') : 4517.0 : x[B,Sep] + y[B,Sep] : 4517.0 :   True
#         ('C', 'Apr') : 2261.0 : x[C,Apr] + y[C,Apr] : 2261.0 :   True
#         ('C', 'Aug') : 2496.0 : x[C,Aug] + y[C,Aug] : 2496.0 :   True
#         ('C', 'Dec') : 1998.0 : x[C,Dec] + y[C,Dec] : 1998.0 :   True
#         ('C', 'Feb') : 1967.0 : x[C,Feb] + y[C,Feb] : 1967.0 :   True
#         ('C', 'Jan') : 1162.0 : x[C,Jan] + y[C,Jan] : 1162.0 :   True
#         ('C', 'Jul') : 2489.0 : x[C,Jul] + y[C,Jul] : 2489.0 :   True
#         ('C', 'Jun') : 1642.0 : x[C,Jun] + y[C,Jun] : 1642.0 :   True
#         ('C', 'Mar') : 1898.0 : x[C,Mar] + y[C,Mar] : 1898.0 :   True
#         ('C', 'May') : 2030.0 : x[C,May] + y[C,May] : 2030.0 :   True
#         ('C', 'Nov') :  963.0 : x[C,Nov] + y[C,Nov] :  963.0 :   True
#         ('C', 'Oct') : 2421.0 : x[C,Oct] + y[C,Oct] : 2421.0 :   True
#         ('C', 'Sep') :  922.0 : x[C,Sep] + y[C,Sep] :  922.0 :   True
#     max_outsourced : Size=36, Index=max_outsourced_index, Active=True
#         Key          : Lower : Body                            : Upper : Active
#         ('A', 'Apr') :  -Inf : 0.00043535045711797995*y[A,Apr] :   0.3 :   True
#         ('A', 'Aug') :  -Inf :  0.0002966478789676654*y[A,Aug] :   0.3 :   True
#         ('A', 'Dec') :  -Inf : 0.00019293845263360988*y[A,Dec] :   0.3 :   True
#         ('A', 'Feb') :  -Inf :  0.0002050020500205002*y[A,Feb] :   0.3 :   True
#         ('A', 'Jan') :  -Inf : 0.00019083969465648855*y[A,Jan] :   0.3 :   True
#         ('A', 'Jul') :  -Inf : 0.00018747656542932134*y[A,Jul] :   0.3 :   True
#         ('A', 'Jun') :  -Inf : 0.00043956043956043956*y[A,Jun] :   0.3 :   True
#         ('A', 'Mar') :  -Inf :  0.0001682935038707506*y[A,Mar] :   0.3 :   True
#         ('A', 'May') :  -Inf :   0.000502008032128514*y[A,May] :   0.3 :   True
#         ('A', 'Nov') :  -Inf : 0.00023342670401493932*y[A,Nov] :   0.3 :   True
#         ('A', 'Oct') :  -Inf : 0.00028336639274582036*y[A,Oct] :   0.3 :   True
#         ('A', 'Sep') :  -Inf : 0.00026602819898909286*y[A,Sep] :   0.3 :   True
#         ('B', 'Apr') :  -Inf :   0.000427715996578272*y[B,Apr] :   0.4 :   True
#         ('B', 'Aug') :  -Inf :  0.0003816793893129771*y[B,Aug] :   0.4 :   True
#         ('B', 'Dec') :  -Inf :  0.0002365744026496333*y[B,Dec] :   0.4 :   True
#         ('B', 'Feb') :  -Inf :   0.000380517503805175*y[B,Feb] :   0.4 :   True
#         ('B', 'Jan') :  -Inf : 0.00020296326364927948*y[B,Jan] :   0.4 :   True
#         ('B', 'Jul') :  -Inf : 0.00023413720440177945*y[B,Jul] :   0.4 :   True
#         ('B', 'Jun') :  -Inf : 0.00031776294884016526*y[B,Jun] :   0.4 :   True
#         ('B', 'Mar') :  -Inf :  0.0003362474781439139*y[B,Mar] :   0.4 :   True
#         ('B', 'May') :  -Inf :  0.0002487562189054726*y[B,May] :   0.4 :   True
#         ('B', 'Nov') :  -Inf :   0.000318775900541919*y[B,Nov] :   0.4 :   True
#         ('B', 'Oct') :  -Inf : 0.00024067388688327315*y[B,Oct] :   0.4 :   True
#         ('B', 'Sep') :  -Inf : 0.00022138587558113792*y[B,Sep] :   0.4 :   True
#         ('C', 'Apr') :  -Inf :  0.0004422821760283061*y[C,Apr] :   1.0 :   True
#         ('C', 'Aug') :  -Inf : 0.00040064102564102563*y[C,Aug] :   1.0 :   True
#         ('C', 'Dec') :  -Inf :  0.0005005005005005005*y[C,Dec] :   1.0 :   True
#         ('C', 'Feb') :  -Inf :  0.0005083884087442806*y[C,Feb] :   1.0 :   True
#         ('C', 'Jan') :  -Inf :  0.0008605851979345956*y[C,Jan] :   1.0 :   True
#         ('C', 'Jul') :  -Inf :  0.0004017677782241864*y[C,Jul] :   1.0 :   True
#         ('C', 'Jun') :  -Inf :  0.0006090133982947625*y[C,Jun] :   1.0 :   True
#         ('C', 'Mar') :  -Inf :  0.0005268703898840885*y[C,Mar] :   1.0 :   True
#         ('C', 'May') :  -Inf :  0.0004926108374384236*y[C,May] :   1.0 :   True
#         ('C', 'Nov') :  -Inf :  0.0010384215991692627*y[C,Nov] :   1.0 :   True
#         ('C', 'Oct') :  -Inf :  0.0004130524576621231*y[C,Oct] :   1.0 :   True
#         ('C', 'Sep') :  -Inf :  0.0010845986984815619*y[C,Sep] :   1.0 :   True
#
# 17 Declarations: x_index_0 x_index_1 x_index x y_index_0 y_index_1 y_index y value max_outsourced_index_0 max_outsourced_index_1 max_outsourced_index max_outsourced demandserviced_index_0 demandserviced_index_1 demandserviced_index demandserviced

# %%
# Print the value of the objective function
model.value()
# Out:
# 16527535.637935732

# %% [markdown]
# **`Checkpoint 5:`** The company has to spend around 16.5 m$ in total for the application approval process if the staffs are working with the maximum availability.

# %%
# Creating dataframe for the results

#Creating an empty list
output4_2 = []

# For every iteration, the code below will create a list containing 6 values - 
# 1. count of applications managed by own staff (OwnStaff)
# 2. count of application managed by outsourced vendor (Outsourced)
# 3. demand (Demand) for each state for each month
# 4. number of FTE (own staff required)
# 5. percentage of application outosurced (PercentOutsourced)
# 6. cost of application processing (Total Cost)

for s in state:
    for m in month:
        
        #Demand for each state for each month
        Dem=Demand[s,m]
       
        #count of applications managed by own staff (OwnStaff)
        OwnStaff=model.x[s,m].value
        
        #count of applications managed by outsourced vendor (Outsourced)
        Outsourced=model.y[s,m].value
        
        #Number of FTE
        FTE=round(model.x[s,m].value /FTE_MgAppServed/StaffAv_UB[s,m],2)
        
        #percentage of application outosurced (PercentOutsourced)
        PercentOutsourced=round(model.y[s,m].value / Demand[s,m]*100,2)
        
        
        #cost of application processing (Total Cost)
        ProcessingCost=round((model.x[s,m].value*FTE_Salary[s,m]/FTE_MgAppServed/StaffAv_UB[s,m])\
                        +(model.y[s,m].value*outsourcecost[s,m]),2)
                
        output4_2.append([s,m,Dem,OwnStaff,Outsourced,FTE, PercentOutsourced,round(ProcessingCost,2)])
        
output4_2 = pd.DataFrame(output4_2,columns=['State','Month','Demand','OwnStaff','Outsourced','FTE',\
                                            'PercentOutsourced','Application_Cost'])
output4_2
# Out:
#    State Month  Demand  OwnStaff  Outsourced     FTE  PercentOutsourced  \
# 0      A   Jan    5240    5240.0         0.0  145.56               0.00
# 1      A   Feb    4878    4878.0         0.0  143.47               0.00
# 2      A   Mar    5942    5942.0         0.0  185.69               0.00
# 3      A   Apr    2297    2297.0         0.0   67.56               0.00
# 4      A   May    1992    1992.0         0.0   58.59               0.00
# 5      A   Jun    2275    2275.0         0.0   71.09               0.00
# 6      A   Jul    5334    5334.0         0.0  177.80               0.00
# 7      A   Aug    3371    3371.0         0.0   99.15               0.00
# 8      A   Sep    3759    3759.0         0.0  104.42               0.00
# 9      A   Oct    3529    3529.0         0.0  110.28               0.00
# 10     A   Nov    4284    4284.0         0.0  142.80               0.00
# 11     A   Dec    5183    5183.0         0.0  185.11               0.00
# 12     B   Jan    4927    4927.0         0.0  136.86               0.00
# 13     B   Feb    2628    2628.0         0.0   77.29               0.00
# 14     B   Mar    2974    2974.0         0.0   92.94               0.00
# 15     B   Apr    2338    2338.0         0.0   68.76               0.00
# 16     B   May    4020    4020.0         0.0  118.24               0.00
# 17     B   Jun    3147    3147.0         0.0   98.34               0.00
# 18     B   Jul    4271    2563.0      1708.0   85.43              39.99
# 19     B   Aug    2620    2620.0         0.0   77.06               0.00
# 20     B   Sep    4517    4517.0         0.0  125.47               0.00
# 21     B   Oct    4155    4155.0         0.0  129.84               0.00
# 22     B   Nov    3137    1883.0      1254.0   62.77              39.97
# 23     B   Dec    4227    2537.0      1690.0   90.61              39.98
# 24     C   Jan    1162    1162.0         0.0   32.28               0.00
# 25     C   Feb    1967    1967.0         0.0   57.85               0.00
# 26     C   Mar    1898    1898.0         0.0   59.31               0.00
# 27     C   Apr    2261    2261.0         0.0   66.50               0.00
# 28     C   May    2030    2030.0         0.0   59.71               0.00
# 29     C   Jun    1642    1642.0         0.0   51.31               0.00
# 30     C   Jul    2489    2489.0         0.0   82.97               0.00
# 31     C   Aug    2496    2496.0         0.0   73.41               0.00
# 32     C   Sep     922     922.0         0.0   25.61               0.00
# 33     C   Oct    2421    2421.0         0.0   75.66               0.00
# 34     C   Nov     963     963.0         0.0   32.10               0.00
# 35     C   Dec    1998    1998.0         0.0   71.36               0.00
#
#     Application_Cost
# 0          727777.78
# 1          717352.94
# 2          928437.50
# 3          337794.12
# 4          292941.18
# 5          355468.75
# 6          889000.00
# 7          495735.29
# 8          522083.33
# 9          551406.25
# 10         714000.00
# 11         925535.71
# 12         627280.09
# 13         354264.71
# 14         425963.54
# 15         315171.57
# 16         541911.76
# 17         450742.19
# 18         647769.44
# 19         353186.27
# 20         575081.02
# 21         595117.19
# 22         475780.56
# 23         668782.74
# 24         142560.19
# 25         255517.16
# 26         261963.54
# 27         293708.33
# 28         263700.98
# 29         226630.21
# 30         366436.11
# 31         324235.29
# 32         113115.74
# 33         334148.44
# 34         141775.00
# 35         315160.71

# %%
# Print the value of the objective function
print(round(sum(output4_2['Application_Cost']/1000000),3), "millions")
# Out:
# 16.528 millions

# %% [markdown]
# #### 4.2.2 Percentage of outsourced applications

# %%
# write your code here

# Percentage of outsource application
print(round(sum(output4_2['PercentOutsourced']/36),3))
# Out:
# 3.332

# %% [markdown]
# #### 4.2.3 Average cost per application

# %%
# write your code here

print(round(sum(output4_2['Application_Cost'])/sum(output4_2['Demand']),2), \
      " rupees is average cost per application in worst case. \n")
# Out:
# 145.88  rupees is average cost per application in worst case.

# %% [markdown]
# #### Optimal number of staff members for the best cases

# %%
# Finding optimal number of inhouse staff members for all the state combined in the worst case

print(sum(output4_2['OwnStaff']))
# Out:
# 108642.0

# %%
# Writing the results in to an Excel sheet

# Importing the required library
from openpyxl import load_workbook

book = load_workbook("Staffing+Data.xlsx")

# create excel writer object
writer = pd.ExcelWriter("Staffing+Data.xlsx", engine = 'openpyxl')

#Assigning the workbook to the writer object
writer.book = book

# write dataframe to excel sheet named 'Staffing+Data.xlsx'
output4_2.to_excel(writer, sheet_name='Question 4 Scenario 2')

# save the excel file
writer.save()
print('DataFrame is written successfully to Excel Sheet.')
# Out:
# DataFrame is written successfully to Excel Sheet.

# %% [markdown]
# # Question 5
#
# #### Creating Visualisations

# %% [markdown]
# Create the following visualisations using your preferred method (i.e. Python, PowerPoint, Power BI, etc.) and add it to your report.
#
# Use the solution of Q2 to create a stacked column chart that shows the percentage of applications processed by the staff and by the vendor for each month (%staff processed applications+ %vendor processed applications should add up to 100%).
# Create a graph to show how the cost per application increases with respect to any change in the parameters in your analysis.
# Hint: Use the cost per application that you calculate in Questions 2, 3 and 4 (i.e., the best case, expected, expected with 10% outsourcing limit and the worst case).

# %% [markdown]
# **Note:** You can create the charts in Python or some other visualisation tools and make it a part of your final report directly.

# %% [markdown]
# # Question 6
#
# #### Additional proposed outsourced vendor
#
# The company sees the additional proposed outsourced vendor as ‘VENDOR 2’ with a cost per application as given below.
#
# **`Vendor 1`**
# **A:** 180 Dollars |
# **B:** 150 Dollars |
# **C:** 160 Dollars
#
# **`Vendor 2`**
# **A:** 155 Dollars |
# **B:** 150 Dollars |
# **C:** 158 Dollars
#
#
#
# The states have signed a memorandum with both vendors to maintain the ratio (60%: 40%) of Vendor 1:Vendor 2 for the number of applications that can be outsourced for every month in each state.
#
#
# **`Q 6.1-`** Calculate the optimal staffing at a 10% limit on outsourcing while maintaining the vendor ratio (60%:40%) for the number of applications that can be outsourced for every month in each state.
#
#
# **`Q 6.2-`** Optimal Allocation of the application after relaxing the ratio criterion mentioned above (60%: 40%) for the number of applications that can be outsourced for every month in each state.

# %% [markdown]
# #### Expected output:
# For each subtask (a) and (b), create a data frame containing the number of outsourced applications for each vendor and the number of FTEs for each state-month combination. You can choose to have extra columns like staff availability, demand etc. in your dataframe apart from the ones mentioned earlier.

# %% [markdown]
# ###  6.1 Optimal staffing at 10% limit on outsourcing while maintaining the vendor ratio as 60%:40% of the total application

# %%
# Creating a model instance
model = ConcreteModel()

# %%
# Define Pyomo sets and Parameters

#outsourcecost = for vendor_1
#outsourcecost_vendor2 = for vendor_2

# Optimal staffing at 10% limit on outsourcing
outsource_limit ={'A':0.1, 'B':0.1, 'C':0.1}
print('\n Quality reasons percent of Outsource allowed : ', outsource_limit)
# Out:
#  Quality reasons percent of Outsource allowed :  {'A': 0.1, 'B': 0.1, 'C': 0.1}

# %%
# Decision variables

#Number of applications managed by Staff or own employee
model.x = Var(state, month, within=Integers, bounds=(0,None))

#Number of applications managed by Outsourced Vendor_1
model.y = Var(state, month, within=Integers, bounds=(0,None))

#Number of applications managed by Outsourced Vendor_2
model.z = Var(state, month, within=Integers, bounds=(0,None))

# %% [markdown]
# ###### The states have signed a memorandum with both vendors to maintain the Vendor 1:Vendor 2 ratio at 60%:40% for the number of applications that can be outsourced for every month in each state.

# %%
# Constraints

#Quality requirement of maximum percentage of applications that can be outsourced - Scenario 1
def max_outsourced_perstate_permonth(model,s,m):
    return (model.y[s,m]+model.z[s,m]/Demand[s,m]) <= outsource_limit[s]
                   
model.max_outsourced = Constraint(state, month, rule=max_outsourced_perstate_permonth)

# %%
# Constraints
#entire demand should be serviced

def demand_serviced(model,s,m):
    return (model.x[s,m]+ model.y[s,m]+model.z[s,m]) == Demand[s,m]
                   
model.demandserviced = Constraint(state, month, rule=demand_serviced)

# %%
# Vendor 1:Vendor 2 ratio at 60%:40% for the number of applications that can be outsourced for every month in each state.

def ratio(model,s,m):
    return (0.60*model.y[s,m]==0.40*model.z[s,m])
                   
model.ratio_distribution = Constraint(state, month, rule=ratio)

# %%
# Objective function

# Defining the objective rule

#Total processing cost = Salary cost for inhouse processed applications + processing cost for outsourced applications
#outsourcing cost is equal to outsourced applications count (Y) mutplied by outsourcing cost per application
#salary cost is decision variable (X)  * employee salary adjusted for servicerate and availability rate

def obj_rule(model):
    
    return sum(((model.x[s,m]*FTE_Salary[s,m]/FTE_MgAppServed/StaffAvPer[s,m])
               +(model.y[s,m])*outsourcecost[s,m]+(model.z[s,m]*outsourcecost_vendor2[s,m]))
                for s in state for m in month)

# Minimize the total cost for the application approval process
model.value = Objective(rule=obj_rule, sense= minimize)

# %%
# Invoking the solver

result = SolverFactory('glpk').solve(model)
result.write()
# Out:
# # ==========================================================
# # = Solver Results                                         =
# # ==========================================================
# # ----------------------------------------------------------
# #   Problem Information
# # ----------------------------------------------------------
# Problem:
# - Name: unknown
#   Lower bound: 18144899.6638542
#   Upper bound: 18144899.6638542
#   Number of objectives: 1
#   Number of constraints: 109
#   Number of variables: 109
#   Number of nonzeros: 253
#   Sense: minimize
# # ----------------------------------------------------------
# #   Solver Information
# # ----------------------------------------------------------
# Solver:
# - Status: ok
#   Termination condition: optimal
#   Statistics:
#     Branch and bound:
#       Number of bounded subproblems: 0
#       Number of created subproblems: 0
#   Error rc: 0
#   Time: 0.11744570732116699
# # ----------------------------------------------------------
# #   Solution Information
# # ----------------------------------------------------------
# Solution:
# - number of solutions: 0
#   number of solutions displayed: 0

# %%
#Display model parameters after optimization
model.pprint()
# Out:
# 18 Set Declarations
#     demandserviced_index : Size=1, Index=None, Ordered=False
#         Key  : Dimen : Domain                                        : Size : Members
#         None :     2 : demandserviced_index_0*demandserviced_index_1 :   36 : {('A', 'Apr'), ('A', 'Aug'), ('A', 'Dec'), ('A', 'Feb'), ('A', 'Jan'), ('A', 'Jul'), ('A', 'Jun'), ('A', 'Mar'), ('A', 'May'), ('A', 'Nov'), ('A', 'Oct'), ('A', 'Sep'), ('B', 'Apr'), ('B', 'Aug'), ('B', 'Dec'), ('B', 'Feb'), ('B', 'Jan'), ('B', 'Jul'), ('B', 'Jun'), ('B', 'Mar'), ('B', 'May'), ('B', 'Nov'), ('B', 'Oct'), ('B', 'Sep'), ('C', 'Apr'), ('C', 'Aug'), ('C', 'Dec'), ('C', 'Feb'), ('C', 'Jan'), ('C', 'Jul'), ('C', 'Jun'), ('C', 'Mar'), ('C', 'May'), ('C', 'Nov'), ('C', 'Oct'), ('C', 'Sep')}
#     demandserviced_index_0 : Size=1, Index=None, Ordered=False
#         Key  : Dimen : Domain : Size : Members
#         None :     1 :    Any :    3 : {'A', 'B', 'C'}
#     demandserviced_index_1 : Size=1, Index=None, Ordered=False
#         Key  : Dimen : Domain : Size : Members
#         None :     1 :    Any :   12 : {'Apr', 'Aug', 'Dec', 'Feb', 'Jan', 'Jul', 'Jun', 'Mar', 'May', 'Nov', 'Oct', 'Sep'}
#     max_outsourced_index : Size=1, Index=None, Ordered=False
#         Key  : Dimen : Domain                                        : Size : Members
#         None :     2 : max_outsourced_index_0*max_outsourced_index_1 :   36 : {('A', 'Apr'), ('A', 'Aug'), ('A', 'Dec'), ('A', 'Feb'), ('A', 'Jan'), ('A', 'Jul'), ('A', 'Jun'), ('A', 'Mar'), ('A', 'May'), ('A', 'Nov'), ('A', 'Oct'), ('A', 'Sep'), ('B', 'Apr'), ('B', 'Aug'), ('B', 'Dec'), ('B', 'Feb'), ('B', 'Jan'), ('B', 'Jul'), ('B', 'Jun'), ('B', 'Mar'), ('B', 'May'), ('B', 'Nov'), ('B', 'Oct'), ('B', 'Sep'), ('C', 'Apr'), ('C', 'Aug'), ('C', 'Dec'), ('C', 'Feb'), ('C', 'Jan'), ('C', 'Jul'), ('C', 'Jun'), ('C', 'Mar'), ('C', 'May'), ('C', 'Nov'), ('C', 'Oct'), ('C', 'Sep')}
#     max_outsourced_index_0 : Size=1, Index=None, Ordered=False
#         Key  : Dimen : Domain : Size : Members
#         None :     1 :    Any :    3 : {'A', 'B', 'C'}
#     max_outsourced_index_1 : Size=1, Index=None, Ordered=False
#         Key  : Dimen : Domain : Size : Members
#         None :     1 :    Any :   12 : {'Apr', 'Aug', 'Dec', 'Feb', 'Jan', 'Jul', 'Jun', 'Mar', 'May', 'Nov', 'Oct', 'Sep'}
#     ratio_distribution_index : Size=1, Index=None, Ordered=False
#         Key  : Dimen : Domain                                                : Size : Members
#         None :     2 : ratio_distribution_index_0*ratio_distribution_index_1 :   36 : {('A', 'Apr'), ('A', 'Aug'), ('A', 'Dec'), ('A', 'Feb'), ('A', 'Jan'), ('A', 'Jul'), ('A', 'Jun'), ('A', 'Mar'), ('A', 'May'), ('A', 'Nov'), ('A', 'Oct'), ('A', 'Sep'), ('B', 'Apr'), ('B', 'Aug'), ('B', 'Dec'), ('B', 'Feb'), ('B', 'Jan'), ('B', 'Jul'), ('B', 'Jun'), ('B', 'Mar'), ('B', 'May'), ('B', 'Nov'), ('B', 'Oct'), ('B', 'Sep'), ('C', 'Apr'), ('C', 'Aug'), ('C', 'Dec'), ('C', 'Feb'), ('C', 'Jan'), ('C', 'Jul'), ('C', 'Jun'), ('C', 'Mar'), ('C', 'May'), ('C', 'Nov'), ('C', 'Oct'), ('C', 'Sep')}
#     ratio_distribution_index_0 : Size=1, Index=None, Ordered=False
#         Key  : Dimen : Domain : Size : Members
#         None :     1 :    Any :    3 : {'A', 'B', 'C'}
#     ratio_distribution_index_1 : Size=1, Index=None, Ordered=False
#         Key  : Dimen : Domain : Size : Members
#         None :     1 :    Any :   12 : {'Apr', 'Aug', 'Dec', 'Feb', 'Jan', 'Jul', 'Jun', 'Mar', 'May', 'Nov', 'Oct', 'Sep'}
#     x_index : Size=1, Index=None, Ordered=False
#         Key  : Dimen : Domain              : Size : Members
#         None :     2 : x_index_0*x_index_1 :   36 : {('A', 'Apr'), ('A', 'Aug'), ('A', 'Dec'), ('A', 'Feb'), ('A', 'Jan'), ('A', 'Jul'), ('A', 'Jun'), ('A', 'Mar'), ('A', 'May'), ('A', 'Nov'), ('A', 'Oct'), ('A', 'Sep'), ('B', 'Apr'), ('B', 'Aug'), ('B', 'Dec'), ('B', 'Feb'), ('B', 'Jan'), ('B', 'Jul'), ('B', 'Jun'), ('B', 'Mar'), ('B', 'May'), ('B', 'Nov'), ('B', 'Oct'), ('B', 'Sep'), ('C', 'Apr'), ('C', 'Aug'), ('C', 'Dec'), ('C', 'Feb'), ('C', 'Jan'), ('C', 'Jul'), ('C', 'Jun'), ('C', 'Mar'), ('C', 'May'), ('C', 'Nov'), ('C', 'Oct'), ('C', 'Sep')}
#     x_index_0 : Size=1, Index=None, Ordered=False
#         Key  : Dimen : Domain : Size : Members
#         None :     1 :    Any :    3 : {'A', 'B', 'C'}
#     x_index_1 : Size=1, Index=None, Ordered=False
#         Key  : Dimen : Domain : Size : Members
#         None :     1 :    Any :   12 : {'Apr', 'Aug', 'Dec', 'Feb', 'Jan', 'Jul', 'Jun', 'Mar', 'May', 'Nov', 'Oct', 'Sep'}
#     y_index : Size=1, Index=None, Ordered=False
#         Key  : Dimen : Domain              : Size : Members
#         None :     2 : y_index_0*y_index_1 :   36 : {('A', 'Apr'), ('A', 'Aug'), ('A', 'Dec'), ('A', 'Feb'), ('A', 'Jan'), ('A', 'Jul'), ('A', 'Jun'), ('A', 'Mar'), ('A', 'May'), ('A', 'Nov'), ('A', 'Oct'), ('A', 'Sep'), ('B', 'Apr'), ('B', 'Aug'), ('B', 'Dec'), ('B', 'Feb'), ('B', 'Jan'), ('B', 'Jul'), ('B', 'Jun'), ('B', 'Mar'), ('B', 'May'), ('B', 'Nov'), ('B', 'Oct'), ('B', 'Sep'), ('C', 'Apr'), ('C', 'Aug'), ('C', 'Dec'), ('C', 'Feb'), ('C', 'Jan'), ('C', 'Jul'), ('C', 'Jun'), ('C', 'Mar'), ('C', 'May'), ('C', 'Nov'), ('C', 'Oct'), ('C', 'Sep')}
#     y_index_0 : Size=1, Index=None, Ordered=False
#         Key  : Dimen : Domain : Size : Members
#         None :     1 :    Any :    3 : {'A', 'B', 'C'}
#     y_index_1 : Size=1, Index=None, Ordered=False
#         Key  : Dimen : Domain : Size : Members
#         None :     1 :    Any :   12 : {'Apr', 'Aug', 'Dec', 'Feb', 'Jan', 'Jul', 'Jun', 'Mar', 'May', 'Nov', 'Oct', 'Sep'}
#     z_index : Size=1, Index=None, Ordered=False
#         Key  : Dimen : Domain              : Size : Members
#         None :     2 : z_index_0*z_index_1 :   36 : {('A', 'Apr'), ('A', 'Aug'), ('A', 'Dec'), ('A', 'Feb'), ('A', 'Jan'), ('A', 'Jul'), ('A', 'Jun'), ('A', 'Mar'), ('A', 'May'), ('A', 'Nov'), ('A', 'Oct'), ('A', 'Sep'), ('B', 'Apr'), ('B', 'Aug'), ('B', 'Dec'), ('B', 'Feb'), ('B', 'Jan'), ('B', 'Jul'), ('B', 'Jun'), ('B', 'Mar'), ('B', 'May'), ('B', 'Nov'), ('B', 'Oct'), ('B', 'Sep'), ('C', 'Apr'), ('C', 'Aug'), ('C', 'Dec'), ('C', 'Feb'), ('C', 'Jan'), ('C', 'Jul'), ('C', 'Jun'), ('C', 'Mar'), ('C', 'May'), ('C', 'Nov'), ('C', 'Oct'), ('C', 'Sep')}
#     z_index_0 : Size=1, Index=None, Ordered=False
#         Key  : Dimen : Domain : Size : Members
#         None :     1 :    Any :    3 : {'A', 'B', 'C'}
#     z_index_1 : Size=1, Index=None, Ordered=False
#         Key  : Dimen : Domain : Size : Members
#         None :     1 :    Any :   12 : {'Apr', 'Aug', 'Dec', 'Feb', 'Jan', 'Jul', 'Jun', 'Mar', 'May', 'Nov', 'Oct', 'Sep'}
#
# 3 Var Declarations
#     x : Size=36, Index=x_index
#         Key          : Lower : Value  : Upper : Fixed : Stale : Domain
#         ('A', 'Apr') :     0 : 2297.0 :  None : False : False : Integers
#         ('A', 'Aug') :     0 : 3371.0 :  None : False : False : Integers
#         ('A', 'Dec') :     0 : 5183.0 :  None : False : False : Integers
#         ('A', 'Feb') :     0 : 4878.0 :  None : False : False : Integers
#         ('A', 'Jan') :     0 : 5240.0 :  None : False : False : Integers
#         ('A', 'Jul') :     0 : 5334.0 :  None : False : False : Integers
#         ('A', 'Jun') :     0 : 2275.0 :  None : False : False : Integers
#         ('A', 'Mar') :     0 : 5942.0 :  None : False : False : Integers
#         ('A', 'May') :     0 : 1992.0 :  None : False : False : Integers
#         ('A', 'Nov') :     0 : 4284.0 :  None : False : False : Integers
#         ('A', 'Oct') :     0 : 3529.0 :  None : False : False : Integers
#         ('A', 'Sep') :     0 : 3759.0 :  None : False : False : Integers
#         ('B', 'Apr') :     0 : 2338.0 :  None : False : False : Integers
#         ('B', 'Aug') :     0 : 2620.0 :  None : False : False : Integers
#         ('B', 'Dec') :     0 : 4227.0 :  None : False : False : Integers
#         ('B', 'Feb') :     0 : 2628.0 :  None : False : False : Integers
#         ('B', 'Jan') :     0 : 4927.0 :  None : False : False : Integers
#         ('B', 'Jul') :     0 : 4271.0 :  None : False : False : Integers
#         ('B', 'Jun') :     0 : 3147.0 :  None : False : False : Integers
#         ('B', 'Mar') :     0 : 2974.0 :  None : False : False : Integers
#         ('B', 'May') :     0 : 4020.0 :  None : False : False : Integers
#         ('B', 'Nov') :     0 : 3137.0 :  None : False : False : Integers
#         ('B', 'Oct') :     0 : 4155.0 :  None : False : False : Integers
#         ('B', 'Sep') :     0 : 4517.0 :  None : False : False : Integers
#         ('C', 'Apr') :     0 : 2261.0 :  None : False : False : Integers
#         ('C', 'Aug') :     0 : 2496.0 :  None : False : False : Integers
#         ('C', 'Dec') :     0 : 1998.0 :  None : False : False : Integers
#         ('C', 'Feb') :     0 : 1967.0 :  None : False : False : Integers
#         ('C', 'Jan') :     0 : 1162.0 :  None : False : False : Integers
#         ('C', 'Jul') :     0 : 2489.0 :  None : False : False : Integers
#         ('C', 'Jun') :     0 : 1642.0 :  None : False : False : Integers
#         ('C', 'Mar') :     0 : 1898.0 :  None : False : False : Integers
#         ('C', 'May') :     0 : 2030.0 :  None : False : False : Integers
#         ('C', 'Nov') :     0 :  963.0 :  None : False : False : Integers
#         ('C', 'Oct') :     0 : 2421.0 :  None : False : False : Integers
#         ('C', 'Sep') :     0 :  922.0 :  None : False : False : Integers
#     y : Size=36, Index=y_index
#         Key          : Lower : Value : Upper : Fixed : Stale : Domain
#         ('A', 'Apr') :     0 :   0.0 :  None : False : False : Integers
#         ('A', 'Aug') :     0 :   0.0 :  None : False : False : Integers
#         ('A', 'Dec') :     0 :   0.0 :  None : False : False : Integers
#         ('A', 'Feb') :     0 :   0.0 :  None : False : False : Integers
#         ('A', 'Jan') :     0 :   0.0 :  None : False : False : Integers
#         ('A', 'Jul') :     0 :   0.0 :  None : False : False : Integers
#         ('A', 'Jun') :     0 :   0.0 :  None : False : False : Integers
#         ('A', 'Mar') :     0 :   0.0 :  None : False : False : Integers
#         ('A', 'May') :     0 :   0.0 :  None : False : False : Integers
#         ('A', 'Nov') :     0 :   0.0 :  None : False : False : Integers
#         ('A', 'Oct') :     0 :   0.0 :  None : False : False : Integers
#         ('A', 'Sep') :     0 :   0.0 :  None : False : False : Integers
#         ('B', 'Apr') :     0 :   0.0 :  None : False : False : Integers
#         ('B', 'Aug') :     0 :   0.0 :  None : False : False : Integers
#         ('B', 'Dec') :     0 :   0.0 :  None : False : False : Integers
#         ('B', 'Feb') :     0 :   0.0 :  None : False : False : Integers
#         ('B', 'Jan') :     0 :   0.0 :  None : False : False : Integers
#         ('B', 'Jul') :     0 :   0.0 :  None : False : False : Integers
#         ('B', 'Jun') :     0 :   0.0 :  None : False : False : Integers
#         ('B', 'Mar') :     0 :   0.0 :  None : False : False : Integers
#         ('B', 'May') :     0 :   0.0 :  None : False : False : Integers
#         ('B', 'Nov') :     0 :   0.0 :  None : False : False : Integers
#         ('B', 'Oct') :     0 :   0.0 :  None : False : False : Integers
#         ('B', 'Sep') :     0 :   0.0 :  None : False : False : Integers
#         ('C', 'Apr') :     0 :   0.0 :  None : False : False : Integers
#         ('C', 'Aug') :     0 :   0.0 :  None : False : False : Integers
#         ('C', 'Dec') :     0 :   0.0 :  None : False : False : Integers
#         ('C', 'Feb') :     0 :   0.0 :  None : False : False : Integers
#         ('C', 'Jan') :     0 :   0.0 :  None : False : False : Integers
#         ('C', 'Jul') :     0 :   0.0 :  None : False : False : Integers
#         ('C', 'Jun') :     0 :   0.0 :  None : False : False : Integers
#         ('C', 'Mar') :     0 :   0.0 :  None : False : False : Integers
#         ('C', 'May') :     0 :   0.0 :  None : False : False : Integers
#         ('C', 'Nov') :     0 :   0.0 :  None : False : False : Integers
#         ('C', 'Oct') :     0 :   0.0 :  None : False : False : Integers
#         ('C', 'Sep') :     0 :   0.0 :  None : False : False : Integers
#     z : Size=36, Index=z_index
#         Key          : Lower : Value : Upper : Fixed : Stale : Domain
#         ('A', 'Apr') :     0 :   0.0 :  None : False : False : Integers
#         ('A', 'Aug') :     0 :   0.0 :  None : False : False : Integers
#         ('A', 'Dec') :     0 :   0.0 :  None : False : False : Integers
#         ('A', 'Feb') :     0 :   0.0 :  None : False : False : Integers
#         ('A', 'Jan') :     0 :   0.0 :  None : False : False : Integers
#         ('A', 'Jul') :     0 :   0.0 :  None : False : False : Integers
#         ('A', 'Jun') :     0 :   0.0 :  None : False : False : Integers
#         ('A', 'Mar') :     0 :   0.0 :  None : False : False : Integers
#         ('A', 'May') :     0 :   0.0 :  None : False : False : Integers
#         ('A', 'Nov') :     0 :   0.0 :  None : False : False : Integers
#         ('A', 'Oct') :     0 :   0.0 :  None : False : False : Integers
#         ('A', 'Sep') :     0 :   0.0 :  None : False : False : Integers
#         ('B', 'Apr') :     0 :   0.0 :  None : False : False : Integers
#         ('B', 'Aug') :     0 :   0.0 :  None : False : False : Integers
#         ('B', 'Dec') :     0 :   0.0 :  None : False : False : Integers
#         ('B', 'Feb') :     0 :   0.0 :  None : False : False : Integers
#         ('B', 'Jan') :     0 :   0.0 :  None : False : False : Integers
#         ('B', 'Jul') :     0 :   0.0 :  None : False : False : Integers
#         ('B', 'Jun') :     0 :   0.0 :  None : False : False : Integers
#         ('B', 'Mar') :     0 :   0.0 :  None : False : False : Integers
#         ('B', 'May') :     0 :   0.0 :  None : False : False : Integers
#         ('B', 'Nov') :     0 :   0.0 :  None : False : False : Integers
#         ('B', 'Oct') :     0 :   0.0 :  None : False : False : Integers
#         ('B', 'Sep') :     0 :   0.0 :  None : False : False : Integers
#         ('C', 'Apr') :     0 :   0.0 :  None : False : False : Integers
#         ('C', 'Aug') :     0 :   0.0 :  None : False : False : Integers
#         ('C', 'Dec') :     0 :   0.0 :  None : False : False : Integers
#         ('C', 'Feb') :     0 :   0.0 :  None : False : False : Integers
#         ('C', 'Jan') :     0 :   0.0 :  None : False : False : Integers
#         ('C', 'Jul') :     0 :   0.0 :  None : False : False : Integers
#         ('C', 'Jun') :     0 :   0.0 :  None : False : False : Integers
#         ('C', 'Mar') :     0 :   0.0 :  None : False : False : Integers
#         ('C', 'May') :     0 :   0.0 :  None : False : False : Integers
#         ('C', 'Nov') :     0 :   0.0 :  None : False : False : Integers
#         ('C', 'Oct') :     0 :   0.0 :  None : False : False : Integers
#         ('C', 'Sep') :     0 :   0.0 :  None : False : False : Integers
#
# 1 Objective Declarations
#     value : Size=1, Index=None, Active=True
#         Key  : Active : Sense    : Expression
#         None :   True : minimize : 154.320987654321*x[A,Jan] + 180.0*y[A,Jan] + 155*z[A,Jan] + 164.4736842105263*x[A,Feb] + 180.0*y[A,Feb] + 155*z[A,Feb] + 166.66666666666666*x[A,Mar] + 180.0*y[A,Mar] + 155*z[A,Mar] + 156.25*x[A,Apr] + 180.0*y[A,Apr] + 155*z[A,Apr] + 160.25641025641025*x[A,May] + 180.0*y[A,May] + 155*z[A,May] + 171.23287671232876*x[A,Jun] + 180.0*y[A,Jun] + 155*z[A,Jun] + 183.8235294117647*x[A,Jul] + 180.0*y[A,Jul] + 155*z[A,Jul] + 164.4736842105263*x[A,Aug] + 180.0*y[A,Aug] + 155*z[A,Aug] + 154.320987654321*x[A,Sep] + 180.0*y[A,Sep] + 155*z[A,Sep] + 171.23287671232876*x[A,Oct] + 180.0*y[A,Oct] + 155*z[A,Oct] + 183.8235294117647*x[A,Nov] + 180.0*y[A,Nov] + 155*z[A,Nov] + 192.3076923076923*x[A,Dec] + 180.0*y[A,Dec] + 155*z[A,Dec] + 141.46090534979422*x[B,Jan] + 150.0*y[B,Jan] + 150*z[B,Jan] + 150.76754385964912*x[B,Feb] + 150.0*y[B,Feb] + 150*z[B,Feb] + 152.77777777777777*x[B,Mar] + 150.0*y[B,Mar] + 150*z[B,Mar] + 143.22916666666666*x[B,Apr] + 150.0*y[B,Apr] + 150*z[B,Apr] + 146.90170940170938*x[B,May] + 150.0*y[B,May] + 150*z[B,May] + 156.9634703196347*x[B,Jun] + 150.0*y[B,Jun] + 150*z[B,Jun] + 168.50490196078428*x[B,Jul] + 150.0*y[B,Jul] + 150*z[B,Jul] + 150.76754385964912*x[B,Aug] + 150.0*y[B,Aug] + 150*z[B,Aug] + 141.46090534979422*x[B,Sep] + 150.0*y[B,Sep] + 150*z[B,Sep] + 156.9634703196347*x[B,Oct] + 150.0*y[B,Oct] + 150*z[B,Oct] + 168.50490196078428*x[B,Nov] + 150.0*y[B,Nov] + 150*z[B,Nov] + 176.28205128205127*x[B,Dec] + 150.0*y[B,Dec] + 150*z[B,Dec] + 136.31687242798353*x[C,Jan] + 160.0*y[C,Jan] + 158*z[C,Jan] + 145.28508771929825*x[C,Feb] + 160.0*y[C,Feb] + 158*z[C,Feb] + 147.22222222222223*x[C,Mar] + 160.0*y[C,Mar] + 158*z[C,Mar] + 138.02083333333334*x[C,Apr] + 160.0*y[C,Apr] + 158*z[C,Apr] + 141.55982905982907*x[C,May] + 160.0*y[C,May] + 158*z[C,May] + 151.25570776255708*x[C,Jun] + 160.0*y[C,Jun] + 158*z[C,Jun] + 162.37745098039215*x[C,Jul] + 160.0*y[C,Jul] + 158*z[C,Jul] + 145.28508771929825*x[C,Aug] + 160.0*y[C,Aug] + 158*z[C,Aug] + 136.31687242798353*x[C,Sep] + 160.0*y[C,Sep] + 158*z[C,Sep] + 151.25570776255708*x[C,Oct] + 160.0*y[C,Oct] + 158*z[C,Oct] + 162.37745098039215*x[C,Nov] + 160.0*y[C,Nov] + 158*z[C,Nov] + 169.87179487179486*x[C,Dec] + 160.0*y[C,Dec] + 158*z[C,Dec]
#
# 3 Constraint Declarations
#     demandserviced : Size=36, Index=demandserviced_index, Active=True
#         Key          : Lower  : Body                           : Upper  : Active
#         ('A', 'Apr') : 2297.0 : x[A,Apr] + y[A,Apr] + z[A,Apr] : 2297.0 :   True
#         ('A', 'Aug') : 3371.0 : x[A,Aug] + y[A,Aug] + z[A,Aug] : 3371.0 :   True
#         ('A', 'Dec') : 5183.0 : x[A,Dec] + y[A,Dec] + z[A,Dec] : 5183.0 :   True
#         ('A', 'Feb') : 4878.0 : x[A,Feb] + y[A,Feb] + z[A,Feb] : 4878.0 :   True
#         ('A', 'Jan') : 5240.0 : x[A,Jan] + y[A,Jan] + z[A,Jan] : 5240.0 :   True
#         ('A', 'Jul') : 5334.0 : x[A,Jul] + y[A,Jul] + z[A,Jul] : 5334.0 :   True
#         ('A', 'Jun') : 2275.0 : x[A,Jun] + y[A,Jun] + z[A,Jun] : 2275.0 :   True
#         ('A', 'Mar') : 5942.0 : x[A,Mar] + y[A,Mar] + z[A,Mar] : 5942.0 :   True
#         ('A', 'May') : 1992.0 : x[A,May] + y[A,May] + z[A,May] : 1992.0 :   True
#         ('A', 'Nov') : 4284.0 : x[A,Nov] + y[A,Nov] + z[A,Nov] : 4284.0 :   True
#         ('A', 'Oct') : 3529.0 : x[A,Oct] + y[A,Oct] + z[A,Oct] : 3529.0 :   True
#         ('A', 'Sep') : 3759.0 : x[A,Sep] + y[A,Sep] + z[A,Sep] : 3759.0 :   True
#         ('B', 'Apr') : 2338.0 : x[B,Apr] + y[B,Apr] + z[B,Apr] : 2338.0 :   True
#         ('B', 'Aug') : 2620.0 : x[B,Aug] + y[B,Aug] + z[B,Aug] : 2620.0 :   True
#         ('B', 'Dec') : 4227.0 : x[B,Dec] + y[B,Dec] + z[B,Dec] : 4227.0 :   True
#         ('B', 'Feb') : 2628.0 : x[B,Feb] + y[B,Feb] + z[B,Feb] : 2628.0 :   True
#         ('B', 'Jan') : 4927.0 : x[B,Jan] + y[B,Jan] + z[B,Jan] : 4927.0 :   True
#         ('B', 'Jul') : 4271.0 : x[B,Jul] + y[B,Jul] + z[B,Jul] : 4271.0 :   True
#         ('B', 'Jun') : 3147.0 : x[B,Jun] + y[B,Jun] + z[B,Jun] : 3147.0 :   True
#         ('B', 'Mar') : 2974.0 : x[B,Mar] + y[B,Mar] + z[B,Mar] : 2974.0 :   True
#         ('B', 'May') : 4020.0 : x[B,May] + y[B,May] + z[B,May] : 4020.0 :   True
#         ('B', 'Nov') : 3137.0 : x[B,Nov] + y[B,Nov] + z[B,Nov] : 3137.0 :   True
#         ('B', 'Oct') : 4155.0 : x[B,Oct] + y[B,Oct] + z[B,Oct] : 4155.0 :   True
#         ('B', 'Sep') : 4517.0 : x[B,Sep] + y[B,Sep] + z[B,Sep] : 4517.0 :   True
#         ('C', 'Apr') : 2261.0 : x[C,Apr] + y[C,Apr] + z[C,Apr] : 2261.0 :   True
#         ('C', 'Aug') : 2496.0 : x[C,Aug] + y[C,Aug] + z[C,Aug] : 2496.0 :   True
#         ('C', 'Dec') : 1998.0 : x[C,Dec] + y[C,Dec] + z[C,Dec] : 1998.0 :   True
#         ('C', 'Feb') : 1967.0 : x[C,Feb] + y[C,Feb] + z[C,Feb] : 1967.0 :   True
#         ('C', 'Jan') : 1162.0 : x[C,Jan] + y[C,Jan] + z[C,Jan] : 1162.0 :   True
#         ('C', 'Jul') : 2489.0 : x[C,Jul] + y[C,Jul] + z[C,Jul] : 2489.0 :   True
#         ('C', 'Jun') : 1642.0 : x[C,Jun] + y[C,Jun] + z[C,Jun] : 1642.0 :   True
#         ('C', 'Mar') : 1898.0 : x[C,Mar] + y[C,Mar] + z[C,Mar] : 1898.0 :   True
#         ('C', 'May') : 2030.0 : x[C,May] + y[C,May] + z[C,May] : 2030.0 :   True
#         ('C', 'Nov') :  963.0 : x[C,Nov] + y[C,Nov] + z[C,Nov] :  963.0 :   True
#         ('C', 'Oct') : 2421.0 : x[C,Oct] + y[C,Oct] + z[C,Oct] : 2421.0 :   True
#         ('C', 'Sep') :  922.0 : x[C,Sep] + y[C,Sep] + z[C,Sep] :  922.0 :   True
#     max_outsourced : Size=36, Index=max_outsourced_index, Active=True
#         Key          : Lower : Body                                       : Upper : Active
#         ('A', 'Apr') :  -Inf : y[A,Apr] + 0.00043535045711797995*z[A,Apr] :   0.1 :   True
#         ('A', 'Aug') :  -Inf :  y[A,Aug] + 0.0002966478789676654*z[A,Aug] :   0.1 :   True
#         ('A', 'Dec') :  -Inf : y[A,Dec] + 0.00019293845263360988*z[A,Dec] :   0.1 :   True
#         ('A', 'Feb') :  -Inf :  y[A,Feb] + 0.0002050020500205002*z[A,Feb] :   0.1 :   True
#         ('A', 'Jan') :  -Inf : y[A,Jan] + 0.00019083969465648855*z[A,Jan] :   0.1 :   True
#         ('A', 'Jul') :  -Inf : y[A,Jul] + 0.00018747656542932134*z[A,Jul] :   0.1 :   True
#         ('A', 'Jun') :  -Inf : y[A,Jun] + 0.00043956043956043956*z[A,Jun] :   0.1 :   True
#         ('A', 'Mar') :  -Inf :  y[A,Mar] + 0.0001682935038707506*z[A,Mar] :   0.1 :   True
#         ('A', 'May') :  -Inf :   y[A,May] + 0.000502008032128514*z[A,May] :   0.1 :   True
#         ('A', 'Nov') :  -Inf : y[A,Nov] + 0.00023342670401493932*z[A,Nov] :   0.1 :   True
#         ('A', 'Oct') :  -Inf : y[A,Oct] + 0.00028336639274582036*z[A,Oct] :   0.1 :   True
#         ('A', 'Sep') :  -Inf : y[A,Sep] + 0.00026602819898909286*z[A,Sep] :   0.1 :   True
#         ('B', 'Apr') :  -Inf :   y[B,Apr] + 0.000427715996578272*z[B,Apr] :   0.1 :   True
#         ('B', 'Aug') :  -Inf :  y[B,Aug] + 0.0003816793893129771*z[B,Aug] :   0.1 :   True
#         ('B', 'Dec') :  -Inf :  y[B,Dec] + 0.0002365744026496333*z[B,Dec] :   0.1 :   True
#         ('B', 'Feb') :  -Inf :   y[B,Feb] + 0.000380517503805175*z[B,Feb] :   0.1 :   True
#         ('B', 'Jan') :  -Inf : y[B,Jan] + 0.00020296326364927948*z[B,Jan] :   0.1 :   True
#         ('B', 'Jul') :  -Inf : y[B,Jul] + 0.00023413720440177945*z[B,Jul] :   0.1 :   True
#         ('B', 'Jun') :  -Inf : y[B,Jun] + 0.00031776294884016526*z[B,Jun] :   0.1 :   True
#         ('B', 'Mar') :  -Inf :  y[B,Mar] + 0.0003362474781439139*z[B,Mar] :   0.1 :   True
#         ('B', 'May') :  -Inf :  y[B,May] + 0.0002487562189054726*z[B,May] :   0.1 :   True
#         ('B', 'Nov') :  -Inf :   y[B,Nov] + 0.000318775900541919*z[B,Nov] :   0.1 :   True
#         ('B', 'Oct') :  -Inf : y[B,Oct] + 0.00024067388688327315*z[B,Oct] :   0.1 :   True
#         ('B', 'Sep') :  -Inf : y[B,Sep] + 0.00022138587558113792*z[B,Sep] :   0.1 :   True
#         ('C', 'Apr') :  -Inf :  y[C,Apr] + 0.0004422821760283061*z[C,Apr] :   0.1 :   True
#         ('C', 'Aug') :  -Inf : y[C,Aug] + 0.00040064102564102563*z[C,Aug] :   0.1 :   True
#         ('C', 'Dec') :  -Inf :  y[C,Dec] + 0.0005005005005005005*z[C,Dec] :   0.1 :   True
#         ('C', 'Feb') :  -Inf :  y[C,Feb] + 0.0005083884087442806*z[C,Feb] :   0.1 :   True
#         ('C', 'Jan') :  -Inf :  y[C,Jan] + 0.0008605851979345956*z[C,Jan] :   0.1 :   True
#         ('C', 'Jul') :  -Inf :  y[C,Jul] + 0.0004017677782241864*z[C,Jul] :   0.1 :   True
#         ('C', 'Jun') :  -Inf :  y[C,Jun] + 0.0006090133982947625*z[C,Jun] :   0.1 :   True
#         ('C', 'Mar') :  -Inf :  y[C,Mar] + 0.0005268703898840885*z[C,Mar] :   0.1 :   True
#         ('C', 'May') :  -Inf :  y[C,May] + 0.0004926108374384236*z[C,May] :   0.1 :   True
#         ('C', 'Nov') :  -Inf :  y[C,Nov] + 0.0010384215991692627*z[C,Nov] :   0.1 :   True
#         ('C', 'Oct') :  -Inf :  y[C,Oct] + 0.0004130524576621231*z[C,Oct] :   0.1 :   True
#         ('C', 'Sep') :  -Inf :  y[C,Sep] + 0.0010845986984815619*z[C,Sep] :   0.1 :   True
#     ratio_distribution : Size=36, Index=ratio_distribution_index, Active=True
#         Key          : Lower : Body                        : Upper : Active
#         ('A', 'Apr') :   0.0 : 0.6*y[A,Apr] - 0.4*z[A,Apr] :   0.0 :   True
#         ('A', 'Aug') :   0.0 : 0.6*y[A,Aug] - 0.4*z[A,Aug] :   0.0 :   True
#         ('A', 'Dec') :   0.0 : 0.6*y[A,Dec] - 0.4*z[A,Dec] :   0.0 :   True
#         ('A', 'Feb') :   0.0 : 0.6*y[A,Feb] - 0.4*z[A,Feb] :   0.0 :   True
#         ('A', 'Jan') :   0.0 : 0.6*y[A,Jan] - 0.4*z[A,Jan] :   0.0 :   True
#         ('A', 'Jul') :   0.0 : 0.6*y[A,Jul] - 0.4*z[A,Jul] :   0.0 :   True
#         ('A', 'Jun') :   0.0 : 0.6*y[A,Jun] - 0.4*z[A,Jun] :   0.0 :   True
#         ('A', 'Mar') :   0.0 : 0.6*y[A,Mar] - 0.4*z[A,Mar] :   0.0 :   True
#         ('A', 'May') :   0.0 : 0.6*y[A,May] - 0.4*z[A,May] :   0.0 :   True
#         ('A', 'Nov') :   0.0 : 0.6*y[A,Nov] - 0.4*z[A,Nov] :   0.0 :   True
#         ('A', 'Oct') :   0.0 : 0.6*y[A,Oct] - 0.4*z[A,Oct] :   0.0 :   True
#         ('A', 'Sep') :   0.0 : 0.6*y[A,Sep] - 0.4*z[A,Sep] :   0.0 :   True
#         ('B', 'Apr') :   0.0 : 0.6*y[B,Apr] - 0.4*z[B,Apr] :   0.0 :   True
#         ('B', 'Aug') :   0.0 : 0.6*y[B,Aug] - 0.4*z[B,Aug] :   0.0 :   True
#         ('B', 'Dec') :   0.0 : 0.6*y[B,Dec] - 0.4*z[B,Dec] :   0.0 :   True
#         ('B', 'Feb') :   0.0 : 0.6*y[B,Feb] - 0.4*z[B,Feb] :   0.0 :   True
#         ('B', 'Jan') :   0.0 : 0.6*y[B,Jan] - 0.4*z[B,Jan] :   0.0 :   True
#         ('B', 'Jul') :   0.0 : 0.6*y[B,Jul] - 0.4*z[B,Jul] :   0.0 :   True
#         ('B', 'Jun') :   0.0 : 0.6*y[B,Jun] - 0.4*z[B,Jun] :   0.0 :   True
#         ('B', 'Mar') :   0.0 : 0.6*y[B,Mar] - 0.4*z[B,Mar] :   0.0 :   True
#         ('B', 'May') :   0.0 : 0.6*y[B,May] - 0.4*z[B,May] :   0.0 :   True
#         ('B', 'Nov') :   0.0 : 0.6*y[B,Nov] - 0.4*z[B,Nov] :   0.0 :   True
#         ('B', 'Oct') :   0.0 : 0.6*y[B,Oct] - 0.4*z[B,Oct] :   0.0 :   True
#         ('B', 'Sep') :   0.0 : 0.6*y[B,Sep] - 0.4*z[B,Sep] :   0.0 :   True
#         ('C', 'Apr') :   0.0 : 0.6*y[C,Apr] - 0.4*z[C,Apr] :   0.0 :   True
#         ('C', 'Aug') :   0.0 : 0.6*y[C,Aug] - 0.4*z[C,Aug] :   0.0 :   True
#         ('C', 'Dec') :   0.0 : 0.6*y[C,Dec] - 0.4*z[C,Dec] :   0.0 :   True
#         ('C', 'Feb') :   0.0 : 0.6*y[C,Feb] - 0.4*z[C,Feb] :   0.0 :   True
#         ('C', 'Jan') :   0.0 : 0.6*y[C,Jan] - 0.4*z[C,Jan] :   0.0 :   True
#         ('C', 'Jul') :   0.0 : 0.6*y[C,Jul] - 0.4*z[C,Jul] :   0.0 :   True
#         ('C', 'Jun') :   0.0 : 0.6*y[C,Jun] - 0.4*z[C,Jun] :   0.0 :   True
#         ('C', 'Mar') :   0.0 : 0.6*y[C,Mar] - 0.4*z[C,Mar] :   0.0 :   True
#         ('C', 'May') :   0.0 : 0.6*y[C,May] - 0.4*z[C,May] :   0.0 :   True
#         ('C', 'Nov') :   0.0 : 0.6*y[C,Nov] - 0.4*z[C,Nov] :   0.0 :   True
#         ('C', 'Oct') :   0.0 : 0.6*y[C,Oct] - 0.4*z[C,Oct] :   0.0 :   True
#         ('C', 'Sep') :   0.0 : 0.6*y[C,Sep] - 0.4*z[C,Sep] :   0.0 :   True
#
# 25 Declarations: x_index_0 x_index_1 x_index x y_index_0 y_index_1 y_index y z_index_0 z_index_1 z_index z max_outsourced_index_0 max_outsourced_index_1 max_outsourced_index max_outsourced demandserviced_index_0 demandserviced_index_1 demandserviced_index demandserviced ratio_distribution_index_0 ratio_distribution_index_1 ratio_distribution_index ratio_distribution value

# %%
# Print the value of the objective function
val = model.value()
print(val/1000000)
# Out:
# 18.144899663854158

# %% [markdown]
# **`Checkpoint 6:`** The company has to spend around 18.1 m$ in total for the application approval process if there is ratio criterion.

# %%
# Creating dataframe for the results


#Creating an empty list
output6_1 = []

# For every iteration, the code below will create a list containing 6 values - 
# 1. count of applications managed by own staff (OwnStaff)
# 2. count of application managed by outsourced vendor (Outsourced)
# 3. demand (Demand) for each state for each month
# 4. number of FTE (own staff required)
# 5. percentage of application outosurced (PercentOutsourced)
# 6. cost of application processing (Total Cost)

for s in state:
    for m in month:
        
        #Demand for each state for each month
        Dem=Demand[s,m]
       
        #count of applications managed by own staff (OwnStaff)
        OwnStaff=model.x[s,m].value
        
        #count of applications managed by outsourced vendor_1 (Outsourced)
        Outsourced_Vendor_1=model.y[s,m].value
        
        #count of applications managed by outsourced vendor_2 (Outsourced)
        Outsourced_Vendor_2=model.z[s,m].value
        
        #Number of FTE
        FTE=round(model.x[s,m].value /FTE_MgAppServed/StaffAvPer[s,m],2)
        
        #percentage of application outosurced (PercentOutsourced)
        PercentOutsourced=round(model.y[s,m].value+model.z[s,m].value / Demand[s,m]*100,2)
        
        
        #cost of application processing (Total Cost)
        ProcessingCost=round((model.x[s,m].value*FTE_Salary[s,m]/FTE_MgAppServed/StaffAv_UB[s,m])\
                        +(model.y[s,m].value*outsourcecost[s,m])+(model.z[s,m].value*outsourcecost_vendor2[s,m]),2)
                
        output6_1.append([s,m,Dem,OwnStaff,Outsourced_Vendor_1, Outsourced_Vendor_2, FTE, PercentOutsourced,ProcessingCost])
        
        
output6_1 = pd.DataFrame(output6_1,columns=['State','Month','Demand','OwnStaff','Outsourced_Vendor1','Outsourced_Vendor2','FTE',\
                                            'PercentOutsourced','Application_Cost'])
output6_1
# Out:
#    State Month  Demand  OwnStaff  Outsourced_Vendor1  Outsourced_Vendor2  \
# 0      A   Jan    5240    5240.0                 0.0                 0.0
# 1      A   Feb    4878    4878.0                 0.0                 0.0
# 2      A   Mar    5942    5942.0                 0.0                 0.0
# 3      A   Apr    2297    2297.0                 0.0                 0.0
# 4      A   May    1992    1992.0                 0.0                 0.0
# 5      A   Jun    2275    2275.0                 0.0                 0.0
# 6      A   Jul    5334    5334.0                 0.0                 0.0
# 7      A   Aug    3371    3371.0                 0.0                 0.0
# 8      A   Sep    3759    3759.0                 0.0                 0.0
# 9      A   Oct    3529    3529.0                 0.0                 0.0
# 10     A   Nov    4284    4284.0                 0.0                 0.0
# 11     A   Dec    5183    5183.0                 0.0                 0.0
# 12     B   Jan    4927    4927.0                 0.0                 0.0
# 13     B   Feb    2628    2628.0                 0.0                 0.0
# 14     B   Mar    2974    2974.0                 0.0                 0.0
# 15     B   Apr    2338    2338.0                 0.0                 0.0
# 16     B   May    4020    4020.0                 0.0                 0.0
# 17     B   Jun    3147    3147.0                 0.0                 0.0
# 18     B   Jul    4271    4271.0                 0.0                 0.0
# 19     B   Aug    2620    2620.0                 0.0                 0.0
# 20     B   Sep    4517    4517.0                 0.0                 0.0
# 21     B   Oct    4155    4155.0                 0.0                 0.0
# 22     B   Nov    3137    3137.0                 0.0                 0.0
# 23     B   Dec    4227    4227.0                 0.0                 0.0
# 24     C   Jan    1162    1162.0                 0.0                 0.0
# 25     C   Feb    1967    1967.0                 0.0                 0.0
# 26     C   Mar    1898    1898.0                 0.0                 0.0
# 27     C   Apr    2261    2261.0                 0.0                 0.0
# 28     C   May    2030    2030.0                 0.0                 0.0
# 29     C   Jun    1642    1642.0                 0.0                 0.0
# 30     C   Jul    2489    2489.0                 0.0                 0.0
# 31     C   Aug    2496    2496.0                 0.0                 0.0
# 32     C   Sep     922     922.0                 0.0                 0.0
# 33     C   Oct    2421    2421.0                 0.0                 0.0
# 34     C   Nov     963     963.0                 0.0                 0.0
# 35     C   Dec    1998    1998.0                 0.0                 0.0
#
#        FTE  PercentOutsourced  Application_Cost
# 0   161.73                0.0         727777.78
# 1   160.46                0.0         717352.94
# 2   198.07                0.0         928437.50
# 3    71.78                0.0         337794.12
# 4    63.85                0.0         292941.18
# 5    77.91                0.0         355468.75
# 6   196.10                0.0         889000.00
# 7   110.89                0.0         495735.29
# 8   116.02                0.0         522083.33
# 9   120.86                0.0         551406.25
# 10  157.50                0.0         714000.00
# 11  199.35                0.0         925535.71
# 12  152.07                0.0         627280.09
# 13   86.45                0.0         354264.71
# 14   99.13                0.0         425963.54
# 15   73.06                0.0         315171.57
# 16  128.85                0.0         541911.76
# 17  107.77                0.0         450742.19
# 18  157.02                0.0         652513.89
# 19   86.18                0.0         353186.27
# 20  139.41                0.0         575081.02
# 21  142.29                0.0         595117.19
# 22  115.33                0.0         479263.89
# 23  162.58                0.0         691919.64
# 24   35.86                0.0         142560.19
# 25   64.70                0.0         255517.16
# 26   63.27                0.0         261963.54
# 27   70.66                0.0         293708.33
# 28   65.06                0.0         263700.98
# 29   56.23                0.0         226630.21
# 30   91.51                0.0         366436.11
# 31   82.11                0.0         324235.29
# 32   28.46                0.0         113115.74
# 33   82.91                0.0         334148.44
# 34   35.40                0.0         141775.00
# 35   76.85                0.0         315160.71

# %%
# Optimal staffing

sum(output6_1['OwnStaff'])
# Out:
# 113294.0

# %%
# Optimal staffing at 10% is 113294.

# %%
# Writing the results in to an Excel sheet

# Importing the required library
from openpyxl import load_workbook

book = load_workbook("C:\\Users\\dell\\Desktop\\Optimisation Case Study - Staff Planning\\Staffing+Data.xlsx")

# create excel writer object
writer = pd.ExcelWriter("C:\\Users\\dell\\Desktop\\Optimisation Case Study - Staff Planning\\Staffing+Data.xlsx", engine = 'openpyxl')

#Assigning the workbook to the writer object
writer.book = book

# write dataframe to excel sheet named 'Staffing+Data'
output6_1.to_excel(writer, sheet_name='Question 6, Scenario 1')

# save the excel file
writer.save()
print('DataFrame is loaded successfully to Excel Sheet.')
# Out:
# DataFrame is loaded successfully to Excel Sheet.

# %% [markdown]
# ### 6.2	Optimal allocation of application to vendors after relaxing the ratio criterion 60%:40% (Vendor 1:Vendor 2)

# %%
# Creating a model instance
model = ConcreteModel()

# %%
# Define Pyomo sets and Parameters

#outsourcecost = for vendor_1
#outsourcecost_vendor2 = for vendor_2

# %%
# Decision variables

#Number of applications managed by Staff or own employee
model.x = Var(state, month, within=Integers, bounds=(0,None))

#Number of applications managed by Outsourced Vendor_1
model.y = Var(state, month, within=Integers, bounds=(0,None))

#Number of applications managed by Outsourced Vendor_2
model.z = Var(state, month, within=Integers, bounds=(0,None))

# %%
# In this scenario there wont be any limit on the outsourcing of the application to the vendor.

# We will also relax the constraint of the 60:40.

# %%
# Constraints
#entire demand should be serviced

def demand_serviced(model,s,m):
    return (model.x[s,m]+ model.y[s,m]+model.z[s,m]) == Demand[s,m]
                   
model.demandserviced = Constraint(state, month, rule=demand_serviced)

# %%
# Objective function

# Defining the objective rule

#Total processing cost = Salary cost for inhouse processed applications + processing cost for outsourced applications
#outsourcing cost is equal to outsourced applications count (Y) mutplied by outsourcing cost per application
#salary cost is decision variable (X)  * employee salary adjusted for servicerate and availability rate

def obj_rule(model):
    
    return sum(((model.x[s,m]*FTE_Salary[s,m]/FTE_MgAppServed/StaffAvPer[s,m])
               +(model.y[s,m])*outsourcecost[s,m]+(model.z[s,m]*outsourcecost_vendor2[s,m]))
                for s in state for m in month)

# Minimize the total cost for the application approval process
model.value = Objective(rule=obj_rule, sense= minimize)

# %%
# Invoking the solver

result = SolverFactory('glpk').solve(model)
result.write()
# Out:
# # ==========================================================
# # = Solver Results                                         =
# # ==========================================================
# # ----------------------------------------------------------
# #   Problem Information
# # ----------------------------------------------------------
# Problem:
# - Name: unknown
#   Lower bound: 17069134.0056925
#   Upper bound: 17069134.0056925
#   Number of objectives: 1
#   Number of constraints: 37
#   Number of variables: 109
#   Number of nonzeros: 109
#   Sense: minimize
# # ----------------------------------------------------------
# #   Solver Information
# # ----------------------------------------------------------
# Solver:
# - Status: ok
#   Termination condition: optimal
#   Statistics:
#     Branch and bound:
#       Number of bounded subproblems: 1
#       Number of created subproblems: 1
#   Error rc: 0
#   Time: 0.07812047004699707
# # ----------------------------------------------------------
# #   Solution Information
# # ----------------------------------------------------------
# Solution:
# - number of solutions: 0
#   number of solutions displayed: 0

# %%
#Display model parameters after optimization
model.pprint()
# Out:
# 12 Set Declarations
#     demandserviced_index : Size=1, Index=None, Ordered=False
#         Key  : Dimen : Domain                                        : Size : Members
#         None :     2 : demandserviced_index_0*demandserviced_index_1 :   36 : {('A', 'Apr'), ('A', 'Aug'), ('A', 'Dec'), ('A', 'Feb'), ('A', 'Jan'), ('A', 'Jul'), ('A', 'Jun'), ('A', 'Mar'), ('A', 'May'), ('A', 'Nov'), ('A', 'Oct'), ('A', 'Sep'), ('B', 'Apr'), ('B', 'Aug'), ('B', 'Dec'), ('B', 'Feb'), ('B', 'Jan'), ('B', 'Jul'), ('B', 'Jun'), ('B', 'Mar'), ('B', 'May'), ('B', 'Nov'), ('B', 'Oct'), ('B', 'Sep'), ('C', 'Apr'), ('C', 'Aug'), ('C', 'Dec'), ('C', 'Feb'), ('C', 'Jan'), ('C', 'Jul'), ('C', 'Jun'), ('C', 'Mar'), ('C', 'May'), ('C', 'Nov'), ('C', 'Oct'), ('C', 'Sep')}
#     demandserviced_index_0 : Size=1, Index=None, Ordered=False
#         Key  : Dimen : Domain : Size : Members
#         None :     1 :    Any :    3 : {'A', 'B', 'C'}
#     demandserviced_index_1 : Size=1, Index=None, Ordered=False
#         Key  : Dimen : Domain : Size : Members
#         None :     1 :    Any :   12 : {'Apr', 'Aug', 'Dec', 'Feb', 'Jan', 'Jul', 'Jun', 'Mar', 'May', 'Nov', 'Oct', 'Sep'}
#     x_index : Size=1, Index=None, Ordered=False
#         Key  : Dimen : Domain              : Size : Members
#         None :     2 : x_index_0*x_index_1 :   36 : {('A', 'Apr'), ('A', 'Aug'), ('A', 'Dec'), ('A', 'Feb'), ('A', 'Jan'), ('A', 'Jul'), ('A', 'Jun'), ('A', 'Mar'), ('A', 'May'), ('A', 'Nov'), ('A', 'Oct'), ('A', 'Sep'), ('B', 'Apr'), ('B', 'Aug'), ('B', 'Dec'), ('B', 'Feb'), ('B', 'Jan'), ('B', 'Jul'), ('B', 'Jun'), ('B', 'Mar'), ('B', 'May'), ('B', 'Nov'), ('B', 'Oct'), ('B', 'Sep'), ('C', 'Apr'), ('C', 'Aug'), ('C', 'Dec'), ('C', 'Feb'), ('C', 'Jan'), ('C', 'Jul'), ('C', 'Jun'), ('C', 'Mar'), ('C', 'May'), ('C', 'Nov'), ('C', 'Oct'), ('C', 'Sep')}
#     x_index_0 : Size=1, Index=None, Ordered=False
#         Key  : Dimen : Domain : Size : Members
#         None :     1 :    Any :    3 : {'A', 'B', 'C'}
#     x_index_1 : Size=1, Index=None, Ordered=False
#         Key  : Dimen : Domain : Size : Members
#         None :     1 :    Any :   12 : {'Apr', 'Aug', 'Dec', 'Feb', 'Jan', 'Jul', 'Jun', 'Mar', 'May', 'Nov', 'Oct', 'Sep'}
#     y_index : Size=1, Index=None, Ordered=False
#         Key  : Dimen : Domain              : Size : Members
#         None :     2 : y_index_0*y_index_1 :   36 : {('A', 'Apr'), ('A', 'Aug'), ('A', 'Dec'), ('A', 'Feb'), ('A', 'Jan'), ('A', 'Jul'), ('A', 'Jun'), ('A', 'Mar'), ('A', 'May'), ('A', 'Nov'), ('A', 'Oct'), ('A', 'Sep'), ('B', 'Apr'), ('B', 'Aug'), ('B', 'Dec'), ('B', 'Feb'), ('B', 'Jan'), ('B', 'Jul'), ('B', 'Jun'), ('B', 'Mar'), ('B', 'May'), ('B', 'Nov'), ('B', 'Oct'), ('B', 'Sep'), ('C', 'Apr'), ('C', 'Aug'), ('C', 'Dec'), ('C', 'Feb'), ('C', 'Jan'), ('C', 'Jul'), ('C', 'Jun'), ('C', 'Mar'), ('C', 'May'), ('C', 'Nov'), ('C', 'Oct'), ('C', 'Sep')}
#     y_index_0 : Size=1, Index=None, Ordered=False
#         Key  : Dimen : Domain : Size : Members
#         None :     1 :    Any :    3 : {'A', 'B', 'C'}
#     y_index_1 : Size=1, Index=None, Ordered=False
#         Key  : Dimen : Domain : Size : Members
#         None :     1 :    Any :   12 : {'Apr', 'Aug', 'Dec', 'Feb', 'Jan', 'Jul', 'Jun', 'Mar', 'May', 'Nov', 'Oct', 'Sep'}
#     z_index : Size=1, Index=None, Ordered=False
#         Key  : Dimen : Domain              : Size : Members
#         None :     2 : z_index_0*z_index_1 :   36 : {('A', 'Apr'), ('A', 'Aug'), ('A', 'Dec'), ('A', 'Feb'), ('A', 'Jan'), ('A', 'Jul'), ('A', 'Jun'), ('A', 'Mar'), ('A', 'May'), ('A', 'Nov'), ('A', 'Oct'), ('A', 'Sep'), ('B', 'Apr'), ('B', 'Aug'), ('B', 'Dec'), ('B', 'Feb'), ('B', 'Jan'), ('B', 'Jul'), ('B', 'Jun'), ('B', 'Mar'), ('B', 'May'), ('B', 'Nov'), ('B', 'Oct'), ('B', 'Sep'), ('C', 'Apr'), ('C', 'Aug'), ('C', 'Dec'), ('C', 'Feb'), ('C', 'Jan'), ('C', 'Jul'), ('C', 'Jun'), ('C', 'Mar'), ('C', 'May'), ('C', 'Nov'), ('C', 'Oct'), ('C', 'Sep')}
#     z_index_0 : Size=1, Index=None, Ordered=False
#         Key  : Dimen : Domain : Size : Members
#         None :     1 :    Any :    3 : {'A', 'B', 'C'}
#     z_index_1 : Size=1, Index=None, Ordered=False
#         Key  : Dimen : Domain : Size : Members
#         None :     1 :    Any :   12 : {'Apr', 'Aug', 'Dec', 'Feb', 'Jan', 'Jul', 'Jun', 'Mar', 'May', 'Nov', 'Oct', 'Sep'}
#
# 3 Var Declarations
#     x : Size=36, Index=x_index
#         Key          : Lower : Value  : Upper : Fixed : Stale : Domain
#         ('A', 'Apr') :     0 :    0.0 :  None : False : False : Integers
#         ('A', 'Aug') :     0 :    0.0 :  None : False : False : Integers
#         ('A', 'Dec') :     0 :    0.0 :  None : False : False : Integers
#         ('A', 'Feb') :     0 :    0.0 :  None : False : False : Integers
#         ('A', 'Jan') :     0 : 5240.0 :  None : False : False : Integers
#         ('A', 'Jul') :     0 :    0.0 :  None : False : False : Integers
#         ('A', 'Jun') :     0 :    0.0 :  None : False : False : Integers
#         ('A', 'Mar') :     0 :    0.0 :  None : False : False : Integers
#         ('A', 'May') :     0 :    0.0 :  None : False : False : Integers
#         ('A', 'Nov') :     0 :    0.0 :  None : False : False : Integers
#         ('A', 'Oct') :     0 :    0.0 :  None : False : False : Integers
#         ('A', 'Sep') :     0 : 3759.0 :  None : False : False : Integers
#         ('B', 'Apr') :     0 : 2338.0 :  None : False : False : Integers
#         ('B', 'Aug') :     0 :    0.0 :  None : False : False : Integers
#         ('B', 'Dec') :     0 :    0.0 :  None : False : False : Integers
#         ('B', 'Feb') :     0 :    0.0 :  None : False : False : Integers
#         ('B', 'Jan') :     0 : 4927.0 :  None : False : False : Integers
#         ('B', 'Jul') :     0 :    0.0 :  None : False : False : Integers
#         ('B', 'Jun') :     0 :    0.0 :  None : False : False : Integers
#         ('B', 'Mar') :     0 :    0.0 :  None : False : False : Integers
#         ('B', 'May') :     0 : 4020.0 :  None : False : False : Integers
#         ('B', 'Nov') :     0 :    0.0 :  None : False : False : Integers
#         ('B', 'Oct') :     0 :    0.0 :  None : False : False : Integers
#         ('B', 'Sep') :     0 : 4517.0 :  None : False : False : Integers
#         ('C', 'Apr') :     0 : 2261.0 :  None : False : False : Integers
#         ('C', 'Aug') :     0 : 2496.0 :  None : False : False : Integers
#         ('C', 'Dec') :     0 :    0.0 :  None : False : False : Integers
#         ('C', 'Feb') :     0 : 1967.0 :  None : False : False : Integers
#         ('C', 'Jan') :     0 : 1162.0 :  None : False : False : Integers
#         ('C', 'Jul') :     0 :    0.0 :  None : False : False : Integers
#         ('C', 'Jun') :     0 : 1642.0 :  None : False : False : Integers
#         ('C', 'Mar') :     0 : 1898.0 :  None : False : False : Integers
#         ('C', 'May') :     0 : 2030.0 :  None : False : False : Integers
#         ('C', 'Nov') :     0 :    0.0 :  None : False : False : Integers
#         ('C', 'Oct') :     0 : 2421.0 :  None : False : False : Integers
#         ('C', 'Sep') :     0 :  922.0 :  None : False : False : Integers
#     y : Size=36, Index=y_index
#         Key          : Lower : Value : Upper : Fixed : Stale : Domain
#         ('A', 'Apr') :     0 :   0.0 :  None : False : False : Integers
#         ('A', 'Aug') :     0 :   0.0 :  None : False : False : Integers
#         ('A', 'Dec') :     0 :   0.0 :  None : False : False : Integers
#         ('A', 'Feb') :     0 :   0.0 :  None : False : False : Integers
#         ('A', 'Jan') :     0 :   0.0 :  None : False : False : Integers
#         ('A', 'Jul') :     0 :   0.0 :  None : False : False : Integers
#         ('A', 'Jun') :     0 :   0.0 :  None : False : False : Integers
#         ('A', 'Mar') :     0 :   0.0 :  None : False : False : Integers
#         ('A', 'May') :     0 :   0.0 :  None : False : False : Integers
#         ('A', 'Nov') :     0 :   0.0 :  None : False : False : Integers
#         ('A', 'Oct') :     0 :   0.0 :  None : False : False : Integers
#         ('A', 'Sep') :     0 :   0.0 :  None : False : False : Integers
#         ('B', 'Apr') :     0 :   0.0 :  None : False : False : Integers
#         ('B', 'Aug') :     0 :   0.0 :  None : False : False : Integers
#         ('B', 'Dec') :     0 :   0.0 :  None : False : False : Integers
#         ('B', 'Feb') :     0 :   0.0 :  None : False : False : Integers
#         ('B', 'Jan') :     0 :   0.0 :  None : False : False : Integers
#         ('B', 'Jul') :     0 :   0.0 :  None : False : False : Integers
#         ('B', 'Jun') :     0 :   0.0 :  None : False : False : Integers
#         ('B', 'Mar') :     0 :   0.0 :  None : False : False : Integers
#         ('B', 'May') :     0 :   0.0 :  None : False : False : Integers
#         ('B', 'Nov') :     0 :   0.0 :  None : False : False : Integers
#         ('B', 'Oct') :     0 :   0.0 :  None : False : False : Integers
#         ('B', 'Sep') :     0 :   0.0 :  None : False : False : Integers
#         ('C', 'Apr') :     0 :   0.0 :  None : False : False : Integers
#         ('C', 'Aug') :     0 :   0.0 :  None : False : False : Integers
#         ('C', 'Dec') :     0 :   0.0 :  None : False : False : Integers
#         ('C', 'Feb') :     0 :   0.0 :  None : False : False : Integers
#         ('C', 'Jan') :     0 :   0.0 :  None : False : False : Integers
#         ('C', 'Jul') :     0 :   0.0 :  None : False : False : Integers
#         ('C', 'Jun') :     0 :   0.0 :  None : False : False : Integers
#         ('C', 'Mar') :     0 :   0.0 :  None : False : False : Integers
#         ('C', 'May') :     0 :   0.0 :  None : False : False : Integers
#         ('C', 'Nov') :     0 :   0.0 :  None : False : False : Integers
#         ('C', 'Oct') :     0 :   0.0 :  None : False : False : Integers
#         ('C', 'Sep') :     0 :   0.0 :  None : False : False : Integers
#     z : Size=36, Index=z_index
#         Key          : Lower : Value  : Upper : Fixed : Stale : Domain
#         ('A', 'Apr') :     0 : 2297.0 :  None : False : False : Integers
#         ('A', 'Aug') :     0 : 3371.0 :  None : False : False : Integers
#         ('A', 'Dec') :     0 : 5183.0 :  None : False : False : Integers
#         ('A', 'Feb') :     0 : 4878.0 :  None : False : False : Integers
#         ('A', 'Jan') :     0 :    0.0 :  None : False : False : Integers
#         ('A', 'Jul') :     0 : 5334.0 :  None : False : False : Integers
#         ('A', 'Jun') :     0 : 2275.0 :  None : False : False : Integers
#         ('A', 'Mar') :     0 : 5942.0 :  None : False : False : Integers
#         ('A', 'May') :     0 : 1992.0 :  None : False : False : Integers
#         ('A', 'Nov') :     0 : 4284.0 :  None : False : False : Integers
#         ('A', 'Oct') :     0 : 3529.0 :  None : False : False : Integers
#         ('A', 'Sep') :     0 :    0.0 :  None : False : False : Integers
#         ('B', 'Apr') :     0 :    0.0 :  None : False : False : Integers
#         ('B', 'Aug') :     0 : 2620.0 :  None : False : False : Integers
#         ('B', 'Dec') :     0 : 4227.0 :  None : False : False : Integers
#         ('B', 'Feb') :     0 : 2628.0 :  None : False : False : Integers
#         ('B', 'Jan') :     0 :    0.0 :  None : False : False : Integers
#         ('B', 'Jul') :     0 : 4271.0 :  None : False : False : Integers
#         ('B', 'Jun') :     0 : 3147.0 :  None : False : False : Integers
#         ('B', 'Mar') :     0 : 2974.0 :  None : False : False : Integers
#         ('B', 'May') :     0 :    0.0 :  None : False : False : Integers
#         ('B', 'Nov') :     0 : 3137.0 :  None : False : False : Integers
#         ('B', 'Oct') :     0 : 4155.0 :  None : False : False : Integers
#         ('B', 'Sep') :     0 :    0.0 :  None : False : False : Integers
#         ('C', 'Apr') :     0 :    0.0 :  None : False : False : Integers
#         ('C', 'Aug') :     0 :    0.0 :  None : False : False : Integers
#         ('C', 'Dec') :     0 : 1998.0 :  None : False : False : Integers
#         ('C', 'Feb') :     0 :    0.0 :  None : False : False : Integers
#         ('C', 'Jan') :     0 :    0.0 :  None : False : False : Integers
#         ('C', 'Jul') :     0 : 2489.0 :  None : False : False : Integers
#         ('C', 'Jun') :     0 :    0.0 :  None : False : False : Integers
#         ('C', 'Mar') :     0 :    0.0 :  None : False : False : Integers
#         ('C', 'May') :     0 :    0.0 :  None : False : False : Integers
#         ('C', 'Nov') :     0 :  963.0 :  None : False : False : Integers
#         ('C', 'Oct') :     0 :    0.0 :  None : False : False : Integers
#         ('C', 'Sep') :     0 :    0.0 :  None : False : False : Integers
#
# 1 Objective Declarations
#     value : Size=1, Index=None, Active=True
#         Key  : Active : Sense    : Expression
#         None :   True : minimize : 154.320987654321*x[A,Jan] + 180.0*y[A,Jan] + 155*z[A,Jan] + 164.4736842105263*x[A,Feb] + 180.0*y[A,Feb] + 155*z[A,Feb] + 166.66666666666666*x[A,Mar] + 180.0*y[A,Mar] + 155*z[A,Mar] + 156.25*x[A,Apr] + 180.0*y[A,Apr] + 155*z[A,Apr] + 160.25641025641025*x[A,May] + 180.0*y[A,May] + 155*z[A,May] + 171.23287671232876*x[A,Jun] + 180.0*y[A,Jun] + 155*z[A,Jun] + 183.8235294117647*x[A,Jul] + 180.0*y[A,Jul] + 155*z[A,Jul] + 164.4736842105263*x[A,Aug] + 180.0*y[A,Aug] + 155*z[A,Aug] + 154.320987654321*x[A,Sep] + 180.0*y[A,Sep] + 155*z[A,Sep] + 171.23287671232876*x[A,Oct] + 180.0*y[A,Oct] + 155*z[A,Oct] + 183.8235294117647*x[A,Nov] + 180.0*y[A,Nov] + 155*z[A,Nov] + 192.3076923076923*x[A,Dec] + 180.0*y[A,Dec] + 155*z[A,Dec] + 141.46090534979422*x[B,Jan] + 150.0*y[B,Jan] + 150*z[B,Jan] + 150.76754385964912*x[B,Feb] + 150.0*y[B,Feb] + 150*z[B,Feb] + 152.77777777777777*x[B,Mar] + 150.0*y[B,Mar] + 150*z[B,Mar] + 143.22916666666666*x[B,Apr] + 150.0*y[B,Apr] + 150*z[B,Apr] + 146.90170940170938*x[B,May] + 150.0*y[B,May] + 150*z[B,May] + 156.9634703196347*x[B,Jun] + 150.0*y[B,Jun] + 150*z[B,Jun] + 168.50490196078428*x[B,Jul] + 150.0*y[B,Jul] + 150*z[B,Jul] + 150.76754385964912*x[B,Aug] + 150.0*y[B,Aug] + 150*z[B,Aug] + 141.46090534979422*x[B,Sep] + 150.0*y[B,Sep] + 150*z[B,Sep] + 156.9634703196347*x[B,Oct] + 150.0*y[B,Oct] + 150*z[B,Oct] + 168.50490196078428*x[B,Nov] + 150.0*y[B,Nov] + 150*z[B,Nov] + 176.28205128205127*x[B,Dec] + 150.0*y[B,Dec] + 150*z[B,Dec] + 136.31687242798353*x[C,Jan] + 160.0*y[C,Jan] + 158*z[C,Jan] + 145.28508771929825*x[C,Feb] + 160.0*y[C,Feb] + 158*z[C,Feb] + 147.22222222222223*x[C,Mar] + 160.0*y[C,Mar] + 158*z[C,Mar] + 138.02083333333334*x[C,Apr] + 160.0*y[C,Apr] + 158*z[C,Apr] + 141.55982905982907*x[C,May] + 160.0*y[C,May] + 158*z[C,May] + 151.25570776255708*x[C,Jun] + 160.0*y[C,Jun] + 158*z[C,Jun] + 162.37745098039215*x[C,Jul] + 160.0*y[C,Jul] + 158*z[C,Jul] + 145.28508771929825*x[C,Aug] + 160.0*y[C,Aug] + 158*z[C,Aug] + 136.31687242798353*x[C,Sep] + 160.0*y[C,Sep] + 158*z[C,Sep] + 151.25570776255708*x[C,Oct] + 160.0*y[C,Oct] + 158*z[C,Oct] + 162.37745098039215*x[C,Nov] + 160.0*y[C,Nov] + 158*z[C,Nov] + 169.87179487179486*x[C,Dec] + 160.0*y[C,Dec] + 158*z[C,Dec]
#
# 1 Constraint Declarations
#     demandserviced : Size=36, Index=demandserviced_index, Active=True
#         Key          : Lower  : Body                           : Upper  : Active
#         ('A', 'Apr') : 2297.0 : x[A,Apr] + y[A,Apr] + z[A,Apr] : 2297.0 :   True
#         ('A', 'Aug') : 3371.0 : x[A,Aug] + y[A,Aug] + z[A,Aug] : 3371.0 :   True
#         ('A', 'Dec') : 5183.0 : x[A,Dec] + y[A,Dec] + z[A,Dec] : 5183.0 :   True
#         ('A', 'Feb') : 4878.0 : x[A,Feb] + y[A,Feb] + z[A,Feb] : 4878.0 :   True
#         ('A', 'Jan') : 5240.0 : x[A,Jan] + y[A,Jan] + z[A,Jan] : 5240.0 :   True
#         ('A', 'Jul') : 5334.0 : x[A,Jul] + y[A,Jul] + z[A,Jul] : 5334.0 :   True
#         ('A', 'Jun') : 2275.0 : x[A,Jun] + y[A,Jun] + z[A,Jun] : 2275.0 :   True
#         ('A', 'Mar') : 5942.0 : x[A,Mar] + y[A,Mar] + z[A,Mar] : 5942.0 :   True
#         ('A', 'May') : 1992.0 : x[A,May] + y[A,May] + z[A,May] : 1992.0 :   True
#         ('A', 'Nov') : 4284.0 : x[A,Nov] + y[A,Nov] + z[A,Nov] : 4284.0 :   True
#         ('A', 'Oct') : 3529.0 : x[A,Oct] + y[A,Oct] + z[A,Oct] : 3529.0 :   True
#         ('A', 'Sep') : 3759.0 : x[A,Sep] + y[A,Sep] + z[A,Sep] : 3759.0 :   True
#         ('B', 'Apr') : 2338.0 : x[B,Apr] + y[B,Apr] + z[B,Apr] : 2338.0 :   True
#         ('B', 'Aug') : 2620.0 : x[B,Aug] + y[B,Aug] + z[B,Aug] : 2620.0 :   True
#         ('B', 'Dec') : 4227.0 : x[B,Dec] + y[B,Dec] + z[B,Dec] : 4227.0 :   True
#         ('B', 'Feb') : 2628.0 : x[B,Feb] + y[B,Feb] + z[B,Feb] : 2628.0 :   True
#         ('B', 'Jan') : 4927.0 : x[B,Jan] + y[B,Jan] + z[B,Jan] : 4927.0 :   True
#         ('B', 'Jul') : 4271.0 : x[B,Jul] + y[B,Jul] + z[B,Jul] : 4271.0 :   True
#         ('B', 'Jun') : 3147.0 : x[B,Jun] + y[B,Jun] + z[B,Jun] : 3147.0 :   True
#         ('B', 'Mar') : 2974.0 : x[B,Mar] + y[B,Mar] + z[B,Mar] : 2974.0 :   True
#         ('B', 'May') : 4020.0 : x[B,May] + y[B,May] + z[B,May] : 4020.0 :   True
#         ('B', 'Nov') : 3137.0 : x[B,Nov] + y[B,Nov] + z[B,Nov] : 3137.0 :   True
#         ('B', 'Oct') : 4155.0 : x[B,Oct] + y[B,Oct] + z[B,Oct] : 4155.0 :   True
#         ('B', 'Sep') : 4517.0 : x[B,Sep] + y[B,Sep] + z[B,Sep] : 4517.0 :   True
#         ('C', 'Apr') : 2261.0 : x[C,Apr] + y[C,Apr] + z[C,Apr] : 2261.0 :   True
#         ('C', 'Aug') : 2496.0 : x[C,Aug] + y[C,Aug] + z[C,Aug] : 2496.0 :   True
#         ('C', 'Dec') : 1998.0 : x[C,Dec] + y[C,Dec] + z[C,Dec] : 1998.0 :   True
#         ('C', 'Feb') : 1967.0 : x[C,Feb] + y[C,Feb] + z[C,Feb] : 1967.0 :   True
#         ('C', 'Jan') : 1162.0 : x[C,Jan] + y[C,Jan] + z[C,Jan] : 1162.0 :   True
#         ('C', 'Jul') : 2489.0 : x[C,Jul] + y[C,Jul] + z[C,Jul] : 2489.0 :   True
#         ('C', 'Jun') : 1642.0 : x[C,Jun] + y[C,Jun] + z[C,Jun] : 1642.0 :   True
#         ('C', 'Mar') : 1898.0 : x[C,Mar] + y[C,Mar] + z[C,Mar] : 1898.0 :   True
#         ('C', 'May') : 2030.0 : x[C,May] + y[C,May] + z[C,May] : 2030.0 :   True
#         ('C', 'Nov') :  963.0 : x[C,Nov] + y[C,Nov] + z[C,Nov] :  963.0 :   True
#         ('C', 'Oct') : 2421.0 : x[C,Oct] + y[C,Oct] + z[C,Oct] : 2421.0 :   True
#         ('C', 'Sep') :  922.0 : x[C,Sep] + y[C,Sep] + z[C,Sep] :  922.0 :   True
#
# 17 Declarations: x_index_0 x_index_1 x_index x y_index_0 y_index_1 y_index y z_index_0 z_index_1 z_index z demandserviced_index_0 demandserviced_index_1 demandserviced_index demandserviced value

# %%
# Print the value of the objective function
model.value()
# Out:
# 17069134.00569254

# %% [markdown]
# **`Checkpoint 7:`** The company has to spend around 17.1 m$ in total for the application approval process on realxing the ratio criterion which is lesser than the previous case.

# %%
# Creating dataframe for the results

#Creating an empty list
output6_2 = []

# For every iteration, the code below will create a list containing 6 values - 
# 1. count of applications managed by own staff (OwnStaff)
# 2. count of application managed by outsourced vendor (Outsourced)
# 3. demand (Demand) for each state for each month
# 4. number of FTE (own staff required)
# 5. percentage of application outosurced (PercentOutsourced)
# 6. cost of application processing (Total Cost)

for s in state:
    for m in month:
        
        #Demand for each state for each month
        Dem=Demand[s,m]
       
        #count of applications managed by own staff (OwnStaff)
        OwnStaff=model.x[s,m].value
        
        #count of applications managed by outsourced vendor_1 (Outsourced)
        Outsourced_Vendor_1=model.y[s,m].value
        
        #count of applications managed by outsourced vendor_2 (Outsourced)
        Outsourced_Vendor_2=model.z[s,m].value
        
        #Number of FTE
        FTE=round(model.x[s,m].value /FTE_MgAppServed/StaffAvPer[s,m],2)
        
        #percentage of application outosurced (PercentOutsourced)
        PercentOutsourced=round(model.y[s,m].value+model.z[s,m].value / Demand[s,m]*100,2)
        
        
        #cost of application processing (Total Cost)
        ProcessingCost=round((model.x[s,m].value*FTE_Salary[s,m]/FTE_MgAppServed/StaffAv_UB[s,m])\
                        +(model.y[s,m].value*outsourcecost[s,m])+(model.z[s,m].value*outsourcecost_vendor2[s,m]),2)
                
        output6_2.append([s,m,Dem,OwnStaff,Outsourced_Vendor_1, Outsourced_Vendor_2, FTE, PercentOutsourced,ProcessingCost])
        
        
output6_2 = pd.DataFrame(output6_2,columns=['State','Month','Demand','OwnStaff','Outsourced_Vendor1','Outsourced_Vendor2','FTE',\
                                            'PercentOutsourced','Application_Cost'])
output6_2
# Out:
#    State Month  Demand  OwnStaff  Outsourced_Vendor1  Outsourced_Vendor2  \
# 0      A   Jan    5240    5240.0                 0.0                 0.0
# 1      A   Feb    4878       0.0                 0.0              4878.0
# 2      A   Mar    5942       0.0                 0.0              5942.0
# 3      A   Apr    2297       0.0                 0.0              2297.0
# 4      A   May    1992       0.0                 0.0              1992.0
# 5      A   Jun    2275       0.0                 0.0              2275.0
# 6      A   Jul    5334       0.0                 0.0              5334.0
# 7      A   Aug    3371       0.0                 0.0              3371.0
# 8      A   Sep    3759    3759.0                 0.0                 0.0
# 9      A   Oct    3529       0.0                 0.0              3529.0
# 10     A   Nov    4284       0.0                 0.0              4284.0
# 11     A   Dec    5183       0.0                 0.0              5183.0
# 12     B   Jan    4927    4927.0                 0.0                 0.0
# 13     B   Feb    2628       0.0                 0.0              2628.0
# 14     B   Mar    2974       0.0                 0.0              2974.0
# 15     B   Apr    2338    2338.0                 0.0                 0.0
# 16     B   May    4020    4020.0                 0.0                 0.0
# 17     B   Jun    3147       0.0                 0.0              3147.0
# 18     B   Jul    4271       0.0                 0.0              4271.0
# 19     B   Aug    2620       0.0                 0.0              2620.0
# 20     B   Sep    4517    4517.0                 0.0                 0.0
# 21     B   Oct    4155       0.0                 0.0              4155.0
# 22     B   Nov    3137       0.0                 0.0              3137.0
# 23     B   Dec    4227       0.0                 0.0              4227.0
# 24     C   Jan    1162    1162.0                 0.0                 0.0
# 25     C   Feb    1967    1967.0                 0.0                 0.0
# 26     C   Mar    1898    1898.0                 0.0                 0.0
# 27     C   Apr    2261    2261.0                 0.0                 0.0
# 28     C   May    2030    2030.0                 0.0                 0.0
# 29     C   Jun    1642    1642.0                 0.0                 0.0
# 30     C   Jul    2489       0.0                 0.0              2489.0
# 31     C   Aug    2496    2496.0                 0.0                 0.0
# 32     C   Sep     922     922.0                 0.0                 0.0
# 33     C   Oct    2421    2421.0                 0.0                 0.0
# 34     C   Nov     963       0.0                 0.0               963.0
# 35     C   Dec    1998       0.0                 0.0              1998.0
#
#        FTE  PercentOutsourced  Application_Cost
# 0   161.73                0.0         727777.78
# 1     0.00              100.0         756090.00
# 2     0.00              100.0         921010.00
# 3     0.00              100.0         356035.00
# 4     0.00              100.0         308760.00
# 5     0.00              100.0         352625.00
# 6     0.00              100.0         826770.00
# 7     0.00              100.0         522505.00
# 8   116.02                0.0         522083.33
# 9     0.00              100.0         546995.00
# 10    0.00              100.0         664020.00
# 11    0.00              100.0         803365.00
# 12  152.07                0.0         627280.09
# 13    0.00              100.0         394200.00
# 14    0.00              100.0         446100.00
# 15   73.06                0.0         315171.57
# 16  128.85                0.0         541911.76
# 17    0.00              100.0         472050.00
# 18    0.00              100.0         640650.00
# 19    0.00              100.0         393000.00
# 20  139.41                0.0         575081.02
# 21    0.00              100.0         623250.00
# 22    0.00              100.0         470550.00
# 23    0.00              100.0         634050.00
# 24   35.86                0.0         142560.19
# 25   64.70                0.0         255517.16
# 26   63.27                0.0         261963.54
# 27   70.66                0.0         293708.33
# 28   65.06                0.0         263700.98
# 29   56.23                0.0         226630.21
# 30    0.00              100.0         393262.00
# 31   82.11                0.0         324235.29
# 32   28.46                0.0         113115.74
# 33   82.91                0.0         334148.44
# 34    0.00              100.0         152154.00
# 35    0.00              100.0         315684.00

# %% [markdown]
# ##### Allocation of application inhouse

# %%
# allocation of application in house

print(sum(output6_2['OwnStaff']))
# Out:
# 41600.0

# %% [markdown]
# ##### Allocation of application to Outsourced_Vendor1

# %%
print(sum(output6_2['Outsourced_Vendor1']))
# Out:
# 0.0

# %% [markdown]
# ##### Allocation of application to Outsourced_Vendor2

# %%
print(sum(output6_2['Outsourced_Vendor2']))
# Out:
# 71694.0

# %%
# Writing the results in to an Excel sheet

# Importing the required library
from openpyxl import load_workbook

book = load_workbook("C:\\Users\\dell\\Desktop\\Optimisation Case Study - Staff Planning\\Staffing+Data.xlsx")

# create excel writer object
writer = pd.ExcelWriter("C:\\Users\\dell\\Desktop\\Optimisation Case Study - Staff Planning\\Staffing+Data.xlsx", engine = 'openpyxl')

#Assigning the workbook to the writer object
writer.book = book

# write dataframe to excel sheet named 'Staffing+Data'
output6_2.to_excel(writer, sheet_name='Question 6, Scenario 2')

# save the excel file
writer.save()
print('DataFrame is loaded successfully to Excel Sheet.')
# Out:
# DataFrame is loaded successfully to Excel Sheet.
